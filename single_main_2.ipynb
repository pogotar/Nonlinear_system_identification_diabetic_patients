# %% [markdown]
# ### Imports

# %%
# %config InlineBackend.figure_format = 'svg'

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pickle
from models import NonLinearController, ClosedLoopSystem, NonLinearController_p2, Double_closed_loop
from Rens import REN_IQC_gamma, DualREN
from utils import set_params, set_QR, ensure_3d, fun_start_controller, fun_start_controller_simple
from torch.utils.data import DataLoader, random_split, Subset, SubsetRandomSampler, Dataset
from ParametersFunctions import Parameter, PID_functions, MinMaxScalerTorch
from pathlib import Path
import scipy.io as sio
from dataset import LoadData, SimpleLoadData

# from neural_ssm import DeepSSM

# model = DeepSSM(d_input=1, d_output=1, param='l2n')  #lru   l2n gamma prescritto
# y, _ = model(torch.tensor([5.0]))
# print(y)

# %% [markdown]
# ### Set parameters

# %%
# Parameters
# ------------
# If ecxecuted with papermill these parameters are overwritten.

patient = globals().get("patient", None)
device = globals().get("device", None)

# if not passed in papermill, set preferred values for manual use
if patient is None:
    patient = 1   # <-- preferred patient for manual use
if device is None:
    device = "cpu"  # <-- preferred device for manual use

# can add like this more optional parameters like batch size, epochs, learning rate, etc.

print(f"[INFO] Training per patient: {patient}    on device: {device}")




# Define simulation parameters
torch.set_default_dtype(torch.float64)

x0, input_dim, output_dim, dim_internal, dim_nl, y_init, IQC_type, gamma, learning_rate, epochs, data_path, model_folder, redo_save, ts, use_noise, num_days, redo_save_101_I, redo_save_101_M = set_params()
# Out:
# [INFO] Training per patient: 1    on device: cpu

# %% [markdown]
# # Closed-loop data

# %%
#-------------------------2. Generate closed loop data---------------------------------------------


# consecutive days split
train_size = int(num_days*0.8*1440//ts)
val_size = int(num_days*0.1*1440//ts)
test_size = int(num_days*0.1*1440//ts)

start_valid = 5*12 # 5 hours of warm-up for validation and test

# it is normalized, has as method also the scaler to denormalize
dataset = LoadData(patient, data_path, use_noise, train_size+start_valid)


val_dataset   = torch.utils.data.Subset(dataset, range(train_size+start_valid, train_size+start_valid + val_size))
test_dataset  = torch.utils.data.Subset(dataset, range(train_size+start_valid + val_size, train_size + val_size + test_size))

val_loader = DataLoader(val_dataset, batch_size=len(val_dataset), shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)



#------------------------- save scalers ---------------------------------------------------

scaler_glucose = dataset.scaler_glucose
scaler_insulin = dataset.scaler_insulin
scaler_meal    = dataset.scaler_meal


if redo_save:
    # Save the scalers
    # 1. Create models directory
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/" + patient_str
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save(scaler_glucose, MODEL_PATH / 'scaler_glucose.pth')
    torch.save(scaler_insulin, MODEL_PATH / 'scaler_insulin.pth')
    torch.save(scaler_meal,    MODEL_PATH / 'scaler_meal.pth')
    
    sio.savemat(MODEL_PATH / 'scalers.mat', {
    'glucose_low':  scaler_glucose.params['low'].item(),
    'glucose_high': scaler_glucose.params['high'].item(),
    'insulin_low':  scaler_insulin.params['low'].item(),
    'insulin_high': scaler_insulin.params['high'].item(),
    'meal_low':     scaler_meal.params['low'].item(),
    'meal_high':    scaler_meal.params['high'].item()
})

# %% [markdown]
# ### Plots: I and R

# %%
CGM   = (scaler_glucose.denormalize(dataset.CGM.detach())).numpy();              G     = (scaler_glucose.denormalize(dataset.G.detach())).numpy()
                                                                                                                                 
I_sat       = (scaler_insulin.denormalize(dataset.I_sat.detach())).numpy();      I_rec = (scaler_insulin.denormalize(dataset.I_rec.detach())).numpy();       
I_sat_rec   = (scaler_insulin.denormalize(dataset.I_sat_rec.detach())).numpy();  R     = (scaler_insulin.denormalize(dataset.R.detach())).numpy()

M       = (scaler_meal.denormalize(dataset.M.detach())).numpy();                 MH    = (scaler_meal.denormalize(dataset.MH.detach())).numpy();          
MH_rec  = (scaler_meal.denormalize(dataset.MH_rec.detach())).numpy()
H       = (scaler_meal.denormalize(dataset.H.detach())).numpy();                 H_rec = (scaler_meal.denormalize(dataset.H_rec.detach())).numpy();     

# R = I_sat (from .mat) - I_rec (exiting the PID and before saturation and noise)
# if  use_noise = True, R contains the noise and the saturation effect


# ------------------------- PID controller dynamic simulation ---------------------------------------------------
CGM_torch = dataset.CGM
time = dataset.time
loaded_parameters = Parameter(patient)
controller = NonLinearController(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise)
u_pid, u_pid_rwgn, u_pid_rwgn_sat, r = controller(CGM_torch, time)


u_pid           = scaler_insulin.denormalize(u_pid.detach())
u_pid_rwgn      = scaler_insulin.denormalize(u_pid_rwgn.detach())
u_pid_rwgn_sat  = scaler_insulin.denormalize(u_pid_rwgn_sat.detach())
r               = scaler_insulin.denormalize(r.detach())

plt.figure()
plt.plot(I_rec[:2*1440//ts]+ R[:2*1440//ts], label= 'I_rec + R')
plt.plot(u_pid_rwgn_sat.numpy()[:2*1440//ts], label = 'I pid dynamic calculation');             plt.legend();plt.grid(True); plt.show()

plt.figure()
plt.plot(R[:2*1440//ts], label= 'R')
plt.plot(r.numpy()[:2*1440//ts], label = 'R dynamic calculation');                             plt.legend();plt.grid(True); plt.show()

# %% [markdown]
# ### parallelization batches

# %%
# train start 5 h aafter midnight, every batch 48 h long finishing at 4:55 am


# time definitions
ts_per_hour = 12           # 288 timesteps = 24h → 12 timesteps/hour (5 min each)
hours_per_batch = 48       # 2 days = 48 hours
steps_per_batch = hours_per_batch * ts_per_hour  # 48*12 = 576

start_train = start_valid        #60    [1 element every 5 minutes] I eliminate eqully the first 5 hours from training set

train_dataset = torch.utils.data.Subset(dataset, range(start_train, train_size+start_valid))



# === FUNZIONE: crea blocchi fissi ===
def create_fixed_batches(total_length, chunk_size=576, start_idx=0):
    """
    Divide il dataset in batch temporali fissi (48h).
    Ogni batch è una lista di indici consecutivi.
    L'ultimo batch viene scartato se più corto di chunk_size.
    """
    batches = []
    start = start_idx
    while start + chunk_size <= total_length:
        end = start + chunk_size
        batches.append(list(range(start, end)))
        start = end
    return batches


# === COSTRUISCI I BATCH INDICI ===
train_indices = create_fixed_batches(len(train_dataset), chunk_size=steps_per_batch)

starting_indices = [batch[0] for batch in train_indices]

batch_size=len(starting_indices)

def collate_train_indices(batch):
    """
    batch: lista di 12 sequenze consecutive (ognuna di lunghezza 576)
    batch_size = len(batch) = 12
    """
    # ogni item del batch corrisponde a un indice di train_indices (576 timesteps)
    u0_batch = torch.stack([train_dataset[i][0] for i in batch]) # MH # shape: (12, 576, input_dim)
    u1_batch = torch.stack([train_dataset[i][3] for i in batch]) # I_sat
    ur_batch = torch.stack([train_dataset[i][2] for i in batch]) # r
    y_batch  = torch.stack([train_dataset[i][4] for i in batch])
    time_batch = torch.stack([train_dataset[i][5] for i in batch])
    
    return u0_batch, None, ur_batch, u1_batch, y_batch, time_batch



train_loader_p = DataLoader(
    train_indices,
    batch_size = batch_size,
    shuffle = False,  # oppure True se vuoi mescolare
    collate_fn = collate_train_indices,
    drop_last = True  # opzionale, elimina batch incompleti
)


saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

controller_p2 = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise = use_noise)

controller_p2.reset(saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)

# === LOOP DI TRAINING ===
for n_batch, (u0_batch, _, _, u1_batch, y_batch, time_batch) in enumerate(train_loader_p):

    u0_batch, u1_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
    u_pid, u_pid_rwgn, u_pid_rwgn_sat, r = controller_p2(CGM = y_batch.squeeze(2), time = time_batch.squeeze(2))
    
r = scaler_insulin.denormalize(r.detach())
for i in range(2):
    plt.figure()
    plt.plot(time_batch[i,:].numpy(), R[time_batch[i,:].squeeze().numpy().astype(int)], label= 'R')
    plt.plot(time_batch[i,:].numpy(), r[i,:].numpy(), label = 'R dynamic calculation');                             plt.legend();plt.grid(True); plt.show()
    
    

# === LOOP DI val ===
# !!! reset va lasciato a 0 solo se parto proprio dall'istante zero, con valid in realtà la simulazione era andata già da un po'

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(val_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
controller_p2.reset(saturation_error_init=saturation_error_init, glucose_PID_init=glucose_PID_init)
for u0_batch, _, _, u1_batch, y_batch, time_batch in val_loader:
    
    u0_batch, u1_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)

    u_pid, u_pid_rwgn, u_pid_rwgn_sat, r = controller_p2(CGM = y_batch.squeeze(2), time = time_batch.squeeze(2))
    
r = scaler_insulin.denormalize(r.detach())

plt.figure()
plt.plot(time_batch[0,:].numpy(), R[time_batch[0,:].squeeze().numpy().astype(int)], label= 'R')
plt.plot(time_batch[0,:].numpy(), r[0,:].numpy(), label = 'R dynamic calculation');                             plt.legend();plt.grid(True); plt.show()

# %% [markdown]
# ### other plots

# %%
plt.figure(1, figsize=(12, 8))

# Subplot 1
ax1 = plt.subplot(2, 1, 1)
ax1.plot(CGM[:], 'b-', label='Glucose sensor CGM')
ax1.plot(G[:], 'gray', label='Glucose');                                                               ax1.set_ylabel('Glucose', color='b'); ax1.tick_params(axis='y', labelcolor='b'); ax1_right = ax1.twinx()
MHtemp = MH[:].copy()
ax1_right.scatter(np.arange(len(MHtemp))[MHtemp!=0], MHtemp[MHtemp!=0], color='g', label='Meals and hypo');         ax1_right.set_ylabel('Meals', color='b'); ax1_right.tick_params(axis='y', labelcolor='g'); plt.grid(True)

# Subplot 2
ax2 = plt.subplot(2, 1, 2, sharex=ax1)
ax2.plot(range(len(I_sat[:])), I_sat[:].flatten(), label='I_sat')
ax2.plot(range(len(I_sat_rec[:])), I_sat_rec[:], label='I_sat_rec');                                      ax2.set_ylim([0, np.max(I_sat_rec) * 1.1]); ax2.legend(); ax2.set_xlabel('Time Index'); ax2.set_ylabel('Insulin')

plt.tight_layout(); plt.grid(True); plt.show()



plt.figure(3, figsize=(12, 8))
plt.plot(I_rec[:1440//4]+ R[:1440//4], label = 'I_rec(calculated by PID) + R')
plt.plot(I_sat[:1440//4], label= 'I_sat (from the data already saturated)')
plt.title('I saturated, They need to be equal,   R = I_sat - I_rec');                   plt.legend();plt.grid(True); plt.show()

plt.figure(4, figsize=(12, 8))
plt.plot(R[:1440//4], label= 'R')
plt.plot(I_rec[:1440//4]+ R[:1440//4], label= 'I_rec + R')
plt.plot(I_rec[:1440//4], label = 'I_rec  (calculated by PID)');                             plt.legend();plt.grid(True); plt.show()


# plt.figure(5)
# plt.plot(H, label='H')
# plt.plot(H_rec-100, label='H_rec')
# plt.title('Hypoglycemia Treatments Comparison');                                                    plt.legend(); plt.show()
#
# plt.figure(6)
# plt.plot(CGM[:1440//4], 'b-', label='Glucose sensor CGM')
# plt.plot(G[:1440//4], 'gray', label='Glucose')
# plt.figure(1, figsize=(12, 8))

# %% [markdown]
# # Patient 101

# %% [markdown]
# ### define dataset 101

# %%
dataset_101_I = SimpleLoadData('./data/train/30days_101_I/', 101,scaler_insulin, scaler_glucose, scaler_meal)
dataset_101_M = SimpleLoadData('./data/train/30days_101_M/', 101,scaler_insulin, scaler_glucose, scaler_meal)

train_dataset_101_I = torch.utils.data.Subset(dataset_101_I, range(start_train, train_size+start_valid))
train_dataset_101_M = torch.utils.data.Subset(dataset_101_M, range(start_train, train_size+start_valid))

val_dataset_101_I   = torch.utils.data.Subset(dataset_101_I, range(train_size+start_valid, train_size+start_valid + val_size))
val_dataset_101_M   = torch.utils.data.Subset(dataset_101_M, range(train_size+start_valid, train_size+start_valid + val_size))
test_dataset_101_I  = torch.utils.data.Subset(dataset_101_I, range(train_size+start_valid + val_size, train_size + val_size + test_size))
test_dataset_101_M  = torch.utils.data.Subset(dataset_101_M, range(train_size+start_valid + val_size, train_size + val_size + test_size))

val_loader_101_I = DataLoader(val_dataset_101_I, batch_size=len(val_dataset_101_I), shuffle=False)
val_loader_101_M = DataLoader(val_dataset_101_M, batch_size=len(val_dataset_101_M), shuffle=False)
test_loader_101_I = DataLoader(test_dataset_101_I, batch_size=len(test_dataset_101_I), shuffle=False)
test_loader_101_M = DataLoader(test_dataset_101_M, batch_size=len(test_dataset_101_M), shuffle=False)


def collate_train_indices_101_I(batch):
    """
    batch: lista di 12 sequenze consecutive (ognuna di lunghezza 576)
    batch_size = len(batch) = 12
    """
    # ogni item del batch corrisponde a un indice di train_indices (576 timesteps)
    u0_batch = torch.stack([train_dataset_101_I[i][0] for i in batch]) # MH 
    u1_batch = torch.stack([train_dataset_101_I[i][1] for i in batch]) # I_sat   (no RWGN)
    y_batch = torch.stack([train_dataset_101_I[i][2] for i in batch]) # y
    time_batch = torch.stack([train_dataset_101_I[i][3] for i in batch])

    return u0_batch, u1_batch, y_batch, time_batch

def collate_train_indices_101_M(batch):
    """
    batch: lista di 12 sequenze consecutive (ognuna di lunghezza 576)
    batch_size = len(batch) = 12
    """
    # ogni item del batch corrisponde a un indice di train_indices (576 timesteps)
    u0_batch = torch.stack([train_dataset_101_M[i][0] for i in batch]) # MH 
    u1_batch = torch.stack([train_dataset_101_M[i][1] for i in batch]) # I_sat   (no RWGN)
    y_batch = torch.stack([train_dataset_101_M[i][2] for i in batch]) # y
    time_batch = torch.stack([train_dataset_101_M[i][3] for i in batch])

    return u0_batch, u1_batch, y_batch, time_batch


train_loader_p_101_I = DataLoader(
    train_indices,
    batch_size = batch_size,
    shuffle = False,  # oppure True se vuoi mescolare
    collate_fn = collate_train_indices_101_I,
    drop_last = True  # opzionale, elimina batch incompleti
)

train_loader_p_101_M = DataLoader(
    train_indices,
    batch_size = batch_size,
    shuffle = False,  # oppure True se vuoi mescolare
    collate_fn = collate_train_indices_101_M,
    drop_last = True  # opzionale, elimina batch incompleti
)

# %% [markdown]
# ### REN model 101, loss function and optimizer parallel
# as strategy 1

# %%
#--------------------------3. Define model for sysid---------------------------------------------


device = torch.device(device if torch.cuda.is_available() else "cpu")

y0_1 = fun_start_controller_simple(train_loader_p_101_I, dataset_101_I)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0


# TODO: gamma diverso per i 101

# meal   M 
REN_0_101 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

# insulin  I_sat
REN_1_101 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

REN_0_101 = REN_0_101.to(device)
REN_1_101 = REN_1_101.to(device)

#create the closed loop with the identified model
# closed_loop_G = ClosedLoopSystem(REN_G, controller)

#--------------------------4. Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()

# %% [markdown]
# ### Training and validation loop

# %% [markdown]
# #### 101 I

# %%
optimizer = torch.optim.Adam( list(REN_1_101.parameters()),   lr=learning_rate)
optimizer.zero_grad()

epochs = 700

#--------------------------5. Training---------------------------------------------------------------------

torch.set_default_device(device)      # default tensor device
torch.set_default_dtype(torch.float32)  # default tensor dtype
print(f"[INFO] Training on device: {device}")

REN_1_101.to(device)
train_losses = []
val_losses = []  # Store validation losses across epochs
for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_1_101.train()
    loss_epoch = 0.0  # Accumulate training loss

    
    for _, u1_batch, y_batch, time_batch in train_loader_p_101_I: # MH, I_rec , CGM, time

        torch.save({'u1_batch': u1_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_valid.pt')
        

        u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
        u1_batch, y_batch, time_batch = u1_batch.to(device), y_batch.to(device), time_batch.to(device)
        
        optimizer.zero_grad()
        
        REN_1_101.reset(y0 = - y_batch[:,:1,:1])

        # y_init_per_batch      torch.zeros_like(y_batch[:,:1])    y_batch[:,:1]
        y1_hat_train = REN_1_101(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
        y_hat_train = - y1_hat_train 
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        optimizer.step()
        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_1_101.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for _, u1_batch, y_batch, time_batch in val_loader_101_I: # MH, I_rec (PID), CGM, time
            
            torch.save({'u1_batch': u1_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_valid.pt')

            u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
            u1_batch, y_batch, time_batch = u1_batch.to(device), y_batch.to(device), time_batch.to(device)
            
            REN_1_101.reset(y0 = - y_batch[:,:1,:1])

            y1_hat_val = REN_1_101(u1_batch, y0 = - y_batch[:,:1,:1])# select the correct U
            y_hat_val = - y1_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        
        candidate_REN_1_101 = REN_1_101

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")


patient_model_folder_101_I = "./models/101_I"
if redo_save_101_I:
    # model on CPU before saving
    candidate_REN_1_101_cpu = candidate_REN_1_101.to('cpu')

    # Save the best model
    # 1. Create models directory
    MODEL_PATH = Path(patient_model_folder_101_I)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_1_101_state_dict': candidate_REN_1_101_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder_101_I) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
# Out:
# [INFO] Training on device: cpu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 57
#      53 for _, u1_batch, y_batch, time_batch in val_loader_101_I: # MH, I_rec (PID), CGM, time
#      55     torch.save({'u1_batch': u1_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_valid.pt')
# ---> 57     u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
#      58     u1_batch, y_batch, time_batch = u1_batch.to(device), y_batch.to(device), time_batch.to(device)
#      60     REN_1_101.reset(y0 = - y_batch[:,:1,:1])
#
# Cell In[23], line 57
#      53 for _, u1_batch, y_batch, time_batch in val_loader_101_I: # MH, I_rec (PID), CGM, time
#      55     torch.save({'u1_batch': u1_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_valid.pt')
# ---> 57     u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
#      58     u1_batch, y_batch, time_batch = u1_batch.to(device), y_batch.to(device), time_batch.to(device)
#      60     REN_1_101.reset(y0 = - y_batch[:,:1,:1])
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\_pydevd_bundle\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\_pydevd_bundle\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\_pydevd_bundle\pydevd_cython.pyx:1368, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\_pydevd_bundle\pydevd_cython.pyx:1311, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\_pydevd_bundle\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# #### test 101 I

# %%
# --------------Plot identification results for G-----------------

patient_model_folder_101_I = "./models/101_I"
MODEL_PATH = Path(patient_model_folder_101_I)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])

# ----------------------------------

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs'); plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs  101 I')
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()


y0_1 = fun_start_controller_simple(train_loader_p_101_I, dataset_101_I)

REN_1_101 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

#########################################################

y0_1 = fun_start_controller_simple(test_loader_101_I, dataset_101_I)
REN_1_101.reset(y0 = -y0_1.unsqueeze(1))


checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")
REN_1_101.load_state_dict(checkpoint["REN_1_101_state_dict"])

#################################################################

for _, u1_batch, y_batch, time_batch in train_loader_p_101_I:

    u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
    
    REN_1_101.reset(y0 = -y_batch[:,:1,:1])

    y1_hat = REN_1_101(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = - y1_hat
    
    loss_train = MSE(y_hat, y_batch)

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

print(f"Loss train: {loss_train}")

fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Insulin (u1)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u1_batch[0,:,0].numpy(), color=color, label='Insulin')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Insulin vs Time, Train')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()



#####################################################################################


for _, u1_batch, y_batch, time_batch in test_loader_101_I:

    u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)

    REN_1_101.reset(y0 = -y_batch[:,:1,:1])
    y1_hat = REN_1_101(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = -y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()


fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Insulin (u1)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u1_batch[0,:,0].numpy(), color=color, label='Insulin')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Insulin vs Time, Test')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_16520\3377500202.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# Loss train: 0.0052614412270486355

# %% [markdown]
# #### 101 M

# %%
optimizer = torch.optim.Adam( list(REN_0_101.parameters()),   lr=learning_rate)
optimizer.zero_grad()

epochs = 700

#--------------------------5. Training---------------------------------------------------------------------

torch.set_default_device(device)      # default tensor device
torch.set_default_dtype(torch.float32)  # default tensor dtype
print(f"[INFO] Training on device: {device}")

REN_0_101.to(device)
train_losses = []
val_losses = []  # Store validation losses across epochs
for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_0_101.train()
    loss_epoch = 0.0  # Accumulate training loss

    
    for u0_batch, _, y_batch, time_batch in train_loader_p_101_M: # MH, I_rec (PID), CGM, time

        

        u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)
        u0_batch, y_batch, time_batch = u0_batch.to(device), y_batch.to(device), time_batch.to(device)
        
        optimizer.zero_grad()
        
        # REN_0_101.reset(y0 = torch.zeros_like(y_batch[:,:1,:1]))
        REN_0_101.reset(y0 = y_batch[:,:1,:1])

        # y_init_per_batch      torch.zeros_like(y_batch[:,:1])    y_batch[:,:1]
        y0_hat_train = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1]) # forward
        y_hat_train = y0_hat_train 
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        optimizer.step()
        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_0_101.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, y_batch, time_batch in val_loader_101_M: # MH, I_rec (PID), CGM, time

            u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)
            u0_batch, y_batch, time_batch = u0_batch.to(device), y_batch.to(device), time_batch.to(device)
            
            REN_0_101.reset(y0 = y_batch[:,:1,:1])

            y0_hat_val = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1])# select the correct U
            y_hat_val = y0_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        
        candidate_REN_0_101 = REN_0_101

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")


patient_model_folder_101_M = "./models/101_M"
if redo_save_101_M:
    # model on CPU before saving
    candidate_REN_0_101_cpu = candidate_REN_0_101.to('cpu')

    # Save the best model
    # 1. Create models directory
    MODEL_PATH = Path(patient_model_folder_101_M)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_0_101_state_dict': candidate_REN_0_101_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder_101_M) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
# Out:
# [INFO] Training on device: cpu
# Epoch: 1 	||	 Training Loss: 0.008838 	||	 Validation Loss: 0.010590
# Epoch: 2 	||	 Training Loss: 0.012546 	||	 Validation Loss: 0.006700
# Epoch: 3 	||	 Training Loss: 0.008411 	||	 Validation Loss: 0.007593
# Epoch: 4 	||	 Training Loss: 0.008970 	||	 Validation Loss: 0.008621
# Epoch: 5 	||	 Training Loss: 0.009850 	||	 Validation Loss: 0.009234
# Epoch: 6 	||	 Training Loss: 0.010321 	||	 Validation Loss: 0.008825
# Epoch: 7 	||	 Training Loss: 0.009927 	||	 Validation Loss: 0.007883
# Epoch: 8 	||	 Training Loss: 0.009082 	||	 Validation Loss: 0.007000
# Epoch: 9 	||	 Training Loss: 0.008287 	||	 Validation Loss: 0.006318
# Epoch: 10 	||	 Training Loss: 0.007726 	||	 Validation Loss: 0.006085
# Epoch: 11 	||	 Training Loss: 0.007648 	||	 Validation Loss: 0.006523
# Epoch: 12 	||	 Training Loss: 0.008165 	||	 Validation Loss: 0.006737
# Epoch: 13 	||	 Training Loss: 0.008368 	||	 Validation Loss: 0.006196
# Epoch: 14 	||	 Training Loss: 0.007789 	||	 Validation Loss: 0.005753
# Epoch: 15 	||	 Training Loss: 0.007243 	||	 Validation Loss: 0.005759
# Epoch: 16 	||	 Training Loss: 0.007118 	||	 Validation Loss: 0.005951
# Epoch: 17 	||	 Training Loss: 0.007208 	||	 Validation Loss: 0.006109
# Epoch: 18 	||	 Training Loss: 0.007304 	||	 Validation Loss: 0.006158
# Epoch: 19 	||	 Training Loss: 0.007320 	||	 Validation Loss: 0.006086
# Epoch: 20 	||	 Training Loss: 0.007238 	||	 Validation Loss: 0.005905
# Epoch: 21 	||	 Training Loss: 0.007067 	||	 Validation Loss: 0.005652
# Epoch: 22 	||	 Training Loss: 0.006844 	||	 Validation Loss: 0.005388
# Epoch: 23 	||	 Training Loss: 0.006623 	||	 Validation Loss: 0.005202
# Epoch: 24 	||	 Training Loss: 0.006484 	||	 Validation Loss: 0.005178
# Epoch: 25 	||	 Training Loss: 0.006487 	||	 Validation Loss: 0.005259
# Epoch: 26 	||	 Training Loss: 0.006565 	||	 Validation Loss: 0.005246
# Epoch: 27 	||	 Training Loss: 0.006535 	||	 Validation Loss: 0.005092
# Epoch: 28 	||	 Training Loss: 0.006363 	||	 Validation Loss: 0.004952
# Epoch: 29 	||	 Training Loss: 0.006194 	||	 Validation Loss: 0.004915
# Epoch: 30 	||	 Training Loss: 0.006120 	||	 Validation Loss: 0.004942
# Epoch: 31 	||	 Training Loss: 0.006111 	||	 Validation Loss: 0.004965
# Epoch: 32 	||	 Training Loss: 0.006108 	||	 Validation Loss: 0.004947
# Epoch: 33 	||	 Training Loss: 0.006076 	||	 Validation Loss: 0.004879
# Epoch: 34 	||	 Training Loss: 0.006005 	||	 Validation Loss: 0.004777
# Epoch: 35 	||	 Training Loss: 0.005909 	||	 Validation Loss: 0.004674
# Epoch: 36 	||	 Training Loss: 0.005814 	||	 Validation Loss: 0.004611
# Epoch: 37 	||	 Training Loss: 0.005752 	||	 Validation Loss: 0.004599
# Epoch: 38 	||	 Training Loss: 0.005733 	||	 Validation Loss: 0.004600
# Epoch: 39 	||	 Training Loss: 0.005723 	||	 Validation Loss: 0.004560
# Epoch: 40 	||	 Training Loss: 0.005678 	||	 Validation Loss: 0.004479
# Epoch: 41 	||	 Training Loss: 0.005601 	||	 Validation Loss: 0.004406
# Epoch: 42 	||	 Training Loss: 0.005534 	||	 Validation Loss: 0.004367
# Epoch: 43 	||	 Training Loss: 0.005496 	||	 Validation Loss: 0.004349
# Epoch: 44 	||	 Training Loss: 0.005477 	||	 Validation Loss: 0.004327
# Epoch: 45 	||	 Training Loss: 0.005453 	||	 Validation Loss: 0.004291
# Epoch: 46 	||	 Training Loss: 0.005413 	||	 Validation Loss: 0.004245
# Epoch: 47 	||	 Training Loss: 0.005361 	||	 Validation Loss: 0.004208
# Epoch: 48 	||	 Training Loss: 0.005312 	||	 Validation Loss: 0.004196
# Epoch: 49 	||	 Training Loss: 0.005280 	||	 Validation Loss: 0.004200
# Epoch: 50 	||	 Training Loss: 0.005261 	||	 Validation Loss: 0.004192
# Epoch: 51 	||	 Training Loss: 0.005238 	||	 Validation Loss: 0.004156
# Epoch: 52 	||	 Training Loss: 0.005201 	||	 Validation Loss: 0.004107
# Epoch: 53 	||	 Training Loss: 0.005160 	||	 Validation Loss: 0.004067
# Epoch: 54 	||	 Training Loss: 0.005130 	||	 Validation Loss: 0.004041
# Epoch: 55 	||	 Training Loss: 0.005109 	||	 Validation Loss: 0.004021
# Epoch: 56 	||	 Training Loss: 0.005089 	||	 Validation Loss: 0.004000
# Epoch: 57 	||	 Training Loss: 0.005062 	||	 Validation Loss: 0.003982
# Epoch: 58 	||	 Training Loss: 0.005031 	||	 Validation Loss: 0.003972
# Epoch: 59 	||	 Training Loss: 0.005003 	||	 Validation Loss: 0.003972
# Epoch: 60 	||	 Training Loss: 0.004983 	||	 Validation Loss: 0.003968
# Epoch: 61 	||	 Training Loss: 0.004965 	||	 Validation Loss: 0.003949
# Epoch: 62 	||	 Training Loss: 0.004944 	||	 Validation Loss: 0.003913
# Epoch: 63 	||	 Training Loss: 0.004919 	||	 Validation Loss: 0.003874
# Epoch: 64 	||	 Training Loss: 0.004896 	||	 Validation Loss: 0.003841
# Epoch: 65 	||	 Training Loss: 0.004878 	||	 Validation Loss: 0.003817
# Epoch: 66 	||	 Training Loss: 0.004862 	||	 Validation Loss: 0.003799
# Epoch: 67 	||	 Training Loss: 0.004843 	||	 Validation Loss: 0.003788
# Epoch: 68 	||	 Training Loss: 0.004823 	||	 Validation Loss: 0.003784
# Epoch: 69 	||	 Training Loss: 0.004804 	||	 Validation Loss: 0.003785
# Epoch: 70 	||	 Training Loss: 0.004788 	||	 Validation Loss: 0.003783
# Epoch: 71 	||	 Training Loss: 0.004774 	||	 Validation Loss: 0.003770
# Epoch: 72 	||	 Training Loss: 0.004758 	||	 Validation Loss: 0.003747
# Epoch: 73 	||	 Training Loss: 0.004741 	||	 Validation Loss: 0.003722
# Epoch: 74 	||	 Training Loss: 0.004725 	||	 Validation Loss: 0.003701
# Epoch: 75 	||	 Training Loss: 0.004711 	||	 Validation Loss: 0.003686
# Epoch: 76 	||	 Training Loss: 0.004698 	||	 Validation Loss: 0.003676
# Epoch: 77 	||	 Training Loss: 0.004684 	||	 Validation Loss: 0.003673
# Epoch: 78 	||	 Training Loss: 0.004670 	||	 Validation Loss: 0.003673
# Epoch: 79 	||	 Training Loss: 0.004657 	||	 Validation Loss: 0.003672
# Epoch: 80 	||	 Training Loss: 0.004645 	||	 Validation Loss: 0.003665
# Epoch: 81 	||	 Training Loss: 0.004633 	||	 Validation Loss: 0.003650
# Epoch: 82 	||	 Training Loss: 0.004621 	||	 Validation Loss: 0.003630
# Epoch: 83 	||	 Training Loss: 0.004609 	||	 Validation Loss: 0.003610
# Epoch: 84 	||	 Training Loss: 0.004598 	||	 Validation Loss: 0.003593
# Epoch: 85 	||	 Training Loss: 0.004587 	||	 Validation Loss: 0.003582
# Epoch: 86 	||	 Training Loss: 0.004577 	||	 Validation Loss: 0.003576
# Epoch: 87 	||	 Training Loss: 0.004566 	||	 Validation Loss: 0.003574
# Epoch: 88 	||	 Training Loss: 0.004556 	||	 Validation Loss: 0.003573
# Epoch: 89 	||	 Training Loss: 0.004546 	||	 Validation Loss: 0.003569
# Epoch: 90 	||	 Training Loss: 0.004537 	||	 Validation Loss: 0.003560
# Epoch: 91 	||	 Training Loss: 0.004528 	||	 Validation Loss: 0.003547
# Epoch: 92 	||	 Training Loss: 0.004518 	||	 Validation Loss: 0.003533
# Epoch: 93 	||	 Training Loss: 0.004510 	||	 Validation Loss: 0.003521
# Epoch: 94 	||	 Training Loss: 0.004501 	||	 Validation Loss: 0.003514
# Epoch: 95 	||	 Training Loss: 0.004493 	||	 Validation Loss: 0.003510
# Epoch: 96 	||	 Training Loss: 0.004484 	||	 Validation Loss: 0.003509
# Epoch: 97 	||	 Training Loss: 0.004476 	||	 Validation Loss: 0.003508
# Epoch: 98 	||	 Training Loss: 0.004469 	||	 Validation Loss: 0.003504
# Epoch: 99 	||	 Training Loss: 0.004461 	||	 Validation Loss: 0.003496
# Epoch: 100 	||	 Training Loss: 0.004454 	||	 Validation Loss: 0.003485
# Epoch: 101 	||	 Training Loss: 0.004446 	||	 Validation Loss: 0.003474
# Epoch: 102 	||	 Training Loss: 0.004439 	||	 Validation Loss: 0.003465
# Epoch: 103 	||	 Training Loss: 0.004432 	||	 Validation Loss: 0.003458
# Epoch: 104 	||	 Training Loss: 0.004425 	||	 Validation Loss: 0.003455
# Epoch: 105 	||	 Training Loss: 0.004418 	||	 Validation Loss: 0.003453
# Epoch: 106 	||	 Training Loss: 0.004412 	||	 Validation Loss: 0.003450
# Epoch: 107 	||	 Training Loss: 0.004405 	||	 Validation Loss: 0.003445
# Epoch: 108 	||	 Training Loss: 0.004399 	||	 Validation Loss: 0.003437
# Epoch: 109 	||	 Training Loss: 0.004393 	||	 Validation Loss: 0.003429
# Epoch: 110 	||	 Training Loss: 0.004387 	||	 Validation Loss: 0.003421
# Epoch: 111 	||	 Training Loss: 0.004381 	||	 Validation Loss: 0.003415
# Epoch: 112 	||	 Training Loss: 0.004375 	||	 Validation Loss: 0.003411
# Epoch: 113 	||	 Training Loss: 0.004369 	||	 Validation Loss: 0.003409
# Epoch: 114 	||	 Training Loss: 0.004364 	||	 Validation Loss: 0.003407
# Epoch: 115 	||	 Training Loss: 0.004358 	||	 Validation Loss: 0.003404
# Epoch: 116 	||	 Training Loss: 0.004353 	||	 Validation Loss: 0.003398
# Epoch: 117 	||	 Training Loss: 0.004348 	||	 Validation Loss: 0.003392
# Epoch: 118 	||	 Training Loss: 0.004342 	||	 Validation Loss: 0.003386
# Epoch: 119 	||	 Training Loss: 0.004337 	||	 Validation Loss: 0.003380
# Epoch: 120 	||	 Training Loss: 0.004332 	||	 Validation Loss: 0.003376
# Epoch: 121 	||	 Training Loss: 0.004327 	||	 Validation Loss: 0.003373
# Epoch: 122 	||	 Training Loss: 0.004322 	||	 Validation Loss: 0.003371
# Epoch: 123 	||	 Training Loss: 0.004318 	||	 Validation Loss: 0.003368
# Epoch: 124 	||	 Training Loss: 0.004313 	||	 Validation Loss: 0.003363
# Epoch: 125 	||	 Training Loss: 0.004308 	||	 Validation Loss: 0.003358
# Epoch: 126 	||	 Training Loss: 0.004304 	||	 Validation Loss: 0.003352
# Epoch: 127 	||	 Training Loss: 0.004299 	||	 Validation Loss: 0.003347
# Epoch: 128 	||	 Training Loss: 0.004295 	||	 Validation Loss: 0.003344
# Epoch: 129 	||	 Training Loss: 0.004290 	||	 Validation Loss: 0.003341
# Epoch: 130 	||	 Training Loss: 0.004286 	||	 Validation Loss: 0.003339
# Epoch: 131 	||	 Training Loss: 0.004282 	||	 Validation Loss: 0.003336
# Epoch: 132 	||	 Training Loss: 0.004277 	||	 Validation Loss: 0.003332
# Epoch: 133 	||	 Training Loss: 0.004273 	||	 Validation Loss: 0.003327
# Epoch: 134 	||	 Training Loss: 0.004269 	||	 Validation Loss: 0.003323
# Epoch: 135 	||	 Training Loss: 0.004265 	||	 Validation Loss: 0.003319
# Epoch: 136 	||	 Training Loss: 0.004261 	||	 Validation Loss: 0.003316
# Epoch: 137 	||	 Training Loss: 0.004257 	||	 Validation Loss: 0.003313
# Epoch: 138 	||	 Training Loss: 0.004253 	||	 Validation Loss: 0.003311
# Epoch: 139 	||	 Training Loss: 0.004249 	||	 Validation Loss: 0.003308
# Epoch: 140 	||	 Training Loss: 0.004245 	||	 Validation Loss: 0.003304
# Epoch: 141 	||	 Training Loss: 0.004242 	||	 Validation Loss: 0.003301
# Epoch: 142 	||	 Training Loss: 0.004238 	||	 Validation Loss: 0.003297
# Epoch: 143 	||	 Training Loss: 0.004234 	||	 Validation Loss: 0.003293
# Epoch: 144 	||	 Training Loss: 0.004230 	||	 Validation Loss: 0.003290
# Epoch: 145 	||	 Training Loss: 0.004227 	||	 Validation Loss: 0.003288
# Epoch: 146 	||	 Training Loss: 0.004223 	||	 Validation Loss: 0.003285
# Epoch: 147 	||	 Training Loss: 0.004220 	||	 Validation Loss: 0.003282
# Epoch: 148 	||	 Training Loss: 0.004216 	||	 Validation Loss: 0.003279
# Epoch: 149 	||	 Training Loss: 0.004213 	||	 Validation Loss: 0.003275
# Epoch: 150 	||	 Training Loss: 0.004209 	||	 Validation Loss: 0.003272
# Epoch: 151 	||	 Training Loss: 0.004206 	||	 Validation Loss: 0.003269
# Epoch: 152 	||	 Training Loss: 0.004202 	||	 Validation Loss: 0.003267
# Epoch: 153 	||	 Training Loss: 0.004199 	||	 Validation Loss: 0.003264
# Epoch: 154 	||	 Training Loss: 0.004195 	||	 Validation Loss: 0.003261
# Epoch: 155 	||	 Training Loss: 0.004192 	||	 Validation Loss: 0.003259
# Epoch: 156 	||	 Training Loss: 0.004189 	||	 Validation Loss: 0.003256
# Epoch: 157 	||	 Training Loss: 0.004186 	||	 Validation Loss: 0.003252
# Epoch: 158 	||	 Training Loss: 0.004182 	||	 Validation Loss: 0.003250
# Epoch: 159 	||	 Training Loss: 0.004179 	||	 Validation Loss: 0.003247
# Epoch: 160 	||	 Training Loss: 0.004176 	||	 Validation Loss: 0.003245
# Epoch: 161 	||	 Training Loss: 0.004173 	||	 Validation Loss: 0.003242
# Epoch: 162 	||	 Training Loss: 0.004169 	||	 Validation Loss: 0.003240
# Epoch: 163 	||	 Training Loss: 0.004166 	||	 Validation Loss: 0.003237
# Epoch: 164 	||	 Training Loss: 0.004163 	||	 Validation Loss: 0.003234
# Epoch: 165 	||	 Training Loss: 0.004160 	||	 Validation Loss: 0.003231
# Epoch: 166 	||	 Training Loss: 0.004157 	||	 Validation Loss: 0.003228
# Epoch: 167 	||	 Training Loss: 0.004154 	||	 Validation Loss: 0.003226
# Epoch: 168 	||	 Training Loss: 0.004151 	||	 Validation Loss: 0.003224
# Epoch: 169 	||	 Training Loss: 0.004148 	||	 Validation Loss: 0.003221
# Epoch: 170 	||	 Training Loss: 0.004145 	||	 Validation Loss: 0.003218
# Epoch: 171 	||	 Training Loss: 0.004142 	||	 Validation Loss: 0.003216
# Epoch: 172 	||	 Training Loss: 0.004139 	||	 Validation Loss: 0.003214
# Epoch: 173 	||	 Training Loss: 0.004136 	||	 Validation Loss: 0.003211
# Epoch: 174 	||	 Training Loss: 0.004133 	||	 Validation Loss: 0.003209
# Epoch: 175 	||	 Training Loss: 0.004130 	||	 Validation Loss: 0.003206
# Epoch: 176 	||	 Training Loss: 0.004127 	||	 Validation Loss: 0.003204
# Epoch: 177 	||	 Training Loss: 0.004124 	||	 Validation Loss: 0.003201
# Epoch: 178 	||	 Training Loss: 0.004121 	||	 Validation Loss: 0.003199
# Epoch: 179 	||	 Training Loss: 0.004119 	||	 Validation Loss: 0.003197
# Epoch: 180 	||	 Training Loss: 0.004116 	||	 Validation Loss: 0.003194
# Epoch: 181 	||	 Training Loss: 0.004113 	||	 Validation Loss: 0.003192
# Epoch: 182 	||	 Training Loss: 0.004110 	||	 Validation Loss: 0.003190
# Epoch: 183 	||	 Training Loss: 0.004107 	||	 Validation Loss: 0.003187
# Epoch: 184 	||	 Training Loss: 0.004104 	||	 Validation Loss: 0.003185
# Epoch: 185 	||	 Training Loss: 0.004102 	||	 Validation Loss: 0.003183
# Epoch: 186 	||	 Training Loss: 0.004099 	||	 Validation Loss: 0.003180
# Epoch: 187 	||	 Training Loss: 0.004096 	||	 Validation Loss: 0.003178
# Epoch: 188 	||	 Training Loss: 0.004093 	||	 Validation Loss: 0.003176
# Epoch: 189 	||	 Training Loss: 0.004091 	||	 Validation Loss: 0.003174
# Epoch: 190 	||	 Training Loss: 0.004088 	||	 Validation Loss: 0.003171
# Epoch: 191 	||	 Training Loss: 0.004085 	||	 Validation Loss: 0.003169
# Epoch: 192 	||	 Training Loss: 0.004082 	||	 Validation Loss: 0.003167
# Epoch: 193 	||	 Training Loss: 0.004080 	||	 Validation Loss: 0.003165
# Epoch: 194 	||	 Training Loss: 0.004077 	||	 Validation Loss: 0.003162
# Epoch: 195 	||	 Training Loss: 0.004074 	||	 Validation Loss: 0.003160
# Epoch: 196 	||	 Training Loss: 0.004072 	||	 Validation Loss: 0.003158
# Epoch: 197 	||	 Training Loss: 0.004069 	||	 Validation Loss: 0.003156
# Epoch: 198 	||	 Training Loss: 0.004066 	||	 Validation Loss: 0.003154
# Epoch: 199 	||	 Training Loss: 0.004064 	||	 Validation Loss: 0.003152
# Epoch: 200 	||	 Training Loss: 0.004061 	||	 Validation Loss: 0.003149
# Epoch: 201 	||	 Training Loss: 0.004058 	||	 Validation Loss: 0.003147
# Epoch: 202 	||	 Training Loss: 0.004056 	||	 Validation Loss: 0.003145
# Epoch: 203 	||	 Training Loss: 0.004053 	||	 Validation Loss: 0.003143
# Epoch: 204 	||	 Training Loss: 0.004051 	||	 Validation Loss: 0.003141
# Epoch: 205 	||	 Training Loss: 0.004048 	||	 Validation Loss: 0.003139
# Epoch: 206 	||	 Training Loss: 0.004045 	||	 Validation Loss: 0.003137
# Epoch: 207 	||	 Training Loss: 0.004043 	||	 Validation Loss: 0.003135
# Epoch: 208 	||	 Training Loss: 0.004040 	||	 Validation Loss: 0.003133
# Epoch: 209 	||	 Training Loss: 0.004038 	||	 Validation Loss: 0.003131
# Epoch: 210 	||	 Training Loss: 0.004035 	||	 Validation Loss: 0.003128
# Epoch: 211 	||	 Training Loss: 0.004032 	||	 Validation Loss: 0.003126
# Epoch: 212 	||	 Training Loss: 0.004030 	||	 Validation Loss: 0.003124
# Epoch: 213 	||	 Training Loss: 0.004027 	||	 Validation Loss: 0.003122
# Epoch: 214 	||	 Training Loss: 0.004025 	||	 Validation Loss: 0.003120
# Epoch: 215 	||	 Training Loss: 0.004022 	||	 Validation Loss: 0.003118
# Epoch: 216 	||	 Training Loss: 0.004020 	||	 Validation Loss: 0.003116
# Epoch: 217 	||	 Training Loss: 0.004017 	||	 Validation Loss: 0.003114
# Epoch: 218 	||	 Training Loss: 0.004015 	||	 Validation Loss: 0.003112
# Epoch: 219 	||	 Training Loss: 0.004012 	||	 Validation Loss: 0.003110
# Epoch: 220 	||	 Training Loss: 0.004010 	||	 Validation Loss: 0.003109
# Epoch: 221 	||	 Training Loss: 0.004007 	||	 Validation Loss: 0.003107
# Epoch: 222 	||	 Training Loss: 0.004005 	||	 Validation Loss: 0.003104
# Epoch: 223 	||	 Training Loss: 0.004002 	||	 Validation Loss: 0.003102
# Epoch: 224 	||	 Training Loss: 0.004000 	||	 Validation Loss: 0.003100
# Epoch: 225 	||	 Training Loss: 0.003997 	||	 Validation Loss: 0.003099
# Epoch: 226 	||	 Training Loss: 0.003995 	||	 Validation Loss: 0.003097
# Epoch: 227 	||	 Training Loss: 0.003993 	||	 Validation Loss: 0.003095
# Epoch: 228 	||	 Training Loss: 0.003990 	||	 Validation Loss: 0.003093
# Epoch: 229 	||	 Training Loss: 0.003988 	||	 Validation Loss: 0.003091
# Epoch: 230 	||	 Training Loss: 0.003985 	||	 Validation Loss: 0.003089
# Epoch: 231 	||	 Training Loss: 0.003983 	||	 Validation Loss: 0.003087
# Epoch: 232 	||	 Training Loss: 0.003980 	||	 Validation Loss: 0.003085
# Epoch: 233 	||	 Training Loss: 0.003978 	||	 Validation Loss: 0.003083
# Epoch: 234 	||	 Training Loss: 0.003976 	||	 Validation Loss: 0.003081
# Epoch: 235 	||	 Training Loss: 0.003973 	||	 Validation Loss: 0.003080
# Epoch: 236 	||	 Training Loss: 0.003971 	||	 Validation Loss: 0.003078
# Epoch: 237 	||	 Training Loss: 0.003968 	||	 Validation Loss: 0.003076
# Epoch: 238 	||	 Training Loss: 0.003966 	||	 Validation Loss: 0.003074
# Epoch: 239 	||	 Training Loss: 0.003964 	||	 Validation Loss: 0.003072
# Epoch: 240 	||	 Training Loss: 0.003961 	||	 Validation Loss: 0.003070
# Epoch: 241 	||	 Training Loss: 0.003959 	||	 Validation Loss: 0.003068
# Epoch: 242 	||	 Training Loss: 0.003956 	||	 Validation Loss: 0.003067
# Epoch: 243 	||	 Training Loss: 0.003954 	||	 Validation Loss: 0.003065
# Epoch: 244 	||	 Training Loss: 0.003952 	||	 Validation Loss: 0.003063
# Epoch: 245 	||	 Training Loss: 0.003949 	||	 Validation Loss: 0.003061
# Epoch: 246 	||	 Training Loss: 0.003947 	||	 Validation Loss: 0.003059
# Epoch: 247 	||	 Training Loss: 0.003945 	||	 Validation Loss: 0.003057
# Epoch: 248 	||	 Training Loss: 0.003942 	||	 Validation Loss: 0.003056
# Epoch: 249 	||	 Training Loss: 0.003940 	||	 Validation Loss: 0.003054
# Epoch: 250 	||	 Training Loss: 0.003938 	||	 Validation Loss: 0.003052
# Epoch: 251 	||	 Training Loss: 0.003935 	||	 Validation Loss: 0.003050
# Epoch: 252 	||	 Training Loss: 0.003933 	||	 Validation Loss: 0.003049
# Epoch: 253 	||	 Training Loss: 0.003931 	||	 Validation Loss: 0.003047
# Epoch: 254 	||	 Training Loss: 0.003928 	||	 Validation Loss: 0.003045
# Epoch: 255 	||	 Training Loss: 0.003926 	||	 Validation Loss: 0.003044
# Epoch: 256 	||	 Training Loss: 0.003924 	||	 Validation Loss: 0.003042
# Epoch: 257 	||	 Training Loss: 0.003922 	||	 Validation Loss: 0.003040
# Epoch: 258 	||	 Training Loss: 0.003919 	||	 Validation Loss: 0.003038
# Epoch: 259 	||	 Training Loss: 0.003917 	||	 Validation Loss: 0.003037
# Epoch: 260 	||	 Training Loss: 0.003915 	||	 Validation Loss: 0.003035
# Epoch: 261 	||	 Training Loss: 0.003912 	||	 Validation Loss: 0.003033
# Epoch: 262 	||	 Training Loss: 0.003910 	||	 Validation Loss: 0.003031
# Epoch: 263 	||	 Training Loss: 0.003908 	||	 Validation Loss: 0.003029
# Epoch: 264 	||	 Training Loss: 0.003906 	||	 Validation Loss: 0.003028
# Epoch: 265 	||	 Training Loss: 0.003903 	||	 Validation Loss: 0.003026
# Epoch: 266 	||	 Training Loss: 0.003901 	||	 Validation Loss: 0.003025
# Epoch: 267 	||	 Training Loss: 0.003899 	||	 Validation Loss: 0.003023
# Epoch: 268 	||	 Training Loss: 0.003897 	||	 Validation Loss: 0.003021
# Epoch: 269 	||	 Training Loss: 0.003894 	||	 Validation Loss: 0.003020
# Epoch: 270 	||	 Training Loss: 0.003892 	||	 Validation Loss: 0.003018
# Epoch: 271 	||	 Training Loss: 0.003890 	||	 Validation Loss: 0.003016
# Epoch: 272 	||	 Training Loss: 0.003888 	||	 Validation Loss: 0.003015
# Epoch: 273 	||	 Training Loss: 0.003885 	||	 Validation Loss: 0.003013
# Epoch: 274 	||	 Training Loss: 0.003883 	||	 Validation Loss: 0.003011
# Epoch: 275 	||	 Training Loss: 0.003881 	||	 Validation Loss: 0.003010
# Epoch: 276 	||	 Training Loss: 0.003879 	||	 Validation Loss: 0.003008
# Epoch: 277 	||	 Training Loss: 0.003876 	||	 Validation Loss: 0.003006
# Epoch: 278 	||	 Training Loss: 0.003874 	||	 Validation Loss: 0.003005
# Epoch: 279 	||	 Training Loss: 0.003872 	||	 Validation Loss: 0.003003
# Epoch: 280 	||	 Training Loss: 0.003870 	||	 Validation Loss: 0.003002
# Epoch: 281 	||	 Training Loss: 0.003868 	||	 Validation Loss: 0.003000
# Epoch: 282 	||	 Training Loss: 0.003865 	||	 Validation Loss: 0.002998
# Epoch: 283 	||	 Training Loss: 0.003863 	||	 Validation Loss: 0.002997
# Epoch: 284 	||	 Training Loss: 0.003861 	||	 Validation Loss: 0.002995
# Epoch: 285 	||	 Training Loss: 0.003859 	||	 Validation Loss: 0.002994
# Epoch: 286 	||	 Training Loss: 0.003857 	||	 Validation Loss: 0.002992
# Epoch: 287 	||	 Training Loss: 0.003855 	||	 Validation Loss: 0.002991
# Epoch: 288 	||	 Training Loss: 0.003852 	||	 Validation Loss: 0.002989
# Epoch: 289 	||	 Training Loss: 0.003850 	||	 Validation Loss: 0.002988
# Epoch: 290 	||	 Training Loss: 0.003848 	||	 Validation Loss: 0.002986
# Epoch: 291 	||	 Training Loss: 0.003846 	||	 Validation Loss: 0.002985
# Epoch: 292 	||	 Training Loss: 0.003844 	||	 Validation Loss: 0.002983
# Epoch: 293 	||	 Training Loss: 0.003842 	||	 Validation Loss: 0.002981
# Epoch: 294 	||	 Training Loss: 0.003840 	||	 Validation Loss: 0.002980
# Epoch: 295 	||	 Training Loss: 0.003837 	||	 Validation Loss: 0.002978
# Epoch: 296 	||	 Training Loss: 0.003835 	||	 Validation Loss: 0.002977
# Epoch: 297 	||	 Training Loss: 0.003833 	||	 Validation Loss: 0.002975
# Epoch: 298 	||	 Training Loss: 0.003831 	||	 Validation Loss: 0.002974
# Epoch: 299 	||	 Training Loss: 0.003829 	||	 Validation Loss: 0.002973
# Epoch: 300 	||	 Training Loss: 0.003827 	||	 Validation Loss: 0.002971
# Epoch: 301 	||	 Training Loss: 0.003825 	||	 Validation Loss: 0.002969
# Epoch: 302 	||	 Training Loss: 0.003823 	||	 Validation Loss: 0.002968
# Epoch: 303 	||	 Training Loss: 0.003820 	||	 Validation Loss: 0.002966
# Epoch: 304 	||	 Training Loss: 0.003818 	||	 Validation Loss: 0.002965
# Epoch: 305 	||	 Training Loss: 0.003816 	||	 Validation Loss: 0.002964
# Epoch: 306 	||	 Training Loss: 0.003814 	||	 Validation Loss: 0.002962
# Epoch: 307 	||	 Training Loss: 0.003812 	||	 Validation Loss: 0.002961
# Epoch: 308 	||	 Training Loss: 0.003810 	||	 Validation Loss: 0.002959
# Epoch: 309 	||	 Training Loss: 0.003808 	||	 Validation Loss: 0.002958
# Epoch: 310 	||	 Training Loss: 0.003806 	||	 Validation Loss: 0.002956
# Epoch: 311 	||	 Training Loss: 0.003804 	||	 Validation Loss: 0.002955
# Epoch: 312 	||	 Training Loss: 0.003802 	||	 Validation Loss: 0.002954
# Epoch: 313 	||	 Training Loss: 0.003800 	||	 Validation Loss: 0.002952
# Epoch: 314 	||	 Training Loss: 0.003798 	||	 Validation Loss: 0.002951
# Epoch: 315 	||	 Training Loss: 0.003796 	||	 Validation Loss: 0.002950
# Epoch: 316 	||	 Training Loss: 0.003794 	||	 Validation Loss: 0.002948
# Epoch: 317 	||	 Training Loss: 0.003791 	||	 Validation Loss: 0.002947
# Epoch: 318 	||	 Training Loss: 0.003789 	||	 Validation Loss: 0.002945
# Epoch: 319 	||	 Training Loss: 0.003787 	||	 Validation Loss: 0.002944
# Epoch: 320 	||	 Training Loss: 0.003785 	||	 Validation Loss: 0.002943
# Epoch: 321 	||	 Training Loss: 0.003783 	||	 Validation Loss: 0.002941
# Epoch: 322 	||	 Training Loss: 0.003781 	||	 Validation Loss: 0.002940
# Epoch: 323 	||	 Training Loss: 0.003779 	||	 Validation Loss: 0.002938
# Epoch: 324 	||	 Training Loss: 0.003777 	||	 Validation Loss: 0.002937
# Epoch: 325 	||	 Training Loss: 0.003775 	||	 Validation Loss: 0.002936
# Epoch: 326 	||	 Training Loss: 0.003773 	||	 Validation Loss: 0.002935
# Epoch: 327 	||	 Training Loss: 0.003771 	||	 Validation Loss: 0.002933
# Epoch: 328 	||	 Training Loss: 0.003769 	||	 Validation Loss: 0.002932
# Epoch: 329 	||	 Training Loss: 0.003767 	||	 Validation Loss: 0.002931
# Epoch: 330 	||	 Training Loss: 0.003765 	||	 Validation Loss: 0.002929
# Epoch: 331 	||	 Training Loss: 0.003763 	||	 Validation Loss: 0.002928
# Epoch: 332 	||	 Training Loss: 0.003761 	||	 Validation Loss: 0.002927
# Epoch: 333 	||	 Training Loss: 0.003759 	||	 Validation Loss: 0.002926
# Epoch: 334 	||	 Training Loss: 0.003758 	||	 Validation Loss: 0.002924
# Epoch: 335 	||	 Training Loss: 0.003756 	||	 Validation Loss: 0.002923
# Epoch: 336 	||	 Training Loss: 0.003754 	||	 Validation Loss: 0.002922
# Epoch: 337 	||	 Training Loss: 0.003752 	||	 Validation Loss: 0.002921
# Epoch: 338 	||	 Training Loss: 0.003750 	||	 Validation Loss: 0.002919
# Epoch: 339 	||	 Training Loss: 0.003748 	||	 Validation Loss: 0.002918
# Epoch: 340 	||	 Training Loss: 0.003746 	||	 Validation Loss: 0.002917
# Epoch: 341 	||	 Training Loss: 0.003744 	||	 Validation Loss: 0.002916
# Epoch: 342 	||	 Training Loss: 0.003742 	||	 Validation Loss: 0.002914
# Epoch: 343 	||	 Training Loss: 0.003740 	||	 Validation Loss: 0.002913
# Epoch: 344 	||	 Training Loss: 0.003738 	||	 Validation Loss: 0.002912
# Epoch: 345 	||	 Training Loss: 0.003736 	||	 Validation Loss: 0.002911
# Epoch: 346 	||	 Training Loss: 0.003734 	||	 Validation Loss: 0.002910
# Epoch: 347 	||	 Training Loss: 0.003732 	||	 Validation Loss: 0.002909
# Epoch: 348 	||	 Training Loss: 0.003731 	||	 Validation Loss: 0.002907
# Epoch: 349 	||	 Training Loss: 0.003729 	||	 Validation Loss: 0.002906
# Epoch: 350 	||	 Training Loss: 0.003727 	||	 Validation Loss: 0.002905
# Epoch: 351 	||	 Training Loss: 0.003725 	||	 Validation Loss: 0.002904
# Epoch: 352 	||	 Training Loss: 0.003723 	||	 Validation Loss: 0.002903
# Epoch: 353 	||	 Training Loss: 0.003721 	||	 Validation Loss: 0.002902
# Epoch: 354 	||	 Training Loss: 0.003719 	||	 Validation Loss: 0.002901
# Epoch: 355 	||	 Training Loss: 0.003717 	||	 Validation Loss: 0.002899
# Epoch: 356 	||	 Training Loss: 0.003716 	||	 Validation Loss: 0.002898
# Epoch: 357 	||	 Training Loss: 0.003714 	||	 Validation Loss: 0.002897
# Epoch: 358 	||	 Training Loss: 0.003712 	||	 Validation Loss: 0.002896
# Epoch: 359 	||	 Training Loss: 0.003710 	||	 Validation Loss: 0.002895
# Epoch: 360 	||	 Training Loss: 0.003708 	||	 Validation Loss: 0.002894
# Epoch: 361 	||	 Training Loss: 0.003706 	||	 Validation Loss: 0.002893
# Epoch: 362 	||	 Training Loss: 0.003705 	||	 Validation Loss: 0.002892
# Epoch: 363 	||	 Training Loss: 0.003703 	||	 Validation Loss: 0.002891
# Epoch: 364 	||	 Training Loss: 0.003701 	||	 Validation Loss: 0.002890
# Epoch: 365 	||	 Training Loss: 0.003699 	||	 Validation Loss: 0.002889
# Epoch: 366 	||	 Training Loss: 0.003697 	||	 Validation Loss: 0.002888
# Epoch: 367 	||	 Training Loss: 0.003696 	||	 Validation Loss: 0.002887
# Epoch: 368 	||	 Training Loss: 0.003694 	||	 Validation Loss: 0.002886
# Epoch: 369 	||	 Training Loss: 0.003692 	||	 Validation Loss: 0.002885
# Epoch: 370 	||	 Training Loss: 0.003690 	||	 Validation Loss: 0.002884
# Epoch: 371 	||	 Training Loss: 0.003688 	||	 Validation Loss: 0.002883
# Epoch: 372 	||	 Training Loss: 0.003687 	||	 Validation Loss: 0.002882
# Epoch: 373 	||	 Training Loss: 0.003685 	||	 Validation Loss: 0.002881
# Epoch: 374 	||	 Training Loss: 0.003683 	||	 Validation Loss: 0.002880
# Epoch: 375 	||	 Training Loss: 0.003681 	||	 Validation Loss: 0.002879
# Epoch: 376 	||	 Training Loss: 0.003680 	||	 Validation Loss: 0.002878
# Epoch: 377 	||	 Training Loss: 0.003678 	||	 Validation Loss: 0.002877
# Epoch: 378 	||	 Training Loss: 0.003676 	||	 Validation Loss: 0.002876
# Epoch: 379 	||	 Training Loss: 0.003674 	||	 Validation Loss: 0.002875
# Epoch: 380 	||	 Training Loss: 0.003673 	||	 Validation Loss: 0.002875
# Epoch: 381 	||	 Training Loss: 0.003671 	||	 Validation Loss: 0.002874
# Epoch: 382 	||	 Training Loss: 0.003669 	||	 Validation Loss: 0.002873
# Epoch: 383 	||	 Training Loss: 0.003668 	||	 Validation Loss: 0.002872
# Epoch: 384 	||	 Training Loss: 0.003666 	||	 Validation Loss: 0.002871
# Epoch: 385 	||	 Training Loss: 0.003664 	||	 Validation Loss: 0.002870
# Epoch: 386 	||	 Training Loss: 0.003663 	||	 Validation Loss: 0.002869
# Epoch: 387 	||	 Training Loss: 0.003661 	||	 Validation Loss: 0.002868
# Epoch: 388 	||	 Training Loss: 0.003659 	||	 Validation Loss: 0.002867
# Epoch: 389 	||	 Training Loss: 0.003658 	||	 Validation Loss: 0.002867
# Epoch: 390 	||	 Training Loss: 0.003656 	||	 Validation Loss: 0.002866
# Epoch: 391 	||	 Training Loss: 0.003654 	||	 Validation Loss: 0.002865
# Epoch: 392 	||	 Training Loss: 0.003653 	||	 Validation Loss: 0.002864
# Epoch: 393 	||	 Training Loss: 0.003651 	||	 Validation Loss: 0.002863
# Epoch: 394 	||	 Training Loss: 0.003649 	||	 Validation Loss: 0.002863
# Epoch: 395 	||	 Training Loss: 0.003648 	||	 Validation Loss: 0.002862
# Epoch: 396 	||	 Training Loss: 0.003646 	||	 Validation Loss: 0.002861
# Epoch: 397 	||	 Training Loss: 0.003644 	||	 Validation Loss: 0.002860
# Epoch: 398 	||	 Training Loss: 0.003643 	||	 Validation Loss: 0.002859
# Epoch: 399 	||	 Training Loss: 0.003641 	||	 Validation Loss: 0.002859
# Epoch: 400 	||	 Training Loss: 0.003640 	||	 Validation Loss: 0.002858
# Epoch: 401 	||	 Training Loss: 0.003638 	||	 Validation Loss: 0.002857
# Epoch: 402 	||	 Training Loss: 0.003636 	||	 Validation Loss: 0.002856
# Epoch: 403 	||	 Training Loss: 0.003635 	||	 Validation Loss: 0.002856
# Epoch: 404 	||	 Training Loss: 0.003633 	||	 Validation Loss: 0.002855
# Epoch: 405 	||	 Training Loss: 0.003632 	||	 Validation Loss: 0.002854
# Epoch: 406 	||	 Training Loss: 0.003630 	||	 Validation Loss: 0.002854
# Epoch: 407 	||	 Training Loss: 0.003628 	||	 Validation Loss: 0.002853
# Epoch: 408 	||	 Training Loss: 0.003627 	||	 Validation Loss: 0.002852
# Epoch: 409 	||	 Training Loss: 0.003625 	||	 Validation Loss: 0.002852
# Epoch: 410 	||	 Training Loss: 0.003624 	||	 Validation Loss: 0.002851
# Epoch: 411 	||	 Training Loss: 0.003622 	||	 Validation Loss: 0.002850
# Epoch: 412 	||	 Training Loss: 0.003621 	||	 Validation Loss: 0.002850
# Epoch: 413 	||	 Training Loss: 0.003619 	||	 Validation Loss: 0.002849
# Epoch: 414 	||	 Training Loss: 0.003618 	||	 Validation Loss: 0.002848
# Epoch: 415 	||	 Training Loss: 0.003616 	||	 Validation Loss: 0.002848
# Epoch: 416 	||	 Training Loss: 0.003614 	||	 Validation Loss: 0.002847
# Epoch: 417 	||	 Training Loss: 0.003613 	||	 Validation Loss: 0.002846
# Epoch: 418 	||	 Training Loss: 0.003611 	||	 Validation Loss: 0.002846
# Epoch: 419 	||	 Training Loss: 0.003610 	||	 Validation Loss: 0.002845
# Epoch: 420 	||	 Training Loss: 0.003608 	||	 Validation Loss: 0.002844
# Epoch: 421 	||	 Training Loss: 0.003607 	||	 Validation Loss: 0.002844
# Epoch: 422 	||	 Training Loss: 0.003605 	||	 Validation Loss: 0.002843
# Epoch: 423 	||	 Training Loss: 0.003604 	||	 Validation Loss: 0.002842
# Epoch: 424 	||	 Training Loss: 0.003602 	||	 Validation Loss: 0.002842
# Epoch: 425 	||	 Training Loss: 0.003601 	||	 Validation Loss: 0.002841
# Epoch: 426 	||	 Training Loss: 0.003599 	||	 Validation Loss: 0.002841
# Epoch: 427 	||	 Training Loss: 0.003598 	||	 Validation Loss: 0.002840
# Epoch: 428 	||	 Training Loss: 0.003596 	||	 Validation Loss: 0.002840
# Epoch: 429 	||	 Training Loss: 0.003595 	||	 Validation Loss: 0.002839
# Epoch: 430 	||	 Training Loss: 0.003594 	||	 Validation Loss: 0.002838
# Epoch: 431 	||	 Training Loss: 0.003592 	||	 Validation Loss: 0.002838
# Epoch: 432 	||	 Training Loss: 0.003591 	||	 Validation Loss: 0.002837
# Epoch: 433 	||	 Training Loss: 0.003589 	||	 Validation Loss: 0.002837
# Epoch: 434 	||	 Training Loss: 0.003588 	||	 Validation Loss: 0.002836
# Epoch: 435 	||	 Training Loss: 0.003586 	||	 Validation Loss: 0.002836
# Epoch: 436 	||	 Training Loss: 0.003585 	||	 Validation Loss: 0.002835
# Epoch: 437 	||	 Training Loss: 0.003583 	||	 Validation Loss: 0.002834
# Epoch: 438 	||	 Training Loss: 0.003582 	||	 Validation Loss: 0.002834
# Epoch: 439 	||	 Training Loss: 0.003580 	||	 Validation Loss: 0.002833
# Epoch: 440 	||	 Training Loss: 0.003579 	||	 Validation Loss: 0.002833
# Epoch: 441 	||	 Training Loss: 0.003578 	||	 Validation Loss: 0.002832
# Epoch: 442 	||	 Training Loss: 0.003576 	||	 Validation Loss: 0.002832
# Epoch: 443 	||	 Training Loss: 0.003575 	||	 Validation Loss: 0.002831
# Epoch: 444 	||	 Training Loss: 0.003573 	||	 Validation Loss: 0.002830
# Epoch: 445 	||	 Training Loss: 0.003572 	||	 Validation Loss: 0.002830
# Epoch: 446 	||	 Training Loss: 0.003571 	||	 Validation Loss: 0.002830
# Epoch: 447 	||	 Training Loss: 0.003569 	||	 Validation Loss: 0.002829
# Epoch: 448 	||	 Training Loss: 0.003568 	||	 Validation Loss: 0.002828
# Epoch: 449 	||	 Training Loss: 0.003566 	||	 Validation Loss: 0.002828
# Epoch: 450 	||	 Training Loss: 0.003565 	||	 Validation Loss: 0.002827
# Epoch: 451 	||	 Training Loss: 0.003564 	||	 Validation Loss: 0.002827
# Epoch: 452 	||	 Training Loss: 0.003562 	||	 Validation Loss: 0.002826
# Epoch: 453 	||	 Training Loss: 0.003561 	||	 Validation Loss: 0.002826
# Epoch: 454 	||	 Training Loss: 0.003560 	||	 Validation Loss: 0.002826
# Epoch: 455 	||	 Training Loss: 0.003558 	||	 Validation Loss: 0.002825
# Epoch: 456 	||	 Training Loss: 0.003557 	||	 Validation Loss: 0.002824
# Epoch: 457 	||	 Training Loss: 0.003555 	||	 Validation Loss: 0.002824
# Epoch: 458 	||	 Training Loss: 0.003554 	||	 Validation Loss: 0.002823
# Epoch: 459 	||	 Training Loss: 0.003553 	||	 Validation Loss: 0.002823
# Epoch: 460 	||	 Training Loss: 0.003551 	||	 Validation Loss: 0.002822
# Epoch: 461 	||	 Training Loss: 0.003550 	||	 Validation Loss: 0.002822
# Epoch: 462 	||	 Training Loss: 0.003549 	||	 Validation Loss: 0.002821
# Epoch: 463 	||	 Training Loss: 0.003547 	||	 Validation Loss: 0.002821
# Epoch: 464 	||	 Training Loss: 0.003546 	||	 Validation Loss: 0.002821
# Epoch: 465 	||	 Training Loss: 0.003545 	||	 Validation Loss: 0.002820
# Epoch: 466 	||	 Training Loss: 0.003543 	||	 Validation Loss: 0.002820
# Epoch: 467 	||	 Training Loss: 0.003542 	||	 Validation Loss: 0.002819
# Epoch: 468 	||	 Training Loss: 0.003541 	||	 Validation Loss: 0.002819
# Epoch: 469 	||	 Training Loss: 0.003539 	||	 Validation Loss: 0.002818
# Epoch: 470 	||	 Training Loss: 0.003538 	||	 Validation Loss: 0.002818
# Epoch: 471 	||	 Training Loss: 0.003537 	||	 Validation Loss: 0.002818
# Epoch: 472 	||	 Training Loss: 0.003535 	||	 Validation Loss: 0.002817
# Epoch: 473 	||	 Training Loss: 0.003534 	||	 Validation Loss: 0.002817
# Epoch: 474 	||	 Training Loss: 0.003533 	||	 Validation Loss: 0.002816
# Epoch: 475 	||	 Training Loss: 0.003531 	||	 Validation Loss: 0.002816
# Epoch: 476 	||	 Training Loss: 0.003530 	||	 Validation Loss: 0.002816
# Epoch: 477 	||	 Training Loss: 0.003529 	||	 Validation Loss: 0.002815
# Epoch: 478 	||	 Training Loss: 0.003527 	||	 Validation Loss: 0.002815
# Epoch: 479 	||	 Training Loss: 0.003526 	||	 Validation Loss: 0.002814
# Epoch: 480 	||	 Training Loss: 0.003525 	||	 Validation Loss: 0.002814
# Epoch: 481 	||	 Training Loss: 0.003524 	||	 Validation Loss: 0.002814
# Epoch: 482 	||	 Training Loss: 0.003522 	||	 Validation Loss: 0.002813
# Epoch: 483 	||	 Training Loss: 0.003521 	||	 Validation Loss: 0.002813
# Epoch: 484 	||	 Training Loss: 0.003520 	||	 Validation Loss: 0.002812
# Epoch: 485 	||	 Training Loss: 0.003519 	||	 Validation Loss: 0.002812
# Epoch: 486 	||	 Training Loss: 0.003517 	||	 Validation Loss: 0.002812
# Epoch: 487 	||	 Training Loss: 0.003516 	||	 Validation Loss: 0.002811
# Epoch: 488 	||	 Training Loss: 0.003515 	||	 Validation Loss: 0.002811
# Epoch: 489 	||	 Training Loss: 0.003513 	||	 Validation Loss: 0.002811
# Epoch: 490 	||	 Training Loss: 0.003512 	||	 Validation Loss: 0.002810
# Epoch: 491 	||	 Training Loss: 0.003511 	||	 Validation Loss: 0.002810
# Epoch: 492 	||	 Training Loss: 0.003510 	||	 Validation Loss: 0.002810
# Epoch: 493 	||	 Training Loss: 0.003508 	||	 Validation Loss: 0.002809
# Epoch: 494 	||	 Training Loss: 0.003507 	||	 Validation Loss: 0.002809
# Epoch: 495 	||	 Training Loss: 0.003506 	||	 Validation Loss: 0.002809
# Epoch: 496 	||	 Training Loss: 0.003505 	||	 Validation Loss: 0.002808
# Epoch: 497 	||	 Training Loss: 0.003503 	||	 Validation Loss: 0.002808
# Epoch: 498 	||	 Training Loss: 0.003502 	||	 Validation Loss: 0.002808
# Epoch: 499 	||	 Training Loss: 0.003501 	||	 Validation Loss: 0.002807
# Epoch: 500 	||	 Training Loss: 0.003500 	||	 Validation Loss: 0.002807
# Epoch: 501 	||	 Training Loss: 0.003499 	||	 Validation Loss: 0.002807
# Epoch: 502 	||	 Training Loss: 0.003497 	||	 Validation Loss: 0.002806
# Epoch: 503 	||	 Training Loss: 0.003496 	||	 Validation Loss: 0.002806
# Epoch: 504 	||	 Training Loss: 0.003495 	||	 Validation Loss: 0.002806
# Epoch: 505 	||	 Training Loss: 0.003494 	||	 Validation Loss: 0.002806
# Epoch: 506 	||	 Training Loss: 0.003493 	||	 Validation Loss: 0.002805
# Epoch: 507 	||	 Training Loss: 0.003491 	||	 Validation Loss: 0.002805
# Epoch: 508 	||	 Training Loss: 0.003490 	||	 Validation Loss: 0.002805
# Epoch: 509 	||	 Training Loss: 0.003489 	||	 Validation Loss: 0.002805
# Epoch: 510 	||	 Training Loss: 0.003488 	||	 Validation Loss: 0.002804
# Epoch: 511 	||	 Training Loss: 0.003487 	||	 Validation Loss: 0.002804
# Epoch: 512 	||	 Training Loss: 0.003485 	||	 Validation Loss: 0.002804
# Epoch: 513 	||	 Training Loss: 0.003484 	||	 Validation Loss: 0.002804
# Epoch: 514 	||	 Training Loss: 0.003483 	||	 Validation Loss: 0.002803
# Epoch: 515 	||	 Training Loss: 0.003482 	||	 Validation Loss: 0.002803
# Epoch: 516 	||	 Training Loss: 0.003481 	||	 Validation Loss: 0.002803
# Epoch: 517 	||	 Training Loss: 0.003479 	||	 Validation Loss: 0.002803
# Epoch: 518 	||	 Training Loss: 0.003478 	||	 Validation Loss: 0.002803
# Epoch: 519 	||	 Training Loss: 0.003477 	||	 Validation Loss: 0.002802
# Epoch: 520 	||	 Training Loss: 0.003476 	||	 Validation Loss: 0.002802
# Epoch: 521 	||	 Training Loss: 0.003475 	||	 Validation Loss: 0.002802
# Epoch: 522 	||	 Training Loss: 0.003474 	||	 Validation Loss: 0.002801
# Epoch: 523 	||	 Training Loss: 0.003472 	||	 Validation Loss: 0.002802
# Epoch: 524 	||	 Training Loss: 0.003471 	||	 Validation Loss: 0.002801
# Epoch: 525 	||	 Training Loss: 0.003470 	||	 Validation Loss: 0.002801
# Epoch: 526 	||	 Training Loss: 0.003469 	||	 Validation Loss: 0.002801
# Epoch: 527 	||	 Training Loss: 0.003468 	||	 Validation Loss: 0.002801
# Epoch: 528 	||	 Training Loss: 0.003467 	||	 Validation Loss: 0.002800
# Epoch: 529 	||	 Training Loss: 0.003466 	||	 Validation Loss: 0.002800
# Epoch: 530 	||	 Training Loss: 0.003464 	||	 Validation Loss: 0.002800
# Epoch: 531 	||	 Training Loss: 0.003463 	||	 Validation Loss: 0.002800
# Epoch: 532 	||	 Training Loss: 0.003462 	||	 Validation Loss: 0.002800
# Epoch: 533 	||	 Training Loss: 0.003461 	||	 Validation Loss: 0.002800
# Epoch: 534 	||	 Training Loss: 0.003460 	||	 Validation Loss: 0.002800
# Epoch: 535 	||	 Training Loss: 0.003459 	||	 Validation Loss: 0.002799
# Epoch: 536 	||	 Training Loss: 0.003458 	||	 Validation Loss: 0.002799
# Epoch: 537 	||	 Training Loss: 0.003457 	||	 Validation Loss: 0.002799
# Epoch: 538 	||	 Training Loss: 0.003455 	||	 Validation Loss: 0.002799
# Epoch: 539 	||	 Training Loss: 0.003454 	||	 Validation Loss: 0.002799
# Epoch: 540 	||	 Training Loss: 0.003453 	||	 Validation Loss: 0.002799
# Epoch: 541 	||	 Training Loss: 0.003452 	||	 Validation Loss: 0.002798
# Epoch: 542 	||	 Training Loss: 0.003451 	||	 Validation Loss: 0.002798
# Epoch: 543 	||	 Training Loss: 0.003450 	||	 Validation Loss: 0.002798
# Epoch: 544 	||	 Training Loss: 0.003449 	||	 Validation Loss: 0.002798
# Epoch: 545 	||	 Training Loss: 0.003448 	||	 Validation Loss: 0.002798
# Epoch: 546 	||	 Training Loss: 0.003447 	||	 Validation Loss: 0.002798
# Epoch: 547 	||	 Training Loss: 0.003445 	||	 Validation Loss: 0.002798
# Epoch: 548 	||	 Training Loss: 0.003444 	||	 Validation Loss: 0.002798
# Epoch: 549 	||	 Training Loss: 0.003443 	||	 Validation Loss: 0.002798
# Epoch: 550 	||	 Training Loss: 0.003442 	||	 Validation Loss: 0.002798
# Epoch: 551 	||	 Training Loss: 0.003441 	||	 Validation Loss: 0.002797
# Epoch: 552 	||	 Training Loss: 0.003440 	||	 Validation Loss: 0.002797
# Epoch: 553 	||	 Training Loss: 0.003439 	||	 Validation Loss: 0.002798
# Epoch: 554 	||	 Training Loss: 0.003438 	||	 Validation Loss: 0.002797
# Epoch: 555 	||	 Training Loss: 0.003437 	||	 Validation Loss: 0.002797
# Epoch: 556 	||	 Training Loss: 0.003436 	||	 Validation Loss: 0.002797
# Epoch: 557 	||	 Training Loss: 0.003435 	||	 Validation Loss: 0.002797
# Epoch: 558 	||	 Training Loss: 0.003434 	||	 Validation Loss: 0.002797
# Epoch: 559 	||	 Training Loss: 0.003433 	||	 Validation Loss: 0.002797
# Epoch: 560 	||	 Training Loss: 0.003432 	||	 Validation Loss: 0.002797
# Epoch: 561 	||	 Training Loss: 0.003431 	||	 Validation Loss: 0.002797
# Epoch: 562 	||	 Training Loss: 0.003430 	||	 Validation Loss: 0.002797
# Epoch: 563 	||	 Training Loss: 0.003428 	||	 Validation Loss: 0.002797
# Epoch: 564 	||	 Training Loss: 0.003427 	||	 Validation Loss: 0.002797
# Epoch: 565 	||	 Training Loss: 0.003426 	||	 Validation Loss: 0.002797
# Epoch: 566 	||	 Training Loss: 0.003425 	||	 Validation Loss: 0.002797
# Epoch: 567 	||	 Training Loss: 0.003424 	||	 Validation Loss: 0.002797
# Epoch: 568 	||	 Training Loss: 0.003423 	||	 Validation Loss: 0.002797
# Epoch: 569 	||	 Training Loss: 0.003422 	||	 Validation Loss: 0.002797
# Epoch: 570 	||	 Training Loss: 0.003421 	||	 Validation Loss: 0.002797
# Epoch: 571 	||	 Training Loss: 0.003420 	||	 Validation Loss: 0.002797
# Epoch: 572 	||	 Training Loss: 0.003419 	||	 Validation Loss: 0.002797
# Epoch: 573 	||	 Training Loss: 0.003418 	||	 Validation Loss: 0.002797
# Epoch: 574 	||	 Training Loss: 0.003417 	||	 Validation Loss: 0.002796
# Epoch: 575 	||	 Training Loss: 0.003416 	||	 Validation Loss: 0.002796
# Epoch: 576 	||	 Training Loss: 0.003415 	||	 Validation Loss: 0.002797
# Epoch: 577 	||	 Training Loss: 0.003414 	||	 Validation Loss: 0.002797
# Epoch: 578 	||	 Training Loss: 0.003413 	||	 Validation Loss: 0.002797
# Epoch: 579 	||	 Training Loss: 0.003412 	||	 Validation Loss: 0.002797
# Epoch: 580 	||	 Training Loss: 0.003411 	||	 Validation Loss: 0.002797
# Epoch: 581 	||	 Training Loss: 0.003410 	||	 Validation Loss: 0.002797
# Epoch: 582 	||	 Training Loss: 0.003409 	||	 Validation Loss: 0.002797
# Epoch: 583 	||	 Training Loss: 0.003408 	||	 Validation Loss: 0.002797
# Epoch: 584 	||	 Training Loss: 0.003407 	||	 Validation Loss: 0.002797
# Epoch: 585 	||	 Training Loss: 0.003406 	||	 Validation Loss: 0.002797
# Epoch: 586 	||	 Training Loss: 0.003405 	||	 Validation Loss: 0.002797
# Epoch: 587 	||	 Training Loss: 0.003404 	||	 Validation Loss: 0.002797
# Epoch: 588 	||	 Training Loss: 0.003403 	||	 Validation Loss: 0.002797
# Epoch: 589 	||	 Training Loss: 0.003402 	||	 Validation Loss: 0.002797
# Epoch: 590 	||	 Training Loss: 0.003401 	||	 Validation Loss: 0.002797
# Epoch: 591 	||	 Training Loss: 0.003400 	||	 Validation Loss: 0.002797
# Epoch: 592 	||	 Training Loss: 0.003399 	||	 Validation Loss: 0.002797
# Epoch: 593 	||	 Training Loss: 0.003398 	||	 Validation Loss: 0.002797
# Epoch: 594 	||	 Training Loss: 0.003397 	||	 Validation Loss: 0.002797
# Epoch: 595 	||	 Training Loss: 0.003397 	||	 Validation Loss: 0.002797
# Epoch: 596 	||	 Training Loss: 0.003396 	||	 Validation Loss: 0.002797
# Epoch: 597 	||	 Training Loss: 0.003395 	||	 Validation Loss: 0.002797
# Epoch: 598 	||	 Training Loss: 0.003394 	||	 Validation Loss: 0.002797
# Epoch: 599 	||	 Training Loss: 0.003393 	||	 Validation Loss: 0.002798
# Epoch: 600 	||	 Training Loss: 0.003392 	||	 Validation Loss: 0.002798
# Epoch: 601 	||	 Training Loss: 0.003391 	||	 Validation Loss: 0.002798
# Epoch: 602 	||	 Training Loss: 0.003390 	||	 Validation Loss: 0.002798
# Epoch: 603 	||	 Training Loss: 0.003389 	||	 Validation Loss: 0.002798
# Epoch: 604 	||	 Training Loss: 0.003388 	||	 Validation Loss: 0.002798
# Epoch: 605 	||	 Training Loss: 0.003387 	||	 Validation Loss: 0.002798
# Epoch: 606 	||	 Training Loss: 0.003386 	||	 Validation Loss: 0.002798
# Epoch: 607 	||	 Training Loss: 0.003385 	||	 Validation Loss: 0.002798
# Epoch: 608 	||	 Training Loss: 0.003384 	||	 Validation Loss: 0.002799
# Epoch: 609 	||	 Training Loss: 0.003383 	||	 Validation Loss: 0.002798
# Epoch: 610 	||	 Training Loss: 0.003383 	||	 Validation Loss: 0.002799
# Epoch: 611 	||	 Training Loss: 0.003382 	||	 Validation Loss: 0.002799
# Epoch: 612 	||	 Training Loss: 0.003381 	||	 Validation Loss: 0.002799
# Epoch: 613 	||	 Training Loss: 0.003380 	||	 Validation Loss: 0.002799
# Epoch: 614 	||	 Training Loss: 0.003379 	||	 Validation Loss: 0.002799
# Epoch: 615 	||	 Training Loss: 0.003378 	||	 Validation Loss: 0.002799
# Epoch: 616 	||	 Training Loss: 0.003377 	||	 Validation Loss: 0.002799
# Epoch: 617 	||	 Training Loss: 0.003376 	||	 Validation Loss: 0.002799
# Epoch: 618 	||	 Training Loss: 0.003375 	||	 Validation Loss: 0.002800
# Epoch: 619 	||	 Training Loss: 0.003374 	||	 Validation Loss: 0.002800
# Epoch: 620 	||	 Training Loss: 0.003374 	||	 Validation Loss: 0.002800
# Epoch: 621 	||	 Training Loss: 0.003373 	||	 Validation Loss: 0.002800
# Epoch: 622 	||	 Training Loss: 0.003372 	||	 Validation Loss: 0.002800
# Epoch: 623 	||	 Training Loss: 0.003371 	||	 Validation Loss: 0.002800
# Epoch: 624 	||	 Training Loss: 0.003370 	||	 Validation Loss: 0.002800
# Epoch: 625 	||	 Training Loss: 0.003369 	||	 Validation Loss: 0.002800
# Epoch: 626 	||	 Training Loss: 0.003368 	||	 Validation Loss: 0.002801
# Epoch: 627 	||	 Training Loss: 0.003367 	||	 Validation Loss: 0.002801
# Epoch: 628 	||	 Training Loss: 0.003366 	||	 Validation Loss: 0.002801
# Epoch: 629 	||	 Training Loss: 0.003366 	||	 Validation Loss: 0.002801
# Epoch: 630 	||	 Training Loss: 0.003365 	||	 Validation Loss: 0.002801
# Epoch: 631 	||	 Training Loss: 0.003364 	||	 Validation Loss: 0.002801
# Epoch: 632 	||	 Training Loss: 0.003363 	||	 Validation Loss: 0.002802
# Epoch: 633 	||	 Training Loss: 0.003362 	||	 Validation Loss: 0.002802
# Epoch: 634 	||	 Training Loss: 0.003361 	||	 Validation Loss: 0.002802
# Epoch: 635 	||	 Training Loss: 0.003360 	||	 Validation Loss: 0.002802
# Epoch: 636 	||	 Training Loss: 0.003360 	||	 Validation Loss: 0.002802
# Epoch: 637 	||	 Training Loss: 0.003359 	||	 Validation Loss: 0.002802
# Epoch: 638 	||	 Training Loss: 0.003358 	||	 Validation Loss: 0.002802
# Epoch: 639 	||	 Training Loss: 0.003357 	||	 Validation Loss: 0.002802
# Epoch: 640 	||	 Training Loss: 0.003356 	||	 Validation Loss: 0.002803
# Epoch: 641 	||	 Training Loss: 0.003355 	||	 Validation Loss: 0.002803
# Epoch: 642 	||	 Training Loss: 0.003355 	||	 Validation Loss: 0.002803
# Epoch: 643 	||	 Training Loss: 0.003354 	||	 Validation Loss: 0.002803
# Epoch: 644 	||	 Training Loss: 0.003353 	||	 Validation Loss: 0.002803
# Epoch: 645 	||	 Training Loss: 0.003352 	||	 Validation Loss: 0.002804
# Epoch: 646 	||	 Training Loss: 0.003351 	||	 Validation Loss: 0.002804
# Epoch: 647 	||	 Training Loss: 0.003350 	||	 Validation Loss: 0.002804
# Epoch: 648 	||	 Training Loss: 0.003350 	||	 Validation Loss: 0.002804
# Epoch: 649 	||	 Training Loss: 0.003349 	||	 Validation Loss: 0.002804
# Epoch: 650 	||	 Training Loss: 0.003348 	||	 Validation Loss: 0.002804
# Epoch: 651 	||	 Training Loss: 0.003347 	||	 Validation Loss: 0.002805
# Epoch: 652 	||	 Training Loss: 0.003346 	||	 Validation Loss: 0.002805
# Epoch: 653 	||	 Training Loss: 0.003345 	||	 Validation Loss: 0.002805
# Epoch: 654 	||	 Training Loss: 0.003345 	||	 Validation Loss: 0.002805
# Epoch: 655 	||	 Training Loss: 0.003344 	||	 Validation Loss: 0.002805
# Epoch: 656 	||	 Training Loss: 0.003343 	||	 Validation Loss: 0.002805
# Epoch: 657 	||	 Training Loss: 0.003342 	||	 Validation Loss: 0.002806
# Epoch: 658 	||	 Training Loss: 0.003341 	||	 Validation Loss: 0.002806
# Epoch: 659 	||	 Training Loss: 0.003341 	||	 Validation Loss: 0.002806
# Epoch: 660 	||	 Training Loss: 0.003340 	||	 Validation Loss: 0.002806
# Epoch: 661 	||	 Training Loss: 0.003339 	||	 Validation Loss: 0.002806
# Epoch: 662 	||	 Training Loss: 0.003338 	||	 Validation Loss: 0.002806
# Epoch: 663 	||	 Training Loss: 0.003337 	||	 Validation Loss: 0.002807
# Epoch: 664 	||	 Training Loss: 0.003337 	||	 Validation Loss: 0.002807
# Epoch: 665 	||	 Training Loss: 0.003336 	||	 Validation Loss: 0.002807
# Epoch: 666 	||	 Training Loss: 0.003335 	||	 Validation Loss: 0.002807
# Epoch: 667 	||	 Training Loss: 0.003334 	||	 Validation Loss: 0.002807
# Epoch: 668 	||	 Training Loss: 0.003334 	||	 Validation Loss: 0.002808
# Epoch: 669 	||	 Training Loss: 0.003333 	||	 Validation Loss: 0.002808
# Epoch: 670 	||	 Training Loss: 0.003332 	||	 Validation Loss: 0.002808
# Epoch: 671 	||	 Training Loss: 0.003331 	||	 Validation Loss: 0.002808
# Epoch: 672 	||	 Training Loss: 0.003330 	||	 Validation Loss: 0.002808
# Epoch: 673 	||	 Training Loss: 0.003330 	||	 Validation Loss: 0.002809
# Epoch: 674 	||	 Training Loss: 0.003329 	||	 Validation Loss: 0.002809
# Epoch: 675 	||	 Training Loss: 0.003328 	||	 Validation Loss: 0.002809
# Epoch: 676 	||	 Training Loss: 0.003327 	||	 Validation Loss: 0.002809
# Epoch: 677 	||	 Training Loss: 0.003327 	||	 Validation Loss: 0.002809
# Epoch: 678 	||	 Training Loss: 0.003326 	||	 Validation Loss: 0.002809
# Epoch: 679 	||	 Training Loss: 0.003325 	||	 Validation Loss: 0.002810
# Epoch: 680 	||	 Training Loss: 0.003324 	||	 Validation Loss: 0.002810
# Epoch: 681 	||	 Training Loss: 0.003324 	||	 Validation Loss: 0.002810
# Epoch: 682 	||	 Training Loss: 0.003323 	||	 Validation Loss: 0.002810
# Epoch: 683 	||	 Training Loss: 0.003322 	||	 Validation Loss: 0.002810
# Epoch: 684 	||	 Training Loss: 0.003321 	||	 Validation Loss: 0.002811
# Epoch: 685 	||	 Training Loss: 0.003321 	||	 Validation Loss: 0.002811
# Epoch: 686 	||	 Training Loss: 0.003320 	||	 Validation Loss: 0.002811
# Epoch: 687 	||	 Training Loss: 0.003319 	||	 Validation Loss: 0.002811
# Epoch: 688 	||	 Training Loss: 0.003318 	||	 Validation Loss: 0.002811
# Epoch: 689 	||	 Training Loss: 0.003318 	||	 Validation Loss: 0.002812
# Epoch: 690 	||	 Training Loss: 0.003317 	||	 Validation Loss: 0.002812
# Epoch: 691 	||	 Training Loss: 0.003316 	||	 Validation Loss: 0.002812
# Epoch: 692 	||	 Training Loss: 0.003315 	||	 Validation Loss: 0.002812
# Epoch: 693 	||	 Training Loss: 0.003315 	||	 Validation Loss: 0.002812
# Epoch: 694 	||	 Training Loss: 0.003314 	||	 Validation Loss: 0.002812
# Epoch: 695 	||	 Training Loss: 0.003313 	||	 Validation Loss: 0.002813
# Epoch: 696 	||	 Training Loss: 0.003312 	||	 Validation Loss: 0.002813
# Epoch: 697 	||	 Training Loss: 0.003312 	||	 Validation Loss: 0.002813
# Epoch: 698 	||	 Training Loss: 0.003311 	||	 Validation Loss: 0.002813
# Epoch: 699 	||	 Training Loss: 0.003310 	||	 Validation Loss: 0.002813
# Epoch: 700 	||	 Training Loss: 0.003310 	||	 Validation Loss: 0.002814

# %% [markdown]
# #### test 101 M

# %%
# --------------Plot identification results for G-----------------

patient_model_folder_101_M = "./models/101_M"
MODEL_PATH = Path(patient_model_folder_101_M)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])

# ----------------------------------

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs'); plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs  101 M')
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()


y0_0 = fun_start_controller_simple(train_loader_p_101_M, dataset_101_M)
y0_0 = torch.zeros_like(y0_0)
REN_0_101 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

#########################################################

y0_0 = fun_start_controller_simple(test_loader_101_M, dataset_101_M)
# y0_0 = torch.zeros_like(y0_0)
REN_0_101.reset(y0 = -y0_0.unsqueeze(1))


checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")
REN_0_101.load_state_dict(checkpoint["REN_0_101_state_dict"])

#################################################################

for u0_batch, _, y_batch, time_batch in train_loader_p_101_M:

    u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)
    
    REN_0_101.reset(y0 = y_batch[:,:1,:1])

    y0_hat = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1])
    y_hat = y0_hat
    
    loss_train = MSE(y_hat, y_batch)

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

print(f"Loss train: {loss_train}")

fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Meal (u0)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u0_batch[0,:,0].numpy(), color=color, label='Meal')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Meal vs Time, Train')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()



#####################################################################################


for u0_batch, _, y_batch, time_batch in test_loader_101_M:

    u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)

    REN_0_101.reset(y0 = y_batch[:,:1,:1])
    y0_hat = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1])
    y_hat = y0_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()


fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Meal (u1)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u0_batch[0,:,0].numpy(), color=color, label='Meal')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Meal vs Time, Test')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_16520\1830596232.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# Loss train: 0.0033088047057390213

# %% [markdown]
# # 1 System identification of G

# %% [markdown]
# ### REN model, loss function and optimizer parallel

# %%
#--------------------------3. Define model for sysid---------------------------------------------


device = torch.device(device if torch.cuda.is_available() else "cpu")

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

# meal   M 
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

# insulin  I_sat
REN_1 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

REN_0 = REN_0.to(device)
REN_1 = REN_1.to(device)

#create the closed loop with the identified model
# closed_loop_G = ClosedLoopSystem(REN_G, controller)

#--------------------------4. Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()

optimizer = torch.optim.Adam( list(REN_0.parameters()) + list(REN_1.parameters()),   lr=learning_rate)
optimizer.zero_grad()

# %% [markdown]
# ### Training and validation loop parallel

# %%
#--------------------------5. Training---------------------------------------------------------------------

torch.set_default_device(device)      # default tensor device
torch.set_default_dtype(torch.float32)  # default tensor dtype
print(f"[INFO] Training on device: {device}")

REN_0.to(device); REN_1.to(device)
train_losses = []
val_losses = []  # Store validation losses across epochs
for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_0.train(); REN_1.train()
    loss_epoch = 0.0  # Accumulate training loss

    
    for u0_batch, _, _, u1_batch, y_batch, _ in train_loader_p: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time

        
        u0_batch, u1_batch, y_batch= ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch) 
        # batch_size, time_horizon, input_dim
        u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)
        
        optimizer.zero_grad()
        REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1])); 
        REN_1.reset(y0 = - y_batch[:,:1,:1])

        # y_init_per_batch      torch.zeros_like(y_batch[:,:1])    y_batch[:,:1]
        y0_hat_train = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
        y1_hat_train = REN_1(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
        y_hat_train = y0_hat_train - y1_hat_train 
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        optimizer.step()
        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_0.eval(); REN_1.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, _, u1_batch, y_batch, _ in val_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time

            u0_batch, u1_batch, y_batch= ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)
            u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)
            
            REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1]))
            REN_1.reset(y0 = - y_batch[:,:1,:1])

            y0_hat_val = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
            y1_hat_val = REN_1(u1_batch, y0 = - y_batch[:,:1,:1])# select the correct U
            y_hat_val = y0_hat_val - y1_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        candidate_REN_0 = REN_0
        candidate_REN_1 = REN_1

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")

if redo_save:
    # model on CPU before saving
    candidate_REN_0_cpu = candidate_REN_0.to('cpu')
    candidate_REN_1_cpu = candidate_REN_1.to('cpu')

    # Save the best model
    # 1. Create models directory
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/"+ "strategy_1" + "/" + patient_str
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_0_state_dict': candidate_REN_0_cpu.state_dict(),
    'REN_1_state_dict': candidate_REN_1_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})

# %% [markdown]
# ### Plots: test results for G

# %%
# --------------Plot identification results for G-----------------



patient_str = "/paz_" + str(int(patient)).zfill(3)
patient_model_folder = model_folder + "/strategy_1" + "/" + patient_str
MODEL_PATH = Path(patient_model_folder)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])


# ----------------------------------

epochs = 700

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

REN_1 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")

REN_0.load_state_dict(checkpoint["REN_0_state_dict"])
REN_1.load_state_dict(checkpoint["REN_1_state_dict"])


REN_0.eval()
REN_1.eval()

for u0_batch, _, _, u1_batch, y_batch, time in train_loader_p:

    u0_batch, u1_batch, y_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)

    y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
    y1_hat = REN_1(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = y0_hat - y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Train Set, first batch")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()

# -------------------------------------------------------------



for u0_batch, _, _, u1_batch, y_batch, time in test_loader:

    u0_batch, u1_batch, y_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)

    y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
    y1_hat = REN_1(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = y0_hat - y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    


# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time, y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time, y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()

# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_insulin_30g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())

# --- Creazione di un Dataset custom ---
class TestDataset(Dataset):
    def __init__(self, MH, I, y, sequence_length=1):
        """
        MH: meal input (torch tensor)
        I: insulin input (torch tensor)
        y: output (glucose) (torch tensor)
        sequence_length: lunghezza sequenza temporale per la RNN/REN
        """
        self.MH = MH.unsqueeze(-1) if MH.ndim==1 else MH  # shape (N,1)
        self.I  = I.unsqueeze(-1) if I.ndim==1 else I
        self.y  = y.unsqueeze(-1) if y.ndim==1 else y
        self.seq_len = sequence_length

    def __len__(self):
        return len(self.y) - self.seq_len + 1

    def __getitem__(self, idx):
        u0_seq = self.MH[idx:idx+self.seq_len]
        u1_seq = self.I[idx:idx+self.seq_len]
        y_seq  = self.y[idx:idx+self.seq_len]
        time_seq = torch.arange(idx, idx+self.seq_len)
        return u0_seq, u1_seq, y_seq, time_seq

# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)


Dual_REN = DualREN(REN_0, REN_1)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, batch_size = 1, use_noise = use_noise) # errore qua! batchsize
closed_loop_REN = ClosedLoopSystem(Dual_REN, controller, negative=True)



for u0_batch, u1_batch, y_batch, time in test_loader_new:
    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2) 
    
    
    closed_loop_REN.eval()
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, insulin")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()


# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_meal_80g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())


# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)


    
for u0_batch, u1_batch, y_batch, time in test_loader_new:
    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2) 
    
    
    closed_loop_REN.eval()
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, meal")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_24768\817672786.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\models.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32) # MODIFICATO PER BATCH

# %% [markdown]
# # System identification of the negative feedback of K and S

# %% [markdown]
# ### Closed loop model of REN in negative feedback with K, loss function and optimizer

# %%
#-----------------------------closedloop sysid of S through RENs------------------------
#--------------------------Define model for sysid---------------------------------------------
#create the REN model for S

y_init = x0

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

REN_S = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = -y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)
Dual_REN = DualREN(REN_0, REN_S, device=device)

controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise = use_noise)

closed_loop_REN = ClosedLoopSystem(Dual_REN, controller, negative=True)

closed_loop_closed_loop_1 = ClosedLoopSystem(closed_loop_REN, controller)



#--------------------------Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()
optimizer = torch.optim.Adam(Dual_REN.parameters(), lr=learning_rate)
optimizer.zero_grad()

# %% [markdown]
# ### Training and validation loop

# %%
#--------------------------5. Training---------------------------------------------------------------------


REN_0 = REN_0.to(device)
REN_S = REN_S.to(device)
Dual_Ren = Dual_REN.to(device)
controller = controller.to(device)
closed_loop_REN = closed_loop_REN.to(device)
x0 = x0.to(device)
print(f"[INFO] Training on device: {device}")

closed_loop_closed_loop_1 = closed_loop_closed_loop_1.to("cpu") # test always on cpu?
torch.set_default_dtype(torch.float32)  # default tensor dtype

train_losses = []
val_losses = []  # Store validation losses across epochs

for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    closed_loop_REN.train()
    loss_epoch = 0.0  # Accumulate training loss


    for u0_batch, _, _, u1_batch, y_batch, t_batch in train_loader_p: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
        # u_batch.shape = batch_size   horizon   input_dim
        
        u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
        u0_batch, u1_batch, y_batch, t_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device), t_batch.to(device)
        u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input dimension

        optimizer.zero_grad()
        
        saturation_error_init, glucose_PID_init, _ = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
        closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
        
        
        _, y_hat_train = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])

        if torch.isnan(y_hat_train).any() or torch.isinf(y_hat_train).any():
            y_hat_train = torch.nan_to_num(y_hat_train, nan=1e5, posinf=1e5, neginf=-1e5)
            for name, param in closed_loop_REN.named_parameters():
                print(f"{name}: mean {param.data.mean()}, std {param.data.std()}")

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        # torch.nn.utils.clip_grad_norm_(Dual_REN.parameters(), max_norm=1.0) # Gradient clipping TODO: check if other code is correct

        optimizer.step()

        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    Dual_REN.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, _, u1_batch, y_batch, t_batch in val_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
            # u_batch.shape = batch_size   horizon   input_dim
            
            u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
            u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input dimension
            u_batch, y_batch, t_batch = u_batch.to(device), y_batch.to(device), t_batch.to(device)
            
            saturation_error_init, glucose_PID_init, _ = fun_start_controller(val_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
            closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
            
            _, y_hat_val = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        candidate_Dual_REN = Dual_REN

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")

if redo_save:
    # model on CPU before saving
    candidate_Dual_REN_cpu = candidate_Dual_REN.to('cpu')

    # Save the best model
    # 1. Create models directory
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/"+ "strategy_2" + "/" + patient_str
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'Dueal_REN_state_dict': candidate_Dual_REN_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})

# %% [markdown]
# ### Plots: identification results for the negative feedback of S and K

# %%
# --------------Plot identification results for G-----------------

patient_str = "/paz_" + str(int(patient)).zfill(3)
patient_model_folder = model_folder + "/strategy_2" + "/" + patient_str
MODEL_PATH = Path(patient_model_folder)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])


# ----------------------------------

epochs = 700


#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)
REN_S = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)
Dual_REN = DualREN(REN_0, REN_S, device=device)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise = use_noise)
closed_loop_REN = ClosedLoopSystem(Dual_REN, controller, negative=True)


checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")

Dual_REN.load_state_dict(checkpoint["Dueal_REN_state_dict"])



Dual_REN.eval()

for u0_batch, _, _, u1_batch, y_batch, t_batch in train_loader_p:

    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
    u0_batch, u1_batch, y_batch, t_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device), t_batch.to(device)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
            
    _, y_hat_train = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat_train.detach().cpu()).numpy()
    
    break # just first batch

# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(t_batch[0,:,0], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(t_batch[0,:,0], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Train Set, first batch")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()





for u0_batch, _, _, u1_batch, y_batch, time in test_loader:

    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input di
    
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    


# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time, y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time, y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()



# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_insulin_30g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())

# --- Creazione di un Dataset custom ---
class TestDataset(Dataset):
    def __init__(self, MH, I, y, sequence_length=1):
        """
        MH: meal input (torch tensor)
        I: insulin input (torch tensor)
        y: output (glucose) (torch tensor)
        sequence_length: lunghezza sequenza temporale per la RNN/REN
        """
        self.MH = MH.unsqueeze(-1) if MH.ndim==1 else MH  # shape (N,1)
        self.I  = I.unsqueeze(-1) if I.ndim==1 else I
        self.y  = y.unsqueeze(-1) if y.ndim==1 else y
        self.seq_len = sequence_length

    def __len__(self):
        return len(self.y) - self.seq_len + 1

    def __getitem__(self, idx):
        u0_seq = self.MH[idx:idx+self.seq_len]
        u1_seq = self.I[idx:idx+self.seq_len]
        y_seq  = self.y[idx:idx+self.seq_len]
        time_seq = torch.arange(idx, idx+self.seq_len)
        return u0_seq, u1_seq, y_seq, time_seq

# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)

for u0_batch, u1_batch, y_batch, time in test_loader_new:

    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input di
    
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, insulin")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()


# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_meal_80g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())


# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)

for u0_batch, u1_batch, y_batch, time in test_loader_new:

    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input di
    
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, meal")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_24768\1859881509.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\models.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32) # MODIFICATO PER BATCH

# %% [markdown]
# # System identification of S using reference inputs

# %%
#-----------------------------closedloop sysid of S through RENs------------------------
#--------------------------Define model for sysid---------------------------------------------
#create the REN model for S

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

REN_S_2 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)


#--------------------------Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()
optimizer = torch.optim.Adam( list(REN_0.parameters()) + list(REN_S_2.parameters()),   lr=learning_rate)
optimizer.zero_grad()

# %% [markdown]
# ### Training and validation loop

# %%
#--------------------------5. Training---------------------------------------------------------------------

REN_0 = REN_0.to(device)
REN_S_2 = REN_S_2.to(device)
print(f"[INFO] Training on device: {device}")

torch.set_default_dtype(torch.float32)  # default tensor dtype

train_losses = []
val_losses = []  # Store validation losses across epochs


for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_0.train(); REN_S_2.train()
    loss_epoch = 0.0  # Accumulate training loss

    for u0_batch, _, u1_batch, _, y_batch, _ in train_loader_p: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
        # u_batch.shape = batch_size   horizon   input_dim
        u0_batch, u1_batch, y_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch) # batch_size, time_horizon, input_dim
        u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)


        optimizer.zero_grad()
        
        REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1])); 
        REN_S_2.reset(y0 = - y_batch[:,:1,:1])
        
        y0_hat_train = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
        y1_hat_train = REN_S_2(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
        y_hat_train = y0_hat_train - y1_hat_train 
        
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)
        
        loss_batch.backward()
        optimizer.step()

        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_0.eval(); REN_S_2.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, u1_batch, _, y_batch, _ in val_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
            # u_batch.shape = batch_size   horizon   input_dim
            
            u0_batch, u1_batch, y_batch= ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch) # batch_size, time_horizon, input_dim
            u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)
            
            
            REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1])); 
            REN_S_2.reset(y0 = - y_batch[:,:1,:1])
            
            y0_hat_val = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
            y1_hat_val = REN_S_2(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
            y_hat_val = y0_hat_val - y1_hat_val
            
            y0_hat_val = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
            y1_hat_val = REN_S_2(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
            y_hat_val = y0_hat_val - y1_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        candidate_REN_0 = REN_0
        candidate_REN_S_2 = REN_S_2

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")

if redo_save:
    # model on CPU before saving
    candidate_REN_0_cpu = candidate_REN_0.to('cpu')
    candidate_REN_S_2_cpu = candidate_REN_S_2.to('cpu')

    # Save the best model
    # 1. Create models directory
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/"+ "strategy_3" + "/" + patient_str
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_0_state_dict': candidate_REN_0_cpu.state_dict(),
    'REN_S_2_state_dict': candidate_REN_S_2_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
    
Dual_REN = DualREN(candidate_REN_0_cpu, candidate_REN_S_2_cpu)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, batch_size = 1, use_noise = use_noise) # errore qua! batchsize
closed_loop_REN_2 = ClosedLoopSystem(Dual_REN, controller, negative=True)

# %% [markdown]
# ### Plots: identification results

# %%
# --------------Plot identification results for S-----------------


patient_str = "/paz_" + str(int(patient)).zfill(3)
patient_model_folder = model_folder + "/strategy_3" + "/" + patient_str
MODEL_PATH = Path(patient_model_folder)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])


# ----------------------------------


#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs'); plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()



# --------------------------------------------

# saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

_, _, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], 
                      IQC_type = IQC_type[0], device=device)

y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0
REN_S_2 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], 
                      IQC_type = IQC_type[1], device=device)

checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")

REN_0.load_state_dict(checkpoint["REN_0_state_dict"]); REN_S_2.load_state_dict(checkpoint["REN_S_2_state_dict"])


Dual_REN = DualREN(REN_0, REN_S_2)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, batch_size = 1, use_noise = use_noise) # errore qua! batchsize
closed_loop_REN_2 = ClosedLoopSystem(Dual_REN, controller, negative=True)
closed_loop_closed_loop_REN_2 = Double_closed_loop(Dual_REN, controller, negative=False)


REN_0.eval(); REN_S_2.eval()

for u0_batch, _, u1_batch, _, y_batch, t_batch in test_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
            # u_batch.shape = batch_size   horizon   input_dim
            
            u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
            u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)
            
            
            REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1])); 
            REN_S_2.reset(y0 = - y_batch[:,:1,:1])
            
            y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
            y1_hat = REN_S_2(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
            y_hat = y0_hat - y1_hat
            
            y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
            y1_hat = REN_S_2(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
            y_hat = y0_hat - y1_hat
            
            y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
            y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
            
plt.figure(figsize=(10, 6))
plt.plot(t_batch[0,:,0], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(t_batch[0,:,0], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, calculated with R as input ")
plt.xlabel("Time (s)"); plt.ylabel("Output Value")
plt.legend(); plt.grid(True); plt.show()


# qui invece mando r dei dati di test direttamente alla S 
# tecnicamente sbagliato perchè r è calcolata sapendo le y
# riproduce però le condizioni di train confermando che il train è andato a buon fine


# ---------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------


Dual_REN.eval()
for u0_batch, _, _, u1_batch, y_batch, t_batch in test_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
            # u_batch.shape = batch_size   horizon   input_dim
            u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
            u0_batch, u1_batch, y_batch, t_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device), t_batch.to(device)
            u_batch = torch.cat((u0_batch, u1_batch), dim=2)
            
            saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
            closed_loop_closed_loop_REN_2.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
                    
            _, y_hat_train = closed_loop_closed_loop_REN_2(u_batch, t_batch, y0 = y_batch[:,:1,:1])  


            y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
            y_hat_np = scaler_glucose.denormalize(y_hat_train.detach().cpu()).numpy()
            
plt.figure(figsize=(10, 6))
plt.plot(t_batch[0,:,0], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(t_batch[0,:,0], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, calculated with the complete closed loop")
plt.xlabel("Time (s)"); plt.ylabel("Output Value")
plt.legend(); plt.grid(True); plt.show()

# prendo la u dai dati    I_sat (I_rec + R)
# la mando attraverso dualren in cl con controllore
# il controllore al posto di restituire una u_pid e fare confronto con u dei dati per ottenere r (come sotto)
# sapendo noise da applicare e saturation error che ha commesso con la predzione di y fino a quel punto inietta direttamente S con r calcolata da k
# quindi in pratica in dual ren entrano solo i pasti, l'input insulina della dual ren è completamente calcolata da saturation error e noise
# (che in realtà è abbastanza quello che vogliamo)
# più o meno perchè in questo modo non utilizzo in alcuna maniera l'insulina dei dati, i dati utilizzati solo per meal
# la rete predice tutto con solo come input meal e un wgn .... un po' sconcertante vedere inpulse responses


# ---------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------


Dual_REN.eval()
for u0_batch, _, _, u1_batch, y_batch, t_batch in test_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
            # u_batch.shape = batch_size   horizon   input_dim
            u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
            u0_batch, u1_batch, y_batch, t_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device), t_batch.to(device)
            u_batch = torch.cat((u0_batch, u1_batch), dim=2)
            
            saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
            closed_loop_REN_2.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
                    
            _, y_hat_train = closed_loop_REN_2(u_batch, t_batch, y0 = y_batch[:,:1,:1])  


            y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
            y_hat_np = scaler_glucose.denormalize(y_hat_train.detach().cpu()).numpy()
            
plt.figure(figsize=(10, 6))
plt.plot(t_batch[0,:,0], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(t_batch[0,:,0], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, G in open loop u from data")
plt.xlabel("Time (s)"); plt.ylabel("Output Value")
plt.legend(); plt.grid(True); plt.show()

# come dovrebbe essere, ho le u di test, con le y predette dalla rennottengo u_k dottraggo e ottengol'exciting signal r
# purtroppo se sto predicendo male r è una cosa completamente sconosciuta e sono in open loop


# marok propone di mettere la saturazione come parte del controllore ma non credo sia lì il problema dato il casso 2

# forse il problema è proprio r che nell'ultimo caso è qualcosa di completamnte strano e ignoto

# nel caso di laura funzionava perchè mandava la stessa identica r al sistema vero e al doppio closed loop
# la r che entrava era perfettamente wgn
# non ha fatto simulazioni in open loop
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_24496\2588272180.py:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])

# %% [markdown]
# ### plot impulse responses

# %%
# --------------Plot identification results for G-----------------



patient_str = "/paz_" + str(int(patient)).zfill(3)
patient_model_folder = model_folder + "/strategy_3" + "/" + patient_str
MODEL_PATH = Path(patient_model_folder)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])


# ----------------------------------


epochs = 700

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()



saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

REN_S_2 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")

REN_0.load_state_dict(checkpoint["REN_0_state_dict"])
REN_S_2.load_state_dict(checkpoint["REN_S_2_state_dict"])


REN_0.eval()
REN_S_2.eval()



for u0_batch, _, u1_batch, _, y_batch, time in train_loader_p:

    u0_batch, u1_batch, y_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)

    y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
    y1_hat = REN_S_2(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = y0_hat - y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Train Set, first batch, input r")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()




# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_insulin_30g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())

# --- Creazione di un Dataset custom ---
class TestDataset(Dataset):
    def __init__(self, MH, I, y, sequence_length=1):
        """
        MH: meal input (torch tensor)
        I: insulin input (torch tensor)
        y: output (glucose) (torch tensor)
        sequence_length: lunghezza sequenza temporale per la RNN/REN
        """
        self.MH = MH.unsqueeze(-1) if MH.ndim==1 else MH  # shape (N,1)
        self.I  = I.unsqueeze(-1) if I.ndim==1 else I
        self.y  = y.unsqueeze(-1) if y.ndim==1 else y
        self.seq_len = sequence_length

    def __len__(self):
        return len(self.y) - self.seq_len + 1

    def __getitem__(self, idx):
        u0_seq = self.MH[idx:idx+self.seq_len]
        u1_seq = self.I[idx:idx+self.seq_len]
        y_seq  = self.y[idx:idx+self.seq_len]
        time_seq = torch.arange(idx, idx+self.seq_len)
        return u0_seq, u1_seq, y_seq, time_seq

# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)



Dual_REN = DualREN(REN_0, REN_S_2)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, batch_size = 1, use_noise = use_noise) # errore qua! batchsize
closed_loop_REN_2 = ClosedLoopSystem(Dual_REN, controller, negative=True)



for u0_batch, u1_batch, y_batch, time in test_loader_new:
    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2) 
    
    
    closed_loop_REN_2.eval()
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN_2.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN_2(u_batch, t_batch, y0 = y_batch[:,:1,:1])


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, insulin");    plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()


# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_meal_80g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())


# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)


    
for u0_batch, u1_batch, y_batch, time in test_loader_new:
    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2) 
    
    
    closed_loop_REN_2.eval()
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN_2.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN_2(u_batch, t_batch, y0 = y_batch[:,:1,:1])


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()


plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, meal");   plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()


# ------------------------- fake insulin ------------------------------------

Sim_time = 2000
Ts = 5
fake_time = np.arange(0, Sim_time, Ts)

fake_meal = np.zeros(Sim_time//Ts)
fake_meal = torch.from_numpy(fake_meal).float()

fake_insulin = np.zeros(Sim_time//Ts)
fake_insulin[100] = 100.0
fake_insulin = torch.from_numpy(fake_insulin).float()

fake_insulin_c = 100*np.ones(Sim_time//Ts)
fake_insulin_c = torch.from_numpy(fake_insulin_c).float()
fake_insulin_c = fake_insulin_c[None,:, None]


fake_meal = fake_meal[None,:, None];   fake_insulin = fake_insulin[None,:, None]
REN_0.eval();                          REN_S_2.eval()

Dual_REN.reset(y0 = - fake_insulin[:,:1,:1])

# non è propriamente corretto: il modello è il closed loop non il dual ren
# in questo modo vedo se effettivamente la condizione di monotonicità è rispettata o cisono degli errori in giro
y_fake = Dual_REN(fake_meal, fake_insulin, y0 = - fake_insulin[:,:1,:1])
y_fake = y_fake.detach().cpu()
y_fake = scaler_glucose.denormalize(y_fake).numpy()

plt.figure(figsize=(10, 6))
plt.plot(fake_time, y_fake[0,:,0], label="Dual Ren prediction", color="blue")
plt.title(f"Test Fake, insulin impulse, dual ren");   plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()



# non è propriamente corretto: il modello è il closed loop non il dual ren
# in questo modo vedo se effettivamente la condizione di monotonicità è rispettata o cisono degli errori in giro
y_fake = Dual_REN(fake_meal, fake_insulin_c, y0 = - fake_insulin[:,:1,:1])
y_fake = y_fake.detach().cpu()
y_fake = scaler_glucose.denormalize(y_fake).numpy()

plt.figure(figsize=(10, 6))
plt.plot(fake_time, y_fake[0,:,0], label="Dual Ren prediction", color="blue")
plt.title(f"Test Fake, insulin constant, dual ren");   plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()



# questo è corretto
closed_loop_REN_2.reset(y0 = - fake_insulin[:,:1,:1])
_, y_hat = closed_loop_REN_2(torch.cat((fake_meal, fake_insulin), dim=2) , torch.from_numpy(fake_time)[None,:,None], y0 = - fake_insulin[:,:1,:1])
y_hat = y_hat.detach().cpu()
y_hat = scaler_glucose.denormalize(y_hat).numpy()

plt.figure(figsize=(10, 6))
plt.plot(fake_time, y_hat[0,:,0], label="Dual Ren prediction", color="blue")
plt.title(f"Test Fake, insulin impulse , model (closed loop)");   plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()


# questo è corretto
closed_loop_REN_2.reset(y0 = - fake_insulin_c[:,:1,:1])
_, y_hat = closed_loop_REN_2(torch.cat((fake_meal, fake_insulin_c), dim=2) , torch.from_numpy(fake_time)[None,:,None], y0 = - fake_insulin[:,:1,:1])
y_hat = y_hat.detach().cpu()
y_hat = scaler_glucose.denormalize(y_hat).numpy()

plt.figure(figsize=(10, 6))
plt.plot(fake_time, y_hat[0,:,0], label="Dual Ren prediction", color="blue")
plt.title(f"Test Fake, insulin constant , model (closed loop)");   plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()




# ------------------------- fake meal ------------------------------------
# non è propriamente corretto: il modello è il closed loop non il dual ren
# in questo modo vedo se effettivamente la condizione di monotonicità è rispettata o cisono degli errori in giro

fake_meal = np.zeros(500)
fake_meal[100] = 1.0
fake_meal = torch.from_numpy(fake_meal).float()
fake_insulin = np.zeros(500)
fake_insulin = torch.from_numpy(fake_insulin).float()

fake_meal = fake_meal[None,:, None];    fake_insulin = fake_insulin[None,:, None]
REN_0.eval();                           REN_S_2.eval()

Dual_REN.reset(y0 = - fake_insulin[:,:1,:1])
y_fake = Dual_REN(fake_meal, fake_insulin, y0 = - fake_insulin[:,:1,:1])
y_fake = y_fake.detach().cpu()
# y_fake = scaler_glucose.denormalize(y_fake).numpy()

# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(y_fake[0,:,0], label="Dual Ren prediction", color="blue")
plt.title(f"Test Fake, meal, dual ren");   plt.xlabel("Time (s)");   plt.ylabel("Output Value")
plt.legend();   plt.grid(True);   plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_24496\4213478763.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
