# %% [markdown]
# ### Imports

# %%
# %config InlineBackend.figure_format = 'svg'

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pickle
from models import NonLinearController, ClosedLoopSystem, NonLinearController_p2, Double_closed_loop
from Rens import REN_IQC_gamma, DualREN
from utils import set_params, set_QR, ensure_3d, fun_start_controller, fun_start_controller_simple
from torch.utils.data import DataLoader, random_split, Subset, SubsetRandomSampler, Dataset
from ParametersFunctions import Parameter, PID_functions, MinMaxScalerTorch
from pathlib import Path
import scipy.io as sio
from dataset import LoadData, SimpleLoadData
from neural_ssm import DeepSSM

# %% [markdown]
# ### Set parameters

# %%
# Parameters
# ------------
# If ecxecuted with papermill these parameters are overwritten.

patient = globals().get("patient", None)
device = globals().get("device", None)

# if not passed in papermill, set preferred values for manual use
if patient is None:
    patient = 1   # <-- preferred patient for manual use
if device is None:
    device = "cpu"  # <-- preferred device for manual use

# can add like this more optional parameters like batch size, epochs, learning rate, etc.

print(f"[INFO] Training per patient: {patient}    on device: {device}")




# Define simulation parameters
torch.set_default_dtype(torch.float64)

current_dir = Path.cwd()
# Se sei dentro code/exp_X, torna alla radice
if "code" in str(current_dir):
    root = current_dir.parent.parent  # Torna a ./
else:
    root = current_dir  # Sei già alla radice
# Define simulation parameters

x0, input_dim, output_dim, dim_internal, dim_nl, y_init, IQC_type, gamma, learning_rate, epochs, data_path, model_folder, redo_save, ts, use_noise, num_days, redo_save_101_I, redo_save_101_M, exp_identifier= set_params(root)
# Out:
# [INFO] Training per patient: 1    on device: cpu

# %% [markdown]
# # Closed-loop data

# %%
#-------------------------2. Generate closed loop data---------------------------------------------


# consecutive days split
train_size = int(num_days*0.8*1440//ts)
val_size = int(num_days*0.1*1440//ts)
test_size = int(num_days*0.1*1440//ts)

start_valid = 5*12 # 5 hours of warm-up for validation and test

# it is normalized, has as method also the scaler to denormalize
dataset = LoadData(patient, data_path, use_noise, train_size+start_valid)


val_dataset   = torch.utils.data.Subset(dataset, range(train_size+start_valid, train_size+start_valid + val_size))
test_dataset  = torch.utils.data.Subset(dataset, range(train_size+start_valid + val_size, train_size + val_size + test_size))

val_loader = DataLoader(val_dataset, batch_size=len(val_dataset), shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)



#------------------------- save scalers ---------------------------------------------------

scaler_glucose = dataset.scaler_glucose
scaler_insulin = dataset.scaler_insulin
scaler_meal    = dataset.scaler_meal


if redo_save:
    # Save the scalers
    # 1. Create models directory
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/" + patient_str
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save(scaler_glucose, MODEL_PATH / 'scaler_glucose.pth')
    torch.save(scaler_insulin, MODEL_PATH / 'scaler_insulin.pth')
    torch.save(scaler_meal,    MODEL_PATH / 'scaler_meal.pth')
    
    sio.savemat(MODEL_PATH / 'scalers.mat', {
    'glucose_low':  scaler_glucose.params['low'].item(),
    'glucose_high': scaler_glucose.params['high'].item(),
    'insulin_low':  scaler_insulin.params['low'].item(),
    'insulin_high': scaler_insulin.params['high'].item(),
    'meal_low':     scaler_meal.params['low'].item(),
    'meal_high':    scaler_meal.params['high'].item()
})

# %% [markdown]
# ### Plots: I and R

# %%
CGM   = (scaler_glucose.denormalize(dataset.CGM.detach())).numpy();              G     = (scaler_glucose.denormalize(dataset.G.detach())).numpy()
                                                                                                                                 
I_sat       = (scaler_insulin.denormalize(dataset.I_sat.detach())).numpy();      I_rec = (scaler_insulin.denormalize(dataset.I_rec.detach())).numpy();       
I_sat_rec   = (scaler_insulin.denormalize(dataset.I_sat_rec.detach())).numpy();  R     = (scaler_insulin.denormalize(dataset.R.detach())).numpy()

M       = (scaler_meal.denormalize(dataset.M.detach())).numpy();                 MH    = (scaler_meal.denormalize(dataset.MH.detach())).numpy();          
MH_rec  = (scaler_meal.denormalize(dataset.MH_rec.detach())).numpy()
H       = (scaler_meal.denormalize(dataset.H.detach())).numpy();                 H_rec = (scaler_meal.denormalize(dataset.H_rec.detach())).numpy();     

# R = I_sat (from .mat) - I_rec (exiting the PID and before saturation and noise)
# if  use_noise = True, R contains the noise and the saturation effect


# ------------------------- PID controller dynamic simulation ---------------------------------------------------
CGM_torch = dataset.CGM
time = dataset.time
loaded_parameters = Parameter(patient)
controller = NonLinearController(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise)
u_pid, u_pid_rwgn, u_pid_rwgn_sat, r = controller(CGM_torch, time)


u_pid           = scaler_insulin.denormalize(u_pid.detach())
u_pid_rwgn      = scaler_insulin.denormalize(u_pid_rwgn.detach())
u_pid_rwgn_sat  = scaler_insulin.denormalize(u_pid_rwgn_sat.detach())
r               = scaler_insulin.denormalize(r.detach())

plt.figure()
plt.plot(I_rec[:2*1440//ts]+ R[:2*1440//ts], label= 'I_rec + R')
plt.plot(u_pid_rwgn_sat.numpy()[:2*1440//ts], label = 'I pid dynamic calculation');             plt.legend();plt.grid(True); plt.show()

plt.figure()
plt.plot(R[:2*1440//ts], label= 'R')
plt.plot(r.numpy()[:2*1440//ts], label = 'R dynamic calculation');                             plt.legend();plt.grid(True); plt.show()
# Out:
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\code\exp_2\models.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32)
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\code\exp_2\models.py:105: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   bolus = torch.tensor(bolus, dtype=torch.float32)

# %% [markdown]
# ### parallelization batches

# %%
# train start 5 h aafter midnight, every batch 48 h long finishing at 4:55 am


# time definitions
ts_per_hour = 12           # 288 timesteps = 24h → 12 timesteps/hour (5 min each)
hours_per_batch = 48       # 2 days = 48 hours
steps_per_batch = hours_per_batch * ts_per_hour  # 48*12 = 576

start_train = start_valid        #60    [1 element every 5 minutes] I eliminate eqully the first 5 hours from training set

train_dataset = torch.utils.data.Subset(dataset, range(start_train, train_size+start_valid))



# === FUNZIONE: crea blocchi fissi ===
def create_fixed_batches(total_length, chunk_size=576, start_idx=0):
    """
    Divide il dataset in batch temporali fissi (48h).
    Ogni batch è una lista di indici consecutivi.
    L'ultimo batch viene scartato se più corto di chunk_size.
    """
    batches = []
    start = start_idx
    while start + chunk_size <= total_length:
        end = start + chunk_size
        batches.append(list(range(start, end)))
        start = end
    return batches


# === COSTRUISCI I BATCH INDICI ===
train_indices = create_fixed_batches(len(train_dataset), chunk_size=steps_per_batch)

starting_indices = [batch[0] for batch in train_indices]

batch_size=len(starting_indices)

def collate_train_indices(batch):
    """
    batch: lista di 12 sequenze consecutive (ognuna di lunghezza 576)
    batch_size = len(batch) = 12
    """
    # ogni item del batch corrisponde a un indice di train_indices (576 timesteps)
    u0_batch = torch.stack([train_dataset[i][0] for i in batch]) # MH # shape: (12, 576, input_dim)
    u1_batch = torch.stack([train_dataset[i][3] for i in batch]) # I_sat
    ur_batch = torch.stack([train_dataset[i][2] for i in batch]) # r
    y_batch  = torch.stack([train_dataset[i][4] for i in batch])
    time_batch = torch.stack([train_dataset[i][5] for i in batch])
    
    return u0_batch, None, ur_batch, u1_batch, y_batch, time_batch



train_loader_p = DataLoader(
    train_indices,
    batch_size = batch_size,
    shuffle = False,  # oppure True se vuoi mescolare
    collate_fn = collate_train_indices,
    drop_last = True  # opzionale, elimina batch incompleti
)


saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

controller_p2 = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise = use_noise)

controller_p2.reset(saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)

# === LOOP DI TRAINING ===
for n_batch, (u0_batch, _, _, u1_batch, y_batch, time_batch) in enumerate(train_loader_p):

    u0_batch, u1_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
    u_pid, u_pid_rwgn, u_pid_rwgn_sat, r = controller_p2(CGM = y_batch.squeeze(2), time = time_batch.squeeze(2))
    
r = scaler_insulin.denormalize(r.detach())
for i in range(2):
    plt.figure()
    plt.plot(time_batch[i,:].numpy(), R[time_batch[i,:].squeeze().numpy().astype(int)], label= 'R')
    plt.plot(time_batch[i,:].numpy(), r[i,:].numpy(), label = 'R dynamic calculation');                             plt.legend();plt.grid(True); plt.show()
    
    

# === LOOP DI val ===
# !!! reset va lasciato a 0 solo se parto proprio dall'istante zero, con valid in realtà la simulazione era andata già da un po'

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(val_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
controller_p2.reset(saturation_error_init=saturation_error_init, glucose_PID_init=glucose_PID_init)
for u0_batch, _, _, u1_batch, y_batch, time_batch in val_loader:
    
    u0_batch, u1_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)

    u_pid, u_pid_rwgn, u_pid_rwgn_sat, r = controller_p2(CGM = y_batch.squeeze(2), time = time_batch.squeeze(2))
    
r = scaler_insulin.denormalize(r.detach())

plt.figure()
plt.plot(time_batch[0,:].numpy(), R[time_batch[0,:].squeeze().numpy().astype(int)], label= 'R')
plt.plot(time_batch[0,:].numpy(), r[0,:].numpy(), label = 'R dynamic calculation');                             plt.legend();plt.grid(True); plt.show()
# Out:
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\code\exp_2\models.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32) # MODIFICATO PER BATCH

# %% [markdown]
# ### other plots

# %%
plt.figure(1, figsize=(12, 8))

# Subplot 1
ax1 = plt.subplot(2, 1, 1)
ax1.plot(CGM[:], 'b-', label='Glucose sensor CGM')
ax1.plot(G[:], 'gray', label='Glucose');                                                               ax1.set_ylabel('Glucose', color='b'); ax1.tick_params(axis='y', labelcolor='b'); ax1_right = ax1.twinx()
MHtemp = MH[:].copy()
ax1_right.scatter(np.arange(len(MHtemp))[MHtemp!=0], MHtemp[MHtemp!=0], color='g', label='Meals and hypo');         ax1_right.set_ylabel('Meals', color='b'); ax1_right.tick_params(axis='y', labelcolor='g'); plt.grid(True)

# Subplot 2
ax2 = plt.subplot(2, 1, 2, sharex=ax1)
ax2.plot(range(len(I_sat[:])), I_sat[:].flatten(), label='I_sat')
ax2.plot(range(len(I_sat_rec[:])), I_sat_rec[:], label='I_sat_rec');                                      ax2.set_ylim([0, np.max(I_sat_rec) * 1.1]); ax2.legend(); ax2.set_xlabel('Time Index'); ax2.set_ylabel('Insulin')

plt.tight_layout(); plt.grid(True); plt.show()



plt.figure(3, figsize=(12, 8))
plt.plot(I_rec[:1440//4]+ R[:1440//4], label = 'I_rec(calculated by PID) + R')
plt.plot(I_sat[:1440//4], label= 'I_sat (from the data already saturated)')
plt.title('I saturated, They need to be equal,   R = I_sat - I_rec');                   plt.legend();plt.grid(True); plt.show()

plt.figure(4, figsize=(12, 8))
plt.plot(R[:1440//4], label= 'R')
plt.plot(I_rec[:1440//4]+ R[:1440//4], label= 'I_rec + R')
plt.plot(I_rec[:1440//4], label = 'I_rec  (calculated by PID)');                             plt.legend();plt.grid(True); plt.show()


# plt.figure(5)
# plt.plot(H, label='H')
# plt.plot(H_rec-100, label='H_rec')
# plt.title('Hypoglycemia Treatments Comparison');                                                    plt.legend(); plt.show()
#
# plt.figure(6)
# plt.plot(CGM[:1440//4], 'b-', label='Glucose sensor CGM')
# plt.plot(G[:1440//4], 'gray', label='Glucose')
# plt.figure(1, figsize=(12, 8))

# %% [markdown]
# # Patient 101

# %% [markdown]
# ### define dataset 101

# %%
dataset_101_I = SimpleLoadData('./data/train/30days_101_I/', 101,scaler_insulin, scaler_glucose, scaler_meal)
dataset_101_M = SimpleLoadData('./data/train/30days_101_M/', 101,scaler_insulin, scaler_glucose, scaler_meal)

train_dataset_101_I = torch.utils.data.Subset(dataset_101_I, range(start_train, train_size+start_valid))
train_dataset_101_M = torch.utils.data.Subset(dataset_101_M, range(start_train, train_size+start_valid))

val_dataset_101_I   = torch.utils.data.Subset(dataset_101_I, range(train_size+start_valid, train_size+start_valid + val_size))
val_dataset_101_M   = torch.utils.data.Subset(dataset_101_M, range(train_size+start_valid, train_size+start_valid + val_size))
test_dataset_101_I  = torch.utils.data.Subset(dataset_101_I, range(train_size+start_valid + val_size, train_size + val_size + test_size))
test_dataset_101_M  = torch.utils.data.Subset(dataset_101_M, range(train_size+start_valid + val_size, train_size + val_size + test_size))

val_loader_101_I = DataLoader(val_dataset_101_I, batch_size=len(val_dataset_101_I), shuffle=False)
val_loader_101_M = DataLoader(val_dataset_101_M, batch_size=len(val_dataset_101_M), shuffle=False)
test_loader_101_I = DataLoader(test_dataset_101_I, batch_size=len(test_dataset_101_I), shuffle=False)
test_loader_101_M = DataLoader(test_dataset_101_M, batch_size=len(test_dataset_101_M), shuffle=False)


def collate_train_indices_101_I(batch):
    """
    batch: lista di 12 sequenze consecutive (ognuna di lunghezza 576)
    batch_size = len(batch) = 12
    """
    # ogni item del batch corrisponde a un indice di train_indices (576 timesteps)
    u0_batch = torch.stack([train_dataset_101_I[i][0] for i in batch]) # MH 
    u1_batch = torch.stack([train_dataset_101_I[i][1] for i in batch]) # I_sat   (no RWGN)
    y_batch = torch.stack([train_dataset_101_I[i][2] for i in batch]) # y
    time_batch = torch.stack([train_dataset_101_I[i][3] for i in batch])

    return u0_batch, u1_batch, y_batch, time_batch

def collate_train_indices_101_M(batch):
    """
    batch: lista di 12 sequenze consecutive (ognuna di lunghezza 576)
    batch_size = len(batch) = 12
    """
    # ogni item del batch corrisponde a un indice di train_indices (576 timesteps)
    u0_batch = torch.stack([train_dataset_101_M[i][0] for i in batch]) # MH 
    u1_batch = torch.stack([train_dataset_101_M[i][1] for i in batch]) # I_sat   (no RWGN)
    y_batch = torch.stack([train_dataset_101_M[i][2] for i in batch]) # y
    time_batch = torch.stack([train_dataset_101_M[i][3] for i in batch])

    return u0_batch, u1_batch, y_batch, time_batch


train_loader_p_101_I = DataLoader(
    train_indices,
    batch_size = batch_size,
    shuffle = False,  # oppure True se vuoi mescolare
    collate_fn = collate_train_indices_101_I,
    drop_last = True  # opzionale, elimina batch incompleti
)

train_loader_p_101_M = DataLoader(
    train_indices,
    batch_size = batch_size,
    shuffle = False,  # oppure True se vuoi mescolare
    collate_fn = collate_train_indices_101_M,
    drop_last = True  # opzionale, elimina batch incompleti
)

# %% [markdown]
# ### REN model 101, loss function and optimizer parallel
# as strategy 1

# %%
#--------------------------3. Define model for sysid---------------------------------------------


device = torch.device(device if torch.cuda.is_available() else "cpu")

y0_1 = fun_start_controller_simple(train_loader_p_101_I, dataset_101_I)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0


# TODO: gamma diverso per i 101

# meal   M 
REN_0_101 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

# insulin  I_sat
REN_1_101 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

REN_0_101 = REN_0_101.to(device)
REN_1_101 = REN_1_101.to(device)

#create the closed loop with the identified model
# closed_loop_G = ClosedLoopSystem(REN_G, controller)

#--------------------------4. Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()

# %% [markdown]
# ### Training and validation loop

# %% [markdown]
# #### 101 I

# %%
optimizer = torch.optim.Adam( list(REN_1_101.parameters()),   lr=learning_rate)
optimizer.zero_grad()

epochs = 700

#--------------------------5. Training---------------------------------------------------------------------

torch.set_default_device(device)      # default tensor device
torch.set_default_dtype(torch.float32)  # default tensor dtype
print(f"[INFO] Training on device: {device}")

REN_1_101.to(device)
train_losses = []
val_losses = []  # Store validation losses across epochs
for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_1_101.train()
    loss_epoch = 0.0  # Accumulate training loss

    
    for _, u1_batch, y_batch, time_batch in train_loader_p_101_I: # MH, I_rec , CGM, time

        torch.save({'u1_batch': u1_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_train_ins.pt')
        

        u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
        u1_batch, y_batch, time_batch = u1_batch.to(device), y_batch.to(device), time_batch.to(device)
        
        optimizer.zero_grad()
        
        REN_1_101.reset(y0 = - y_batch[:,:1,:1])

        # y_init_per_batch      torch.zeros_like(y_batch[:,:1])    y_batch[:,:1]
        y1_hat_train = REN_1_101(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
        y_hat_train = - y1_hat_train 
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        optimizer.step()
        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_1_101.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for _, u1_batch, y_batch, time_batch in val_loader_101_I: # MH, I_rec (PID), CGM, time
            
            torch.save({'u1_batch': u1_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_valid_ins.pt')

            u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
            u1_batch, y_batch, time_batch = u1_batch.to(device), y_batch.to(device), time_batch.to(device)
            
            REN_1_101.reset(y0 = - y_batch[:,:1,:1])

            y1_hat_val = REN_1_101(u1_batch, y0 = - y_batch[:,:1,:1])# select the correct U
            y_hat_val = - y1_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        
        candidate_REN_1_101 = REN_1_101

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")


patient_model_folder_101_I = f"./models/REN/101_I/{exp_identifier}"
if redo_save_101_I:
    # model on CPU before saving
    candidate_REN_1_101_cpu = candidate_REN_1_101.to('cpu')

    # Save the best model
    # 1. Create models directory
    MODEL_PATH = Path(patient_model_folder_101_I)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_1_101_state_dict': candidate_REN_1_101_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder_101_I) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
# Out:
# [INFO] Training on device: cpu
# Epoch: 1 	||	 Training Loss: 0.066111 	||	 Validation Loss: 0.065676
# Epoch: 2 	||	 Training Loss: 0.065527 	||	 Validation Loss: 0.065175
# Epoch: 3 	||	 Training Loss: 0.064962 	||	 Validation Loss: 0.064690
# Epoch: 4 	||	 Training Loss: 0.064415 	||	 Validation Loss: 0.064220
# Epoch: 5 	||	 Training Loss: 0.063885 	||	 Validation Loss: 0.063767
# Epoch: 6 	||	 Training Loss: 0.063373 	||	 Validation Loss: 0.063329
# Epoch: 7 	||	 Training Loss: 0.062878 	||	 Validation Loss: 0.062907
# Epoch: 8 	||	 Training Loss: 0.062401 	||	 Validation Loss: 0.062500
# Epoch: 9 	||	 Training Loss: 0.061941 	||	 Validation Loss: 0.062107
# Epoch: 10 	||	 Training Loss: 0.061497 	||	 Validation Loss: 0.061730
# Epoch: 11 	||	 Training Loss: 0.061070 	||	 Validation Loss: 0.061366
# Epoch: 12 	||	 Training Loss: 0.060659 	||	 Validation Loss: 0.061017
# Epoch: 13 	||	 Training Loss: 0.060263 	||	 Validation Loss: 0.060681
# Epoch: 14 	||	 Training Loss: 0.059883 	||	 Validation Loss: 0.060358
# Epoch: 15 	||	 Training Loss: 0.059518 	||	 Validation Loss: 0.060049
# Epoch: 16 	||	 Training Loss: 0.059167 	||	 Validation Loss: 0.059752
# Epoch: 17 	||	 Training Loss: 0.058830 	||	 Validation Loss: 0.059467
# Epoch: 18 	||	 Training Loss: 0.058506 	||	 Validation Loss: 0.059194
# Epoch: 19 	||	 Training Loss: 0.058196 	||	 Validation Loss: 0.058932
# Epoch: 20 	||	 Training Loss: 0.057899 	||	 Validation Loss: 0.058681
# Epoch: 21 	||	 Training Loss: 0.057614 	||	 Validation Loss: 0.058441
# Epoch: 22 	||	 Training Loss: 0.057340 	||	 Validation Loss: 0.058212
# Epoch: 23 	||	 Training Loss: 0.057079 	||	 Validation Loss: 0.057992
# Epoch: 24 	||	 Training Loss: 0.056828 	||	 Validation Loss: 0.057782
# Epoch: 25 	||	 Training Loss: 0.056589 	||	 Validation Loss: 0.057581
# Epoch: 26 	||	 Training Loss: 0.056360 	||	 Validation Loss: 0.057390
# Epoch: 27 	||	 Training Loss: 0.056140 	||	 Validation Loss: 0.057206
# Epoch: 28 	||	 Training Loss: 0.055931 	||	 Validation Loss: 0.057032
# Epoch: 29 	||	 Training Loss: 0.055731 	||	 Validation Loss: 0.056865
# Epoch: 30 	||	 Training Loss: 0.055540 	||	 Validation Loss: 0.056706
# Epoch: 31 	||	 Training Loss: 0.055357 	||	 Validation Loss: 0.056554
# Epoch: 32 	||	 Training Loss: 0.055183 	||	 Validation Loss: 0.056409
# Epoch: 33 	||	 Training Loss: 0.055016 	||	 Validation Loss: 0.056271
# Epoch: 34 	||	 Training Loss: 0.054858 	||	 Validation Loss: 0.056140
# Epoch: 35 	||	 Training Loss: 0.054707 	||	 Validation Loss: 0.056015
# Epoch: 36 	||	 Training Loss: 0.054563 	||	 Validation Loss: 0.055896
# Epoch: 37 	||	 Training Loss: 0.054426 	||	 Validation Loss: 0.055783
# Epoch: 38 	||	 Training Loss: 0.054295 	||	 Validation Loss: 0.055676
# Epoch: 39 	||	 Training Loss: 0.054171 	||	 Validation Loss: 0.055574
# Epoch: 40 	||	 Training Loss: 0.054052 	||	 Validation Loss: 0.055477
# Epoch: 41 	||	 Training Loss: 0.053940 	||	 Validation Loss: 0.055385
# Epoch: 42 	||	 Training Loss: 0.053833 	||	 Validation Loss: 0.055298
# Epoch: 43 	||	 Training Loss: 0.053732 	||	 Validation Loss: 0.055215
# Epoch: 44 	||	 Training Loss: 0.053636 	||	 Validation Loss: 0.055137
# Epoch: 45 	||	 Training Loss: 0.053545 	||	 Validation Loss: 0.055063
# Epoch: 46 	||	 Training Loss: 0.053458 	||	 Validation Loss: 0.054993
# Epoch: 47 	||	 Training Loss: 0.053377 	||	 Validation Loss: 0.054927
# Epoch: 48 	||	 Training Loss: 0.053299 	||	 Validation Loss: 0.054864
# Epoch: 49 	||	 Training Loss: 0.053226 	||	 Validation Loss: 0.054806
# Epoch: 50 	||	 Training Loss: 0.053157 	||	 Validation Loss: 0.054750
# Epoch: 51 	||	 Training Loss: 0.053092 	||	 Validation Loss: 0.054698
# Epoch: 52 	||	 Training Loss: 0.053031 	||	 Validation Loss: 0.054649
# Epoch: 53 	||	 Training Loss: 0.052973 	||	 Validation Loss: 0.054603
# Epoch: 54 	||	 Training Loss: 0.052919 	||	 Validation Loss: 0.054560
# Epoch: 55 	||	 Training Loss: 0.052868 	||	 Validation Loss: 0.054520
# Epoch: 56 	||	 Training Loss: 0.052820 	||	 Validation Loss: 0.054482
# Epoch: 57 	||	 Training Loss: 0.052775 	||	 Validation Loss: 0.054447
# Epoch: 58 	||	 Training Loss: 0.052733 	||	 Validation Loss: 0.054414
# Epoch: 59 	||	 Training Loss: 0.052694 	||	 Validation Loss: 0.054383
# Epoch: 60 	||	 Training Loss: 0.052657 	||	 Validation Loss: 0.054354
# Epoch: 61 	||	 Training Loss: 0.052623 	||	 Validation Loss: 0.054327
# Epoch: 62 	||	 Training Loss: 0.052591 	||	 Validation Loss: 0.054303
# Epoch: 63 	||	 Training Loss: 0.052561 	||	 Validation Loss: 0.054279
# Epoch: 64 	||	 Training Loss: 0.052533 	||	 Validation Loss: 0.054258
# Epoch: 65 	||	 Training Loss: 0.052507 	||	 Validation Loss: 0.054238
# Epoch: 66 	||	 Training Loss: 0.052483 	||	 Validation Loss: 0.054219
# Epoch: 67 	||	 Training Loss: 0.052460 	||	 Validation Loss: 0.054201
# Epoch: 68 	||	 Training Loss: 0.052438 	||	 Validation Loss: 0.054185
# Epoch: 69 	||	 Training Loss: 0.052418 	||	 Validation Loss: 0.054170
# Epoch: 70 	||	 Training Loss: 0.052399 	||	 Validation Loss: 0.054155
# Epoch: 71 	||	 Training Loss: 0.052381 	||	 Validation Loss: 0.054141
# Epoch: 72 	||	 Training Loss: 0.052364 	||	 Validation Loss: 0.054128
# Epoch: 73 	||	 Training Loss: 0.052348 	||	 Validation Loss: 0.054116
# Epoch: 74 	||	 Training Loss: 0.052332 	||	 Validation Loss: 0.054104
# Epoch: 75 	||	 Training Loss: 0.052317 	||	 Validation Loss: 0.054092
# Epoch: 76 	||	 Training Loss: 0.052302 	||	 Validation Loss: 0.054081
# Epoch: 77 	||	 Training Loss: 0.052288 	||	 Validation Loss: 0.054070
# Epoch: 78 	||	 Training Loss: 0.052274 	||	 Validation Loss: 0.054059
# Epoch: 79 	||	 Training Loss: 0.052260 	||	 Validation Loss: 0.054048
# Epoch: 80 	||	 Training Loss: 0.052246 	||	 Validation Loss: 0.054037
# Epoch: 81 	||	 Training Loss: 0.052232 	||	 Validation Loss: 0.054026
# Epoch: 82 	||	 Training Loss: 0.052218 	||	 Validation Loss: 0.054015
# Epoch: 83 	||	 Training Loss: 0.052204 	||	 Validation Loss: 0.054003
# Epoch: 84 	||	 Training Loss: 0.052190 	||	 Validation Loss: 0.053992
# Epoch: 85 	||	 Training Loss: 0.052175 	||	 Validation Loss: 0.053980
# Epoch: 86 	||	 Training Loss: 0.052160 	||	 Validation Loss: 0.053967
# Epoch: 87 	||	 Training Loss: 0.052145 	||	 Validation Loss: 0.053955
# Epoch: 88 	||	 Training Loss: 0.052129 	||	 Validation Loss: 0.053941
# Epoch: 89 	||	 Training Loss: 0.052113 	||	 Validation Loss: 0.053928
# Epoch: 90 	||	 Training Loss: 0.052096 	||	 Validation Loss: 0.053914
# Epoch: 91 	||	 Training Loss: 0.052079 	||	 Validation Loss: 0.053899
# Epoch: 92 	||	 Training Loss: 0.052061 	||	 Validation Loss: 0.053884
# Epoch: 93 	||	 Training Loss: 0.052042 	||	 Validation Loss: 0.053868
# Epoch: 94 	||	 Training Loss: 0.052023 	||	 Validation Loss: 0.053851
# Epoch: 95 	||	 Training Loss: 0.052002 	||	 Validation Loss: 0.053834
# Epoch: 96 	||	 Training Loss: 0.051981 	||	 Validation Loss: 0.053816
# Epoch: 97 	||	 Training Loss: 0.051959 	||	 Validation Loss: 0.053797
# Epoch: 98 	||	 Training Loss: 0.051936 	||	 Validation Loss: 0.053778
# Epoch: 99 	||	 Training Loss: 0.051913 	||	 Validation Loss: 0.053757
# Epoch: 100 	||	 Training Loss: 0.051888 	||	 Validation Loss: 0.053736
# Epoch: 101 	||	 Training Loss: 0.051862 	||	 Validation Loss: 0.053714
# Epoch: 102 	||	 Training Loss: 0.051835 	||	 Validation Loss: 0.053690
# Epoch: 103 	||	 Training Loss: 0.051806 	||	 Validation Loss: 0.053666
# Epoch: 104 	||	 Training Loss: 0.051777 	||	 Validation Loss: 0.053640
# Epoch: 105 	||	 Training Loss: 0.051746 	||	 Validation Loss: 0.053614
# Epoch: 106 	||	 Training Loss: 0.051713 	||	 Validation Loss: 0.053586
# Epoch: 107 	||	 Training Loss: 0.051679 	||	 Validation Loss: 0.053556
# Epoch: 108 	||	 Training Loss: 0.051643 	||	 Validation Loss: 0.053525
# Epoch: 109 	||	 Training Loss: 0.051606 	||	 Validation Loss: 0.053493
# Epoch: 110 	||	 Training Loss: 0.051566 	||	 Validation Loss: 0.053459
# Epoch: 111 	||	 Training Loss: 0.051525 	||	 Validation Loss: 0.053424
# Epoch: 112 	||	 Training Loss: 0.051481 	||	 Validation Loss: 0.053387
# Epoch: 113 	||	 Training Loss: 0.051435 	||	 Validation Loss: 0.053348
# Epoch: 114 	||	 Training Loss: 0.051387 	||	 Validation Loss: 0.053307
# Epoch: 115 	||	 Training Loss: 0.051337 	||	 Validation Loss: 0.053264
# Epoch: 116 	||	 Training Loss: 0.051284 	||	 Validation Loss: 0.053219
# Epoch: 117 	||	 Training Loss: 0.051228 	||	 Validation Loss: 0.053172
# Epoch: 118 	||	 Training Loss: 0.051169 	||	 Validation Loss: 0.053123
# Epoch: 119 	||	 Training Loss: 0.051107 	||	 Validation Loss: 0.053072
# Epoch: 120 	||	 Training Loss: 0.051042 	||	 Validation Loss: 0.053019
# Epoch: 121 	||	 Training Loss: 0.050975 	||	 Validation Loss: 0.052963
# Epoch: 122 	||	 Training Loss: 0.050904 	||	 Validation Loss: 0.052906
# Epoch: 123 	||	 Training Loss: 0.050829 	||	 Validation Loss: 0.052847
# Epoch: 124 	||	 Training Loss: 0.050752 	||	 Validation Loss: 0.052786
# Epoch: 125 	||	 Training Loss: 0.050672 	||	 Validation Loss: 0.052723
# Epoch: 126 	||	 Training Loss: 0.050588 	||	 Validation Loss: 0.052659
# Epoch: 127 	||	 Training Loss: 0.050502 	||	 Validation Loss: 0.052595
# Epoch: 128 	||	 Training Loss: 0.050413 	||	 Validation Loss: 0.052530
# Epoch: 129 	||	 Training Loss: 0.050321 	||	 Validation Loss: 0.052464
# Epoch: 130 	||	 Training Loss: 0.050227 	||	 Validation Loss: 0.052399
# Epoch: 131 	||	 Training Loss: 0.050132 	||	 Validation Loss: 0.052334
# Epoch: 132 	||	 Training Loss: 0.050034 	||	 Validation Loss: 0.052270
# Epoch: 133 	||	 Training Loss: 0.049935 	||	 Validation Loss: 0.052207
# Epoch: 134 	||	 Training Loss: 0.049835 	||	 Validation Loss: 0.052144
# Epoch: 135 	||	 Training Loss: 0.049734 	||	 Validation Loss: 0.052083
# Epoch: 136 	||	 Training Loss: 0.049631 	||	 Validation Loss: 0.052022
# Epoch: 137 	||	 Training Loss: 0.049526 	||	 Validation Loss: 0.051960
# Epoch: 138 	||	 Training Loss: 0.049419 	||	 Validation Loss: 0.051896
# Epoch: 139 	||	 Training Loss: 0.049309 	||	 Validation Loss: 0.051830
# Epoch: 140 	||	 Training Loss: 0.049195 	||	 Validation Loss: 0.051759
# Epoch: 141 	||	 Training Loss: 0.049074 	||	 Validation Loss: 0.051681
# Epoch: 142 	||	 Training Loss: 0.048946 	||	 Validation Loss: 0.051595
# Epoch: 143 	||	 Training Loss: 0.048807 	||	 Validation Loss: 0.051497
# Epoch: 144 	||	 Training Loss: 0.048654 	||	 Validation Loss: 0.051384
# Epoch: 145 	||	 Training Loss: 0.048483 	||	 Validation Loss: 0.051250
# Epoch: 146 	||	 Training Loss: 0.048287 	||	 Validation Loss: 0.051087
# Epoch: 147 	||	 Training Loss: 0.048058 	||	 Validation Loss: 0.050884
# Epoch: 148 	||	 Training Loss: 0.047785 	||	 Validation Loss: 0.050623
# Epoch: 149 	||	 Training Loss: 0.047450 	||	 Validation Loss: 0.050279
# Epoch: 150 	||	 Training Loss: 0.047032 	||	 Validation Loss: 0.049812
# Epoch: 151 	||	 Training Loss: 0.046502 	||	 Validation Loss: 0.049172
# Epoch: 152 	||	 Training Loss: 0.045823 	||	 Validation Loss: 0.048293
# Epoch: 153 	||	 Training Loss: 0.044957 	||	 Validation Loss: 0.047110
# Epoch: 154 	||	 Training Loss: 0.043873 	||	 Validation Loss: 0.045580
# Epoch: 155 	||	 Training Loss: 0.042561 	||	 Validation Loss: 0.043715
# Epoch: 156 	||	 Training Loss: 0.041049 	||	 Validation Loss: 0.041612
# Epoch: 157 	||	 Training Loss: 0.039411 	||	 Validation Loss: 0.039426
# Epoch: 158 	||	 Training Loss: 0.037750 	||	 Validation Loss: 0.037323
# Epoch: 159 	||	 Training Loss: 0.036175 	||	 Validation Loss: 0.035448
# Epoch: 160 	||	 Training Loss: 0.034785 	||	 Validation Loss: 0.033941
# Epoch: 161 	||	 Training Loss: 0.033677 	||	 Validation Loss: 0.032894
# Epoch: 162 	||	 Training Loss: 0.032906 	||	 Validation Loss: 0.032309
# Epoch: 163 	||	 Training Loss: 0.032465 	||	 Validation Loss: 0.032122
# Epoch: 164 	||	 Training Loss: 0.032306 	||	 Validation Loss: 0.032185
# Epoch: 165 	||	 Training Loss: 0.032324 	||	 Validation Loss: 0.032322
# Epoch: 166 	||	 Training Loss: 0.032391 	||	 Validation Loss: 0.032415
# Epoch: 167 	||	 Training Loss: 0.032416 	||	 Validation Loss: 0.032413
# Epoch: 168 	||	 Training Loss: 0.032355 	||	 Validation Loss: 0.032296
# Epoch: 169 	||	 Training Loss: 0.032195 	||	 Validation Loss: 0.032064
# Epoch: 170 	||	 Training Loss: 0.031936 	||	 Validation Loss: 0.031730
# Epoch: 171 	||	 Training Loss: 0.031592 	||	 Validation Loss: 0.031317
# Epoch: 172 	||	 Training Loss: 0.031179 	||	 Validation Loss: 0.030850
# Epoch: 173 	||	 Training Loss: 0.030716 	||	 Validation Loss: 0.030357
# Epoch: 174 	||	 Training Loss: 0.030223 	||	 Validation Loss: 0.029867
# Epoch: 175 	||	 Training Loss: 0.029724 	||	 Validation Loss: 0.029404
# Epoch: 176 	||	 Training Loss: 0.029242 	||	 Validation Loss: 0.028989
# Epoch: 177 	||	 Training Loss: 0.028797 	||	 Validation Loss: 0.028631
# Epoch: 178 	||	 Training Loss: 0.028399 	||	 Validation Loss: 0.028330
# Epoch: 179 	||	 Training Loss: 0.028051 	||	 Validation Loss: 0.028076
# Epoch: 180 	||	 Training Loss: 0.027745 	||	 Validation Loss: 0.027857
# Epoch: 181 	||	 Training Loss: 0.027469 	||	 Validation Loss: 0.027652
# Epoch: 182 	||	 Training Loss: 0.027205 	||	 Validation Loss: 0.027442
# Epoch: 183 	||	 Training Loss: 0.026938 	||	 Validation Loss: 0.027210
# Epoch: 184 	||	 Training Loss: 0.026655 	||	 Validation Loss: 0.026945
# Epoch: 185 	||	 Training Loss: 0.026349 	||	 Validation Loss: 0.026643
# Epoch: 186 	||	 Training Loss: 0.026017 	||	 Validation Loss: 0.026308
# Epoch: 187 	||	 Training Loss: 0.025659 	||	 Validation Loss: 0.025943
# Epoch: 188 	||	 Training Loss: 0.025277 	||	 Validation Loss: 0.025552
# Epoch: 189 	||	 Training Loss: 0.024872 	||	 Validation Loss: 0.025133
# Epoch: 190 	||	 Training Loss: 0.024445 	||	 Validation Loss: 0.024687
# Epoch: 191 	||	 Training Loss: 0.023993 	||	 Validation Loss: 0.024213
# Epoch: 192 	||	 Training Loss: 0.023518 	||	 Validation Loss: 0.023713
# Epoch: 193 	||	 Training Loss: 0.023018 	||	 Validation Loss: 0.023188
# Epoch: 194 	||	 Training Loss: 0.022492 	||	 Validation Loss: 0.022634
# Epoch: 195 	||	 Training Loss: 0.021936 	||	 Validation Loss: 0.022051
# Epoch: 196 	||	 Training Loss: 0.021348 	||	 Validation Loss: 0.021438
# Epoch: 197 	||	 Training Loss: 0.020727 	||	 Validation Loss: 0.020800
# Epoch: 198 	||	 Training Loss: 0.020074 	||	 Validation Loss: 0.020145
# Epoch: 199 	||	 Training Loss: 0.019395 	||	 Validation Loss: 0.019495
# Epoch: 200 	||	 Training Loss: 0.018708 	||	 Validation Loss: 0.018877
# Epoch: 201 	||	 Training Loss: 0.018034 	||	 Validation Loss: 0.018332
# Epoch: 202 	||	 Training Loss: 0.017407 	||	 Validation Loss: 0.017886
# Epoch: 203 	||	 Training Loss: 0.016853 	||	 Validation Loss: 0.017539
# Epoch: 204 	||	 Training Loss: 0.016375 	||	 Validation Loss: 0.017243
# Epoch: 205 	||	 Training Loss: 0.015942 	||	 Validation Loss: 0.016924
# Epoch: 206 	||	 Training Loss: 0.015499 	||	 Validation Loss: 0.016516
# Epoch: 207 	||	 Training Loss: 0.014999 	||	 Validation Loss: 0.016005
# Epoch: 208 	||	 Training Loss: 0.014437 	||	 Validation Loss: 0.015431
# Epoch: 209 	||	 Training Loss: 0.013845 	||	 Validation Loss: 0.014856
# Epoch: 210 	||	 Training Loss: 0.013270 	||	 Validation Loss: 0.014328
# Epoch: 211 	||	 Training Loss: 0.012747 	||	 Validation Loss: 0.013870
# Epoch: 212 	||	 Training Loss: 0.012284 	||	 Validation Loss: 0.013475
# Epoch: 213 	||	 Training Loss: 0.011871 	||	 Validation Loss: 0.013132
# Epoch: 214 	||	 Training Loss: 0.011491 	||	 Validation Loss: 0.012827
# Epoch: 215 	||	 Training Loss: 0.011129 	||	 Validation Loss: 0.012550
# Epoch: 216 	||	 Training Loss: 0.010780 	||	 Validation Loss: 0.012296
# Epoch: 217 	||	 Training Loss: 0.010445 	||	 Validation Loss: 0.012063
# Epoch: 218 	||	 Training Loss: 0.010128 	||	 Validation Loss: 0.011844
# Epoch: 219 	||	 Training Loss: 0.009829 	||	 Validation Loss: 0.011629
# Epoch: 220 	||	 Training Loss: 0.009546 	||	 Validation Loss: 0.011418
# Epoch: 221 	||	 Training Loss: 0.009280 	||	 Validation Loss: 0.011215
# Epoch: 222 	||	 Training Loss: 0.009034 	||	 Validation Loss: 0.011027
# Epoch: 223 	||	 Training Loss: 0.008810 	||	 Validation Loss: 0.010858
# Epoch: 224 	||	 Training Loss: 0.008610 	||	 Validation Loss: 0.010705
# Epoch: 225 	||	 Training Loss: 0.008428 	||	 Validation Loss: 0.010562
# Epoch: 226 	||	 Training Loss: 0.008260 	||	 Validation Loss: 0.010425
# Epoch: 227 	||	 Training Loss: 0.008100 	||	 Validation Loss: 0.010291
# Epoch: 228 	||	 Training Loss: 0.007945 	||	 Validation Loss: 0.010162
# Epoch: 229 	||	 Training Loss: 0.007796 	||	 Validation Loss: 0.010046
# Epoch: 230 	||	 Training Loss: 0.007659 	||	 Validation Loss: 0.009948
# Epoch: 231 	||	 Training Loss: 0.007535 	||	 Validation Loss: 0.009863
# Epoch: 232 	||	 Training Loss: 0.007426 	||	 Validation Loss: 0.009785
# Epoch: 233 	||	 Training Loss: 0.007328 	||	 Validation Loss: 0.009712
# Epoch: 234 	||	 Training Loss: 0.007239 	||	 Validation Loss: 0.009638
# Epoch: 235 	||	 Training Loss: 0.007155 	||	 Validation Loss: 0.009562
# Epoch: 236 	||	 Training Loss: 0.007075 	||	 Validation Loss: 0.009489
# Epoch: 237 	||	 Training Loss: 0.007000 	||	 Validation Loss: 0.009421
# Epoch: 238 	||	 Training Loss: 0.006930 	||	 Validation Loss: 0.009361
# Epoch: 239 	||	 Training Loss: 0.006866 	||	 Validation Loss: 0.009306
# Epoch: 240 	||	 Training Loss: 0.006808 	||	 Validation Loss: 0.009257
# Epoch: 241 	||	 Training Loss: 0.006754 	||	 Validation Loss: 0.009214
# Epoch: 242 	||	 Training Loss: 0.006704 	||	 Validation Loss: 0.009174
# Epoch: 243 	||	 Training Loss: 0.006659 	||	 Validation Loss: 0.009137
# Epoch: 244 	||	 Training Loss: 0.006617 	||	 Validation Loss: 0.009103
# Epoch: 245 	||	 Training Loss: 0.006579 	||	 Validation Loss: 0.009070
# Epoch: 246 	||	 Training Loss: 0.006543 	||	 Validation Loss: 0.009040
# Epoch: 247 	||	 Training Loss: 0.006511 	||	 Validation Loss: 0.009005
# Epoch: 248 	||	 Training Loss: 0.006479 	||	 Validation Loss: 0.008972
# Epoch: 249 	||	 Training Loss: 0.006449 	||	 Validation Loss: 0.008940
# Epoch: 250 	||	 Training Loss: 0.006421 	||	 Validation Loss: 0.008907
# Epoch: 251 	||	 Training Loss: 0.006395 	||	 Validation Loss: 0.008876
# Epoch: 252 	||	 Training Loss: 0.006370 	||	 Validation Loss: 0.008849
# Epoch: 253 	||	 Training Loss: 0.006347 	||	 Validation Loss: 0.008822
# Epoch: 254 	||	 Training Loss: 0.006326 	||	 Validation Loss: 0.008797
# Epoch: 255 	||	 Training Loss: 0.006305 	||	 Validation Loss: 0.008774
# Epoch: 256 	||	 Training Loss: 0.006285 	||	 Validation Loss: 0.008751
# Epoch: 257 	||	 Training Loss: 0.006266 	||	 Validation Loss: 0.008728
# Epoch: 258 	||	 Training Loss: 0.006247 	||	 Validation Loss: 0.008707
# Epoch: 259 	||	 Training Loss: 0.006230 	||	 Validation Loss: 0.008687
# Epoch: 260 	||	 Training Loss: 0.006213 	||	 Validation Loss: 0.008668
# Epoch: 261 	||	 Training Loss: 0.006196 	||	 Validation Loss: 0.008649
# Epoch: 262 	||	 Training Loss: 0.006180 	||	 Validation Loss: 0.008630
# Epoch: 263 	||	 Training Loss: 0.006165 	||	 Validation Loss: 0.008611
# Epoch: 264 	||	 Training Loss: 0.006150 	||	 Validation Loss: 0.008591
# Epoch: 265 	||	 Training Loss: 0.006135 	||	 Validation Loss: 0.008571
# Epoch: 266 	||	 Training Loss: 0.006121 	||	 Validation Loss: 0.008551
# Epoch: 267 	||	 Training Loss: 0.006107 	||	 Validation Loss: 0.008531
# Epoch: 268 	||	 Training Loss: 0.006093 	||	 Validation Loss: 0.008512
# Epoch: 269 	||	 Training Loss: 0.006080 	||	 Validation Loss: 0.008495
# Epoch: 270 	||	 Training Loss: 0.006067 	||	 Validation Loss: 0.008476
# Epoch: 271 	||	 Training Loss: 0.006054 	||	 Validation Loss: 0.008459
# Epoch: 272 	||	 Training Loss: 0.006042 	||	 Validation Loss: 0.008441
# Epoch: 273 	||	 Training Loss: 0.006029 	||	 Validation Loss: 0.008424
# Epoch: 274 	||	 Training Loss: 0.006017 	||	 Validation Loss: 0.008408
# Epoch: 275 	||	 Training Loss: 0.006006 	||	 Validation Loss: 0.008391
# Epoch: 276 	||	 Training Loss: 0.005995 	||	 Validation Loss: 0.008376
# Epoch: 277 	||	 Training Loss: 0.005984 	||	 Validation Loss: 0.008360
# Epoch: 278 	||	 Training Loss: 0.005973 	||	 Validation Loss: 0.008344
# Epoch: 279 	||	 Training Loss: 0.005962 	||	 Validation Loss: 0.008328
# Epoch: 280 	||	 Training Loss: 0.005952 	||	 Validation Loss: 0.008314
# Epoch: 281 	||	 Training Loss: 0.005942 	||	 Validation Loss: 0.008298
# Epoch: 282 	||	 Training Loss: 0.005932 	||	 Validation Loss: 0.008284
# Epoch: 283 	||	 Training Loss: 0.005922 	||	 Validation Loss: 0.008270
# Epoch: 284 	||	 Training Loss: 0.005913 	||	 Validation Loss: 0.008255
# Epoch: 285 	||	 Training Loss: 0.005904 	||	 Validation Loss: 0.008242
# Epoch: 286 	||	 Training Loss: 0.005895 	||	 Validation Loss: 0.008228
# Epoch: 287 	||	 Training Loss: 0.005886 	||	 Validation Loss: 0.008215
# Epoch: 288 	||	 Training Loss: 0.005877 	||	 Validation Loss: 0.008202
# Epoch: 289 	||	 Training Loss: 0.005869 	||	 Validation Loss: 0.008190
# Epoch: 290 	||	 Training Loss: 0.005861 	||	 Validation Loss: 0.008178
# Epoch: 291 	||	 Training Loss: 0.005853 	||	 Validation Loss: 0.008165
# Epoch: 292 	||	 Training Loss: 0.005845 	||	 Validation Loss: 0.008153
# Epoch: 293 	||	 Training Loss: 0.005838 	||	 Validation Loss: 0.008141
# Epoch: 294 	||	 Training Loss: 0.005830 	||	 Validation Loss: 0.008130
# Epoch: 295 	||	 Training Loss: 0.005824 	||	 Validation Loss: 0.008117
# Epoch: 296 	||	 Training Loss: 0.005816 	||	 Validation Loss: 0.008107
# Epoch: 297 	||	 Training Loss: 0.005810 	||	 Validation Loss: 0.008096
# Epoch: 298 	||	 Training Loss: 0.005803 	||	 Validation Loss: 0.008084
# Epoch: 299 	||	 Training Loss: 0.005797 	||	 Validation Loss: 0.008074
# Epoch: 300 	||	 Training Loss: 0.005790 	||	 Validation Loss: 0.008064
# Epoch: 301 	||	 Training Loss: 0.005784 	||	 Validation Loss: 0.008053
# Epoch: 302 	||	 Training Loss: 0.005778 	||	 Validation Loss: 0.008042
# Epoch: 303 	||	 Training Loss: 0.005772 	||	 Validation Loss: 0.008034
# Epoch: 304 	||	 Training Loss: 0.005766 	||	 Validation Loss: 0.008024
# Epoch: 305 	||	 Training Loss: 0.005760 	||	 Validation Loss: 0.008015
# Epoch: 306 	||	 Training Loss: 0.005755 	||	 Validation Loss: 0.008006
# Epoch: 307 	||	 Training Loss: 0.005749 	||	 Validation Loss: 0.007998
# Epoch: 308 	||	 Training Loss: 0.005744 	||	 Validation Loss: 0.007987
# Epoch: 309 	||	 Training Loss: 0.005738 	||	 Validation Loss: 0.007981
# Epoch: 310 	||	 Training Loss: 0.005733 	||	 Validation Loss: 0.007972
# Epoch: 311 	||	 Training Loss: 0.005728 	||	 Validation Loss: 0.007962
# Epoch: 312 	||	 Training Loss: 0.005723 	||	 Validation Loss: 0.007955
# Epoch: 313 	||	 Training Loss: 0.005718 	||	 Validation Loss: 0.007948
# Epoch: 314 	||	 Training Loss: 0.005714 	||	 Validation Loss: 0.007939
# Epoch: 315 	||	 Training Loss: 0.005709 	||	 Validation Loss: 0.007931
# Epoch: 316 	||	 Training Loss: 0.005705 	||	 Validation Loss: 0.007925
# Epoch: 317 	||	 Training Loss: 0.005700 	||	 Validation Loss: 0.007916
# Epoch: 318 	||	 Training Loss: 0.005696 	||	 Validation Loss: 0.007909
# Epoch: 319 	||	 Training Loss: 0.005691 	||	 Validation Loss: 0.007903
# Epoch: 320 	||	 Training Loss: 0.005687 	||	 Validation Loss: 0.007896
# Epoch: 321 	||	 Training Loss: 0.005683 	||	 Validation Loss: 0.007888
# Epoch: 322 	||	 Training Loss: 0.005679 	||	 Validation Loss: 0.007883
# Epoch: 323 	||	 Training Loss: 0.005675 	||	 Validation Loss: 0.007875
# Epoch: 324 	||	 Training Loss: 0.005671 	||	 Validation Loss: 0.007869
# Epoch: 325 	||	 Training Loss: 0.005667 	||	 Validation Loss: 0.007863
# Epoch: 326 	||	 Training Loss: 0.005663 	||	 Validation Loss: 0.007856
# Epoch: 327 	||	 Training Loss: 0.005660 	||	 Validation Loss: 0.007850
# Epoch: 328 	||	 Training Loss: 0.005656 	||	 Validation Loss: 0.007844
# Epoch: 329 	||	 Training Loss: 0.005653 	||	 Validation Loss: 0.007838
# Epoch: 330 	||	 Training Loss: 0.005649 	||	 Validation Loss: 0.007833
# Epoch: 331 	||	 Training Loss: 0.005645 	||	 Validation Loss: 0.007826
# Epoch: 332 	||	 Training Loss: 0.005642 	||	 Validation Loss: 0.007821
# Epoch: 333 	||	 Training Loss: 0.005639 	||	 Validation Loss: 0.007815
# Epoch: 334 	||	 Training Loss: 0.005635 	||	 Validation Loss: 0.007810
# Epoch: 335 	||	 Training Loss: 0.005632 	||	 Validation Loss: 0.007804
# Epoch: 336 	||	 Training Loss: 0.005629 	||	 Validation Loss: 0.007799
# Epoch: 337 	||	 Training Loss: 0.005626 	||	 Validation Loss: 0.007793
# Epoch: 338 	||	 Training Loss: 0.005623 	||	 Validation Loss: 0.007789
# Epoch: 339 	||	 Training Loss: 0.005620 	||	 Validation Loss: 0.007783
# Epoch: 340 	||	 Training Loss: 0.005617 	||	 Validation Loss: 0.007778
# Epoch: 341 	||	 Training Loss: 0.005614 	||	 Validation Loss: 0.007773
# Epoch: 342 	||	 Training Loss: 0.005611 	||	 Validation Loss: 0.007769
# Epoch: 343 	||	 Training Loss: 0.005608 	||	 Validation Loss: 0.007763
# Epoch: 344 	||	 Training Loss: 0.005606 	||	 Validation Loss: 0.007759
# Epoch: 345 	||	 Training Loss: 0.005603 	||	 Validation Loss: 0.007754
# Epoch: 346 	||	 Training Loss: 0.005600 	||	 Validation Loss: 0.007750
# Epoch: 347 	||	 Training Loss: 0.005598 	||	 Validation Loss: 0.007744
# Epoch: 348 	||	 Training Loss: 0.005595 	||	 Validation Loss: 0.007741
# Epoch: 349 	||	 Training Loss: 0.005592 	||	 Validation Loss: 0.007736
# Epoch: 350 	||	 Training Loss: 0.005590 	||	 Validation Loss: 0.007730
# Epoch: 351 	||	 Training Loss: 0.005587 	||	 Validation Loss: 0.007728
# Epoch: 352 	||	 Training Loss: 0.005585 	||	 Validation Loss: 0.007722
# Epoch: 353 	||	 Training Loss: 0.005582 	||	 Validation Loss: 0.007718
# Epoch: 354 	||	 Training Loss: 0.005580 	||	 Validation Loss: 0.007713
# Epoch: 355 	||	 Training Loss: 0.005578 	||	 Validation Loss: 0.007711
# Epoch: 356 	||	 Training Loss: 0.005576 	||	 Validation Loss: 0.007704
# Epoch: 357 	||	 Training Loss: 0.005573 	||	 Validation Loss: 0.007703
# Epoch: 358 	||	 Training Loss: 0.005571 	||	 Validation Loss: 0.007698
# Epoch: 359 	||	 Training Loss: 0.005569 	||	 Validation Loss: 0.007692
# Epoch: 360 	||	 Training Loss: 0.005567 	||	 Validation Loss: 0.007691
# Epoch: 361 	||	 Training Loss: 0.005565 	||	 Validation Loss: 0.007685
# Epoch: 362 	||	 Training Loss: 0.005563 	||	 Validation Loss: 0.007681
# Epoch: 363 	||	 Training Loss: 0.005561 	||	 Validation Loss: 0.007679
# Epoch: 364 	||	 Training Loss: 0.005559 	||	 Validation Loss: 0.007673
# Epoch: 365 	||	 Training Loss: 0.005557 	||	 Validation Loss: 0.007671
# Epoch: 366 	||	 Training Loss: 0.005555 	||	 Validation Loss: 0.007666
# Epoch: 367 	||	 Training Loss: 0.005553 	||	 Validation Loss: 0.007663
# Epoch: 368 	||	 Training Loss: 0.005551 	||	 Validation Loss: 0.007660
# Epoch: 369 	||	 Training Loss: 0.005549 	||	 Validation Loss: 0.007655
# Epoch: 370 	||	 Training Loss: 0.005547 	||	 Validation Loss: 0.007654
# Epoch: 371 	||	 Training Loss: 0.005545 	||	 Validation Loss: 0.007648
# Epoch: 372 	||	 Training Loss: 0.005543 	||	 Validation Loss: 0.007645
# Epoch: 373 	||	 Training Loss: 0.005542 	||	 Validation Loss: 0.007642
# Epoch: 374 	||	 Training Loss: 0.005540 	||	 Validation Loss: 0.007638
# Epoch: 375 	||	 Training Loss: 0.005538 	||	 Validation Loss: 0.007636
# Epoch: 376 	||	 Training Loss: 0.005537 	||	 Validation Loss: 0.007633
# Epoch: 377 	||	 Training Loss: 0.005535 	||	 Validation Loss: 0.007628
# Epoch: 378 	||	 Training Loss: 0.005533 	||	 Validation Loss: 0.007626
# Epoch: 379 	||	 Training Loss: 0.005532 	||	 Validation Loss: 0.007622
# Epoch: 380 	||	 Training Loss: 0.005530 	||	 Validation Loss: 0.007618
# Epoch: 381 	||	 Training Loss: 0.005528 	||	 Validation Loss: 0.007617
# Epoch: 382 	||	 Training Loss: 0.005527 	||	 Validation Loss: 0.007612
# Epoch: 383 	||	 Training Loss: 0.005525 	||	 Validation Loss: 0.007610
# Epoch: 384 	||	 Training Loss: 0.005524 	||	 Validation Loss: 0.007608
# Epoch: 385 	||	 Training Loss: 0.005522 	||	 Validation Loss: 0.007603
# Epoch: 386 	||	 Training Loss: 0.005521 	||	 Validation Loss: 0.007601
# Epoch: 387 	||	 Training Loss: 0.005519 	||	 Validation Loss: 0.007598
# Epoch: 388 	||	 Training Loss: 0.005518 	||	 Validation Loss: 0.007596
# Epoch: 389 	||	 Training Loss: 0.005516 	||	 Validation Loss: 0.007591
# Epoch: 390 	||	 Training Loss: 0.005515 	||	 Validation Loss: 0.007590
# Epoch: 391 	||	 Training Loss: 0.005514 	||	 Validation Loss: 0.007586
# Epoch: 392 	||	 Training Loss: 0.005512 	||	 Validation Loss: 0.007583
# Epoch: 393 	||	 Training Loss: 0.005511 	||	 Validation Loss: 0.007582
# Epoch: 394 	||	 Training Loss: 0.005510 	||	 Validation Loss: 0.007576
# Epoch: 395 	||	 Training Loss: 0.005508 	||	 Validation Loss: 0.007577
# Epoch: 396 	||	 Training Loss: 0.005507 	||	 Validation Loss: 0.007572
# Epoch: 397 	||	 Training Loss: 0.005506 	||	 Validation Loss: 0.007571
# Epoch: 398 	||	 Training Loss: 0.005505 	||	 Validation Loss: 0.007568
# Epoch: 399 	||	 Training Loss: 0.005503 	||	 Validation Loss: 0.007565
# Epoch: 400 	||	 Training Loss: 0.005502 	||	 Validation Loss: 0.007562
# Epoch: 401 	||	 Training Loss: 0.005501 	||	 Validation Loss: 0.007560
# Epoch: 402 	||	 Training Loss: 0.005499 	||	 Validation Loss: 0.007558
# Epoch: 403 	||	 Training Loss: 0.005498 	||	 Validation Loss: 0.007554
# Epoch: 404 	||	 Training Loss: 0.005497 	||	 Validation Loss: 0.007554
# Epoch: 405 	||	 Training Loss: 0.005496 	||	 Validation Loss: 0.007549
# Epoch: 406 	||	 Training Loss: 0.005495 	||	 Validation Loss: 0.007547
# Epoch: 407 	||	 Training Loss: 0.005494 	||	 Validation Loss: 0.007546
# Epoch: 408 	||	 Training Loss: 0.005493 	||	 Validation Loss: 0.007541
# Epoch: 409 	||	 Training Loss: 0.005491 	||	 Validation Loss: 0.007541
# Epoch: 410 	||	 Training Loss: 0.005490 	||	 Validation Loss: 0.007538
# Epoch: 411 	||	 Training Loss: 0.005489 	||	 Validation Loss: 0.007535
# Epoch: 412 	||	 Training Loss: 0.005488 	||	 Validation Loss: 0.007534
# Epoch: 413 	||	 Training Loss: 0.005487 	||	 Validation Loss: 0.007531
# Epoch: 414 	||	 Training Loss: 0.005486 	||	 Validation Loss: 0.007528
# Epoch: 415 	||	 Training Loss: 0.005485 	||	 Validation Loss: 0.007528
# Epoch: 416 	||	 Training Loss: 0.005484 	||	 Validation Loss: 0.007524
# Epoch: 417 	||	 Training Loss: 0.005483 	||	 Validation Loss: 0.007521
# Epoch: 418 	||	 Training Loss: 0.005482 	||	 Validation Loss: 0.007521
# Epoch: 419 	||	 Training Loss: 0.005481 	||	 Validation Loss: 0.007517
# Epoch: 420 	||	 Training Loss: 0.005480 	||	 Validation Loss: 0.007516
# Epoch: 421 	||	 Training Loss: 0.005479 	||	 Validation Loss: 0.007514
# Epoch: 422 	||	 Training Loss: 0.005478 	||	 Validation Loss: 0.007512
# Epoch: 423 	||	 Training Loss: 0.005477 	||	 Validation Loss: 0.007509
# Epoch: 424 	||	 Training Loss: 0.005476 	||	 Validation Loss: 0.007509
# Epoch: 425 	||	 Training Loss: 0.005475 	||	 Validation Loss: 0.007504
# Epoch: 426 	||	 Training Loss: 0.005474 	||	 Validation Loss: 0.007504
# Epoch: 427 	||	 Training Loss: 0.005474 	||	 Validation Loss: 0.007502
# Epoch: 428 	||	 Training Loss: 0.005473 	||	 Validation Loss: 0.007498
# Epoch: 429 	||	 Training Loss: 0.005472 	||	 Validation Loss: 0.007497
# Epoch: 430 	||	 Training Loss: 0.005471 	||	 Validation Loss: 0.007495
# Epoch: 431 	||	 Training Loss: 0.005470 	||	 Validation Loss: 0.007493
# Epoch: 432 	||	 Training Loss: 0.005469 	||	 Validation Loss: 0.007492
# Epoch: 433 	||	 Training Loss: 0.005468 	||	 Validation Loss: 0.007489
# Epoch: 434 	||	 Training Loss: 0.005468 	||	 Validation Loss: 0.007488
# Epoch: 435 	||	 Training Loss: 0.005467 	||	 Validation Loss: 0.007485
# Epoch: 436 	||	 Training Loss: 0.005466 	||	 Validation Loss: 0.007484
# Epoch: 437 	||	 Training Loss: 0.005465 	||	 Validation Loss: 0.007482
# Epoch: 438 	||	 Training Loss: 0.005464 	||	 Validation Loss: 0.007480
# Epoch: 439 	||	 Training Loss: 0.005463 	||	 Validation Loss: 0.007480
# Epoch: 440 	||	 Training Loss: 0.005463 	||	 Validation Loss: 0.007475
# Epoch: 441 	||	 Training Loss: 0.005462 	||	 Validation Loss: 0.007476
# Epoch: 442 	||	 Training Loss: 0.005461 	||	 Validation Loss: 0.007472
# Epoch: 443 	||	 Training Loss: 0.005460 	||	 Validation Loss: 0.007473
# Epoch: 444 	||	 Training Loss: 0.005460 	||	 Validation Loss: 0.007468
# Epoch: 445 	||	 Training Loss: 0.005459 	||	 Validation Loss: 0.007468
# Epoch: 446 	||	 Training Loss: 0.005458 	||	 Validation Loss: 0.007467
# Epoch: 447 	||	 Training Loss: 0.005457 	||	 Validation Loss: 0.007462
# Epoch: 448 	||	 Training Loss: 0.005457 	||	 Validation Loss: 0.007466
# Epoch: 449 	||	 Training Loss: 0.005456 	||	 Validation Loss: 0.007459
# Epoch: 450 	||	 Training Loss: 0.005455 	||	 Validation Loss: 0.007459
# Epoch: 451 	||	 Training Loss: 0.005454 	||	 Validation Loss: 0.007460
# Epoch: 452 	||	 Training Loss: 0.005454 	||	 Validation Loss: 0.007452
# Epoch: 453 	||	 Training Loss: 0.005453 	||	 Validation Loss: 0.007457
# Epoch: 454 	||	 Training Loss: 0.005452 	||	 Validation Loss: 0.007452
# Epoch: 455 	||	 Training Loss: 0.005452 	||	 Validation Loss: 0.007449
# Epoch: 456 	||	 Training Loss: 0.005451 	||	 Validation Loss: 0.007453
# Epoch: 457 	||	 Training Loss: 0.005450 	||	 Validation Loss: 0.007444
# Epoch: 458 	||	 Training Loss: 0.005450 	||	 Validation Loss: 0.007449
# Epoch: 459 	||	 Training Loss: 0.005449 	||	 Validation Loss: 0.007445
# Epoch: 460 	||	 Training Loss: 0.005449 	||	 Validation Loss: 0.007441
# Epoch: 461 	||	 Training Loss: 0.005448 	||	 Validation Loss: 0.007445
# Epoch: 462 	||	 Training Loss: 0.005447 	||	 Validation Loss: 0.007438
# Epoch: 463 	||	 Training Loss: 0.005447 	||	 Validation Loss: 0.007439
# Epoch: 464 	||	 Training Loss: 0.005446 	||	 Validation Loss: 0.007439
# Epoch: 465 	||	 Training Loss: 0.005445 	||	 Validation Loss: 0.007432
# Epoch: 466 	||	 Training Loss: 0.005445 	||	 Validation Loss: 0.007438
# Epoch: 467 	||	 Training Loss: 0.005444 	||	 Validation Loss: 0.007429
# Epoch: 468 	||	 Training Loss: 0.005443 	||	 Validation Loss: 0.007434
# Epoch: 469 	||	 Training Loss: 0.005443 	||	 Validation Loss: 0.007429
# Epoch: 470 	||	 Training Loss: 0.005442 	||	 Validation Loss: 0.007428
# Epoch: 471 	||	 Training Loss: 0.005442 	||	 Validation Loss: 0.007429
# Epoch: 472 	||	 Training Loss: 0.005441 	||	 Validation Loss: 0.007423
# Epoch: 473 	||	 Training Loss: 0.005441 	||	 Validation Loss: 0.007426
# Epoch: 474 	||	 Training Loss: 0.005440 	||	 Validation Loss: 0.007422
# Epoch: 475 	||	 Training Loss: 0.005439 	||	 Validation Loss: 0.007420
# Epoch: 476 	||	 Training Loss: 0.005439 	||	 Validation Loss: 0.007422
# Epoch: 477 	||	 Training Loss: 0.005438 	||	 Validation Loss: 0.007416
# Epoch: 478 	||	 Training Loss: 0.005438 	||	 Validation Loss: 0.007420
# Epoch: 479 	||	 Training Loss: 0.005437 	||	 Validation Loss: 0.007414
# Epoch: 480 	||	 Training Loss: 0.005437 	||	 Validation Loss: 0.007415
# Epoch: 481 	||	 Training Loss: 0.005436 	||	 Validation Loss: 0.007413
# Epoch: 482 	||	 Training Loss: 0.005435 	||	 Validation Loss: 0.007411
# Epoch: 483 	||	 Training Loss: 0.005435 	||	 Validation Loss: 0.007411
# Epoch: 484 	||	 Training Loss: 0.005434 	||	 Validation Loss: 0.007409
# Epoch: 485 	||	 Training Loss: 0.005434 	||	 Validation Loss: 0.007407
# Epoch: 486 	||	 Training Loss: 0.005433 	||	 Validation Loss: 0.007408
# Epoch: 487 	||	 Training Loss: 0.005433 	||	 Validation Loss: 0.007404
# Epoch: 488 	||	 Training Loss: 0.005433 	||	 Validation Loss: 0.007404
# Epoch: 489 	||	 Training Loss: 0.005432 	||	 Validation Loss: 0.007404
# Epoch: 490 	||	 Training Loss: 0.005431 	||	 Validation Loss: 0.007400
# Epoch: 491 	||	 Training Loss: 0.005431 	||	 Validation Loss: 0.007401
# Epoch: 492 	||	 Training Loss: 0.005430 	||	 Validation Loss: 0.007399
# Epoch: 493 	||	 Training Loss: 0.005430 	||	 Validation Loss: 0.007397
# Epoch: 494 	||	 Training Loss: 0.005429 	||	 Validation Loss: 0.007397
# Epoch: 495 	||	 Training Loss: 0.005429 	||	 Validation Loss: 0.007395
# Epoch: 496 	||	 Training Loss: 0.005428 	||	 Validation Loss: 0.007394
# Epoch: 497 	||	 Training Loss: 0.005428 	||	 Validation Loss: 0.007392
# Epoch: 498 	||	 Training Loss: 0.005428 	||	 Validation Loss: 0.007392
# Epoch: 499 	||	 Training Loss: 0.005427 	||	 Validation Loss: 0.007390
# Epoch: 500 	||	 Training Loss: 0.005427 	||	 Validation Loss: 0.007389
# Epoch: 501 	||	 Training Loss: 0.005426 	||	 Validation Loss: 0.007388
# Epoch: 502 	||	 Training Loss: 0.005426 	||	 Validation Loss: 0.007387
# Epoch: 503 	||	 Training Loss: 0.005425 	||	 Validation Loss: 0.007387
# Epoch: 504 	||	 Training Loss: 0.005425 	||	 Validation Loss: 0.007384
# Epoch: 505 	||	 Training Loss: 0.005424 	||	 Validation Loss: 0.007386
# Epoch: 506 	||	 Training Loss: 0.005424 	||	 Validation Loss: 0.007380
# Epoch: 507 	||	 Training Loss: 0.005424 	||	 Validation Loss: 0.007383
# Epoch: 508 	||	 Training Loss: 0.005423 	||	 Validation Loss: 0.007380
# Epoch: 509 	||	 Training Loss: 0.005423 	||	 Validation Loss: 0.007378
# Epoch: 510 	||	 Training Loss: 0.005422 	||	 Validation Loss: 0.007382
# Epoch: 511 	||	 Training Loss: 0.005422 	||	 Validation Loss: 0.007372
# Epoch: 512 	||	 Training Loss: 0.005421 	||	 Validation Loss: 0.007380
# Epoch: 513 	||	 Training Loss: 0.005421 	||	 Validation Loss: 0.007372
# Epoch: 514 	||	 Training Loss: 0.005421 	||	 Validation Loss: 0.007374
# Epoch: 515 	||	 Training Loss: 0.005420 	||	 Validation Loss: 0.007374
# Epoch: 516 	||	 Training Loss: 0.005420 	||	 Validation Loss: 0.007369
# Epoch: 517 	||	 Training Loss: 0.005419 	||	 Validation Loss: 0.007374
# Epoch: 518 	||	 Training Loss: 0.005419 	||	 Validation Loss: 0.007366
# Epoch: 519 	||	 Training Loss: 0.005418 	||	 Validation Loss: 0.007372
# Epoch: 520 	||	 Training Loss: 0.005418 	||	 Validation Loss: 0.007363
# Epoch: 521 	||	 Training Loss: 0.005418 	||	 Validation Loss: 0.007370
# Epoch: 522 	||	 Training Loss: 0.005417 	||	 Validation Loss: 0.007363
# Epoch: 523 	||	 Training Loss: 0.005417 	||	 Validation Loss: 0.007365
# Epoch: 524 	||	 Training Loss: 0.005416 	||	 Validation Loss: 0.007365
# Epoch: 525 	||	 Training Loss: 0.005416 	||	 Validation Loss: 0.007358
# Epoch: 526 	||	 Training Loss: 0.005416 	||	 Validation Loss: 0.007367
# Epoch: 527 	||	 Training Loss: 0.005415 	||	 Validation Loss: 0.007354
# Epoch: 528 	||	 Training Loss: 0.005415 	||	 Validation Loss: 0.007364
# Epoch: 529 	||	 Training Loss: 0.005415 	||	 Validation Loss: 0.007356
# Epoch: 530 	||	 Training Loss: 0.005414 	||	 Validation Loss: 0.007357
# Epoch: 531 	||	 Training Loss: 0.005414 	||	 Validation Loss: 0.007359
# Epoch: 532 	||	 Training Loss: 0.005414 	||	 Validation Loss: 0.007350
# Epoch: 533 	||	 Training Loss: 0.005413 	||	 Validation Loss: 0.007361
# Epoch: 534 	||	 Training Loss: 0.005413 	||	 Validation Loss: 0.007348
# Epoch: 535 	||	 Training Loss: 0.005413 	||	 Validation Loss: 0.007357
# Epoch: 536 	||	 Training Loss: 0.005412 	||	 Validation Loss: 0.007349
# Epoch: 537 	||	 Training Loss: 0.005412 	||	 Validation Loss: 0.007351
# Epoch: 538 	||	 Training Loss: 0.005411 	||	 Validation Loss: 0.007351
# Epoch: 539 	||	 Training Loss: 0.005411 	||	 Validation Loss: 0.007345
# Epoch: 540 	||	 Training Loss: 0.005411 	||	 Validation Loss: 0.007353
# Epoch: 541 	||	 Training Loss: 0.005410 	||	 Validation Loss: 0.007341
# Epoch: 542 	||	 Training Loss: 0.005410 	||	 Validation Loss: 0.007351
# Epoch: 543 	||	 Training Loss: 0.005410 	||	 Validation Loss: 0.007340
# Epoch: 544 	||	 Training Loss: 0.005409 	||	 Validation Loss: 0.007348
# Epoch: 545 	||	 Training Loss: 0.005409 	||	 Validation Loss: 0.007341
# Epoch: 546 	||	 Training Loss: 0.005409 	||	 Validation Loss: 0.007343
# Epoch: 547 	||	 Training Loss: 0.005408 	||	 Validation Loss: 0.007343
# Epoch: 548 	||	 Training Loss: 0.005408 	||	 Validation Loss: 0.007338
# Epoch: 549 	||	 Training Loss: 0.005408 	||	 Validation Loss: 0.007344
# Epoch: 550 	||	 Training Loss: 0.005407 	||	 Validation Loss: 0.007335
# Epoch: 551 	||	 Training Loss: 0.005407 	||	 Validation Loss: 0.007341
# Epoch: 552 	||	 Training Loss: 0.005407 	||	 Validation Loss: 0.007335
# Epoch: 553 	||	 Training Loss: 0.005406 	||	 Validation Loss: 0.007337
# Epoch: 554 	||	 Training Loss: 0.005406 	||	 Validation Loss: 0.007337
# Epoch: 555 	||	 Training Loss: 0.005406 	||	 Validation Loss: 0.007331
# Epoch: 556 	||	 Training Loss: 0.005405 	||	 Validation Loss: 0.007340
# Epoch: 557 	||	 Training Loss: 0.005405 	||	 Validation Loss: 0.007325
# Epoch: 558 	||	 Training Loss: 0.005405 	||	 Validation Loss: 0.007341
# Epoch: 559 	||	 Training Loss: 0.005404 	||	 Validation Loss: 0.007322
# Epoch: 560 	||	 Training Loss: 0.005404 	||	 Validation Loss: 0.007340
# Epoch: 561 	||	 Training Loss: 0.005404 	||	 Validation Loss: 0.007321
# Epoch: 562 	||	 Training Loss: 0.005403 	||	 Validation Loss: 0.007336
# Epoch: 563 	||	 Training Loss: 0.005403 	||	 Validation Loss: 0.007322
# Epoch: 564 	||	 Training Loss: 0.005403 	||	 Validation Loss: 0.007330
# Epoch: 565 	||	 Training Loss: 0.005403 	||	 Validation Loss: 0.007328
# Epoch: 566 	||	 Training Loss: 0.005402 	||	 Validation Loss: 0.007321
# Epoch: 567 	||	 Training Loss: 0.005402 	||	 Validation Loss: 0.007332
# Epoch: 568 	||	 Training Loss: 0.005402 	||	 Validation Loss: 0.007316
# Epoch: 569 	||	 Training Loss: 0.005401 	||	 Validation Loss: 0.007332
# Epoch: 570 	||	 Training Loss: 0.005401 	||	 Validation Loss: 0.007315
# Epoch: 571 	||	 Training Loss: 0.005401 	||	 Validation Loss: 0.007328
# Epoch: 572 	||	 Training Loss: 0.005401 	||	 Validation Loss: 0.007317
# Epoch: 573 	||	 Training Loss: 0.005400 	||	 Validation Loss: 0.007321
# Epoch: 574 	||	 Training Loss: 0.005400 	||	 Validation Loss: 0.007323
# Epoch: 575 	||	 Training Loss: 0.005400 	||	 Validation Loss: 0.007312
# Epoch: 576 	||	 Training Loss: 0.005399 	||	 Validation Loss: 0.007328
# Epoch: 577 	||	 Training Loss: 0.005399 	||	 Validation Loss: 0.007305
# Epoch: 578 	||	 Training Loss: 0.005399 	||	 Validation Loss: 0.007330
# Epoch: 579 	||	 Training Loss: 0.005399 	||	 Validation Loss: 0.007301
# Epoch: 580 	||	 Training Loss: 0.005398 	||	 Validation Loss: 0.007330
# Epoch: 581 	||	 Training Loss: 0.005398 	||	 Validation Loss: 0.007300
# Epoch: 582 	||	 Training Loss: 0.005398 	||	 Validation Loss: 0.007328
# Epoch: 583 	||	 Training Loss: 0.005398 	||	 Validation Loss: 0.007299
# Epoch: 584 	||	 Training Loss: 0.005397 	||	 Validation Loss: 0.007326
# Epoch: 585 	||	 Training Loss: 0.005397 	||	 Validation Loss: 0.007299
# Epoch: 586 	||	 Training Loss: 0.005397 	||	 Validation Loss: 0.007323
# Epoch: 587 	||	 Training Loss: 0.005397 	||	 Validation Loss: 0.007298
# Epoch: 588 	||	 Training Loss: 0.005396 	||	 Validation Loss: 0.007321
# Epoch: 589 	||	 Training Loss: 0.005396 	||	 Validation Loss: 0.007297
# Epoch: 590 	||	 Training Loss: 0.005396 	||	 Validation Loss: 0.007319
# Epoch: 591 	||	 Training Loss: 0.005395 	||	 Validation Loss: 0.007295
# Epoch: 592 	||	 Training Loss: 0.005395 	||	 Validation Loss: 0.007320
# Epoch: 593 	||	 Training Loss: 0.005395 	||	 Validation Loss: 0.007291
# Epoch: 594 	||	 Training Loss: 0.005395 	||	 Validation Loss: 0.007322
# Epoch: 595 	||	 Training Loss: 0.005394 	||	 Validation Loss: 0.007286
# Epoch: 596 	||	 Training Loss: 0.005394 	||	 Validation Loss: 0.007324
# Epoch: 597 	||	 Training Loss: 0.005394 	||	 Validation Loss: 0.007280
# Epoch: 598 	||	 Training Loss: 0.005394 	||	 Validation Loss: 0.007329
# Epoch: 599 	||	 Training Loss: 0.005394 	||	 Validation Loss: 0.007272
# Epoch: 600 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007335
# Epoch: 601 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007264
# Epoch: 602 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007341
# Epoch: 603 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007256
# Epoch: 604 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007348
# Epoch: 605 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007247
# Epoch: 606 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007355
# Epoch: 607 	||	 Training Loss: 0.005392 	||	 Validation Loss: 0.007239
# Epoch: 608 	||	 Training Loss: 0.005393 	||	 Validation Loss: 0.007360
# Epoch: 609 	||	 Training Loss: 0.005392 	||	 Validation Loss: 0.007234
# Epoch: 610 	||	 Training Loss: 0.005392 	||	 Validation Loss: 0.007361
# Epoch: 611 	||	 Training Loss: 0.005392 	||	 Validation Loss: 0.007234
# Epoch: 612 	||	 Training Loss: 0.005392 	||	 Validation Loss: 0.007356
# Epoch: 613 	||	 Training Loss: 0.005391 	||	 Validation Loss: 0.007239
# Epoch: 614 	||	 Training Loss: 0.005391 	||	 Validation Loss: 0.007343
# Epoch: 615 	||	 Training Loss: 0.005390 	||	 Validation Loss: 0.007252
# Epoch: 616 	||	 Training Loss: 0.005390 	||	 Validation Loss: 0.007323
# Epoch: 617 	||	 Training Loss: 0.005389 	||	 Validation Loss: 0.007270
# Epoch: 618 	||	 Training Loss: 0.005389 	||	 Validation Loss: 0.007301
# Epoch: 619 	||	 Training Loss: 0.005389 	||	 Validation Loss: 0.007287
# Epoch: 620 	||	 Training Loss: 0.005388 	||	 Validation Loss: 0.007284
# Epoch: 621 	||	 Training Loss: 0.005388 	||	 Validation Loss: 0.007297
# Epoch: 622 	||	 Training Loss: 0.005388 	||	 Validation Loss: 0.007274
# Epoch: 623 	||	 Training Loss: 0.005388 	||	 Validation Loss: 0.007303
# Epoch: 624 	||	 Training Loss: 0.005388 	||	 Validation Loss: 0.007267
# Epoch: 625 	||	 Training Loss: 0.005387 	||	 Validation Loss: 0.007308
# Epoch: 626 	||	 Training Loss: 0.005387 	||	 Validation Loss: 0.007262
# Epoch: 627 	||	 Training Loss: 0.005387 	||	 Validation Loss: 0.007309
# Epoch: 628 	||	 Training Loss: 0.005387 	||	 Validation Loss: 0.007261
# Epoch: 629 	||	 Training Loss: 0.005387 	||	 Validation Loss: 0.007306
# Epoch: 630 	||	 Training Loss: 0.005386 	||	 Validation Loss: 0.007262
# Epoch: 631 	||	 Training Loss: 0.005386 	||	 Validation Loss: 0.007302
# Epoch: 632 	||	 Training Loss: 0.005386 	||	 Validation Loss: 0.007264
# Epoch: 633 	||	 Training Loss: 0.005386 	||	 Validation Loss: 0.007298
# Epoch: 634 	||	 Training Loss: 0.005385 	||	 Validation Loss: 0.007266
# Epoch: 635 	||	 Training Loss: 0.005385 	||	 Validation Loss: 0.007294
# Epoch: 636 	||	 Training Loss: 0.005385 	||	 Validation Loss: 0.007267
# Epoch: 637 	||	 Training Loss: 0.005385 	||	 Validation Loss: 0.007291
# Epoch: 638 	||	 Training Loss: 0.005385 	||	 Validation Loss: 0.007267
# Epoch: 639 	||	 Training Loss: 0.005384 	||	 Validation Loss: 0.007290
# Epoch: 640 	||	 Training Loss: 0.005384 	||	 Validation Loss: 0.007264
# Epoch: 641 	||	 Training Loss: 0.005384 	||	 Validation Loss: 0.007291
# Epoch: 642 	||	 Training Loss: 0.005384 	||	 Validation Loss: 0.007261
# Epoch: 643 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007294
# Epoch: 644 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007256
# Epoch: 645 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007298
# Epoch: 646 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007249
# Epoch: 647 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007304
# Epoch: 648 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007239
# Epoch: 649 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007314
# Epoch: 650 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007226
# Epoch: 651 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007328
# Epoch: 652 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007211
# Epoch: 653 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007343
# Epoch: 654 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007196
# Epoch: 655 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007356
# Epoch: 656 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007187
# Epoch: 657 	||	 Training Loss: 0.005384 	||	 Validation Loss: 0.007358
# Epoch: 658 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007193
# Epoch: 659 	||	 Training Loss: 0.005383 	||	 Validation Loss: 0.007338
# Epoch: 660 	||	 Training Loss: 0.005382 	||	 Validation Loss: 0.007220
# Epoch: 661 	||	 Training Loss: 0.005381 	||	 Validation Loss: 0.007298
# Epoch: 662 	||	 Training Loss: 0.005380 	||	 Validation Loss: 0.007259
# Epoch: 663 	||	 Training Loss: 0.005380 	||	 Validation Loss: 0.007255
# Epoch: 664 	||	 Training Loss: 0.005379 	||	 Validation Loss: 0.007294
# Epoch: 665 	||	 Training Loss: 0.005379 	||	 Validation Loss: 0.007223
# Epoch: 666 	||	 Training Loss: 0.005380 	||	 Validation Loss: 0.007317
# Epoch: 667 	||	 Training Loss: 0.005380 	||	 Validation Loss: 0.007208
# Epoch: 668 	||	 Training Loss: 0.005380 	||	 Validation Loss: 0.007324
# Epoch: 669 	||	 Training Loss: 0.005380 	||	 Validation Loss: 0.007209
# Epoch: 670 	||	 Training Loss: 0.005379 	||	 Validation Loss: 0.007313
# Epoch: 671 	||	 Training Loss: 0.005379 	||	 Validation Loss: 0.007226
# Epoch: 672 	||	 Training Loss: 0.005378 	||	 Validation Loss: 0.007286
# Epoch: 673 	||	 Training Loss: 0.005378 	||	 Validation Loss: 0.007253
# Epoch: 674 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007256
# Epoch: 675 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007278
# Epoch: 676 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007233
# Epoch: 677 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007293
# Epoch: 678 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007223
# Epoch: 679 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007297
# Epoch: 680 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007224
# Epoch: 681 	||	 Training Loss: 0.005377 	||	 Validation Loss: 0.007289
# Epoch: 682 	||	 Training Loss: 0.005376 	||	 Validation Loss: 0.007233
# Epoch: 683 	||	 Training Loss: 0.005376 	||	 Validation Loss: 0.007275
# Epoch: 684 	||	 Training Loss: 0.005376 	||	 Validation Loss: 0.007245
# Epoch: 685 	||	 Training Loss: 0.005376 	||	 Validation Loss: 0.007261
# Epoch: 686 	||	 Training Loss: 0.005375 	||	 Validation Loss: 0.007257
# Epoch: 687 	||	 Training Loss: 0.005375 	||	 Validation Loss: 0.007248
# Epoch: 688 	||	 Training Loss: 0.005375 	||	 Validation Loss: 0.007266
# Epoch: 689 	||	 Training Loss: 0.005375 	||	 Validation Loss: 0.007241
# Epoch: 690 	||	 Training Loss: 0.005375 	||	 Validation Loss: 0.007271
# Epoch: 691 	||	 Training Loss: 0.005375 	||	 Validation Loss: 0.007236
# Epoch: 692 	||	 Training Loss: 0.005374 	||	 Validation Loss: 0.007273
# Epoch: 693 	||	 Training Loss: 0.005374 	||	 Validation Loss: 0.007233
# Epoch: 694 	||	 Training Loss: 0.005374 	||	 Validation Loss: 0.007273
# Epoch: 695 	||	 Training Loss: 0.005374 	||	 Validation Loss: 0.007232
# Epoch: 696 	||	 Training Loss: 0.005374 	||	 Validation Loss: 0.007272
# Epoch: 697 	||	 Training Loss: 0.005374 	||	 Validation Loss: 0.007230
# Epoch: 698 	||	 Training Loss: 0.005373 	||	 Validation Loss: 0.007271
# Epoch: 699 	||	 Training Loss: 0.005373 	||	 Validation Loss: 0.007231
# Epoch: 700 	||	 Training Loss: 0.005373 	||	 Validation Loss: 0.007267

# %% [markdown]
# #### test 101 I

# %%
# --------------Plot identification results for G-----------------

patient_model_folder_101_I = f"./models/REN/101_I/{exp_identifier}"
MODEL_PATH = Path(patient_model_folder_101_I)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])

# ----------------------------------

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs'); plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs  101 I')
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()


y0_1 = fun_start_controller_simple(train_loader_p_101_I, dataset_101_I)

REN_1_101 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

#########################################################

y0_1 = fun_start_controller_simple(test_loader_101_I, dataset_101_I)
REN_1_101.reset(y0 = -y0_1.unsqueeze(1))


checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")
REN_1_101.load_state_dict(checkpoint["REN_1_101_state_dict"])

#################################################################

for _, u1_batch, y_batch, time_batch in train_loader_p_101_I:

    u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)
    
    REN_1_101.reset(y0 = -y_batch[:,:1,:1])

    y1_hat = REN_1_101(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = - y1_hat
    
    loss_train = MSE(y_hat, y_batch)

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

print(f"Loss train: {loss_train}")

fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Insulin (u1)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u1_batch[0,:,0].numpy(), color=color, label='Insulin')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Insulin vs Time, Train')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()



#####################################################################################


for _, u1_batch, y_batch, time_batch in test_loader_101_I:

    u1_batch, y_batch, time_batch = ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time_batch)

    REN_1_101.reset(y0 = -y_batch[:,:1,:1])
    y1_hat = REN_1_101(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = -y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()


fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Insulin (u1)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u1_batch[0,:,0].numpy(), color=color, label='Insulin')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Insulin vs Time, Test')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_17500\618630813.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# Loss train: 0.0053728362545371056

# %% [markdown]
# #### 101 M

# %%
optimizer = torch.optim.Adam( list(REN_0_101.parameters()),   lr=learning_rate)
optimizer.zero_grad()

epochs = 700

#--------------------------5. Training---------------------------------------------------------------------

torch.set_default_device(device)      # default tensor device
torch.set_default_dtype(torch.float32)  # default tensor dtype
print(f"[INFO] Training on device: {device}")

REN_0_101.to(device)
train_losses = []
val_losses = []  # Store validation losses across epochs
for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_0_101.train()
    loss_epoch = 0.0  # Accumulate training loss

    
    for u0_batch, _, y_batch, time_batch in train_loader_p_101_M: # MH, I_rec (PID), CGM, time
        
        torch.save({'u0_batch': u0_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_train_meal.pt')

        

        u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)
        u0_batch, y_batch, time_batch = u0_batch.to(device), y_batch.to(device), time_batch.to(device)
        
        optimizer.zero_grad()
        
        # REN_0_101.reset(y0 = torch.zeros_like(y_batch[:,:1,:1]))
        REN_0_101.reset(y0 = y_batch[:,:1,:1])

        # y_init_per_batch      torch.zeros_like(y_batch[:,:1])    y_batch[:,:1]
        y0_hat_train = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1]) # forward
        y_hat_train = y0_hat_train 
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        optimizer.step()
        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_0_101.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, y_batch, time_batch in val_loader_101_M: # MH, I_rec (PID), CGM, time
            
            torch.save({'u0_batch': u0_batch, 'y_batch':y_batch, 'time_batch':time_batch},  'temp_for_leo_valid_meal.pt')

            u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)
            u0_batch, y_batch, time_batch = u0_batch.to(device), y_batch.to(device), time_batch.to(device)
            
            REN_0_101.reset(y0 = y_batch[:,:1,:1])

            y0_hat_val = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1])# select the correct U
            y_hat_val = y0_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        
        candidate_REN_0_101 = REN_0_101

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")


patient_model_folder_101_M = f"./models/101_M/{exp_identifier}"
if redo_save_101_M:
    # model on CPU before saving
    candidate_REN_0_101_cpu = candidate_REN_0_101.to('cpu')

    # Save the best model
    # 1. Create models directory
    MODEL_PATH = Path(patient_model_folder_101_M)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_0_101_state_dict': candidate_REN_0_101_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder_101_M) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
# Out:
# [INFO] Training on device: cpu
# Epoch: 1 	||	 Training Loss: 0.126300 	||	 Validation Loss: 0.115082

# %% [markdown]
# #### test 101 M

# %%
# --------------Plot identification results for G-----------------

patient_model_folder_101_M = f"./models/101_M/{exp_identifier}"
MODEL_PATH = Path(patient_model_folder_101_M)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])

# ----------------------------------

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs'); plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs  101 M')
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()


y0_0 = fun_start_controller_simple(train_loader_p_101_M, dataset_101_M)
y0_0 = torch.zeros_like(y0_0)
REN_0_101 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

#########################################################

y0_0 = fun_start_controller_simple(test_loader_101_M, dataset_101_M)
# y0_0 = torch.zeros_like(y0_0)
REN_0_101.reset(y0 = -y0_0.unsqueeze(1))


checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")
REN_0_101.load_state_dict(checkpoint["REN_0_101_state_dict"])

#################################################################

for u0_batch, _, y_batch, time_batch in train_loader_p_101_M:

    u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)
    
    REN_0_101.reset(y0 = y_batch[:,:1,:1])

    y0_hat = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1])
    y_hat = y0_hat
    
    loss_train = MSE(y_hat, y_batch)

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

print(f"Loss train: {loss_train}")

fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Meal (u0)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u0_batch[0,:,0].numpy(), color=color, label='Meal')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Meal vs Time, Train')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()



#####################################################################################


for u0_batch, _, y_batch, time_batch in test_loader_101_M:

    u0_batch, y_batch, time_batch = ensure_3d(u0_batch), ensure_3d(y_batch), ensure_3d(time_batch)

    REN_0_101.reset(y0 = y_batch[:,:1,:1])
    y0_hat = REN_0_101(u0_batch, y0 = y_batch[:,:1,:1])
    y_hat = y0_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()


fig, ax1 = plt.subplots(figsize=(12, 5))

# Primo asse y: Insulina
color = 'tab:blue'
ax1.set_xlabel('Time step')
ax1.set_ylabel('Meal (u1)', color=color)
ax1.plot(time_batch[0,:,0].numpy(), u0_batch[0,:,0].numpy(), color=color, label='Meal')
ax1.tick_params(axis='y', labelcolor=color)

# Secondo asse y: Glucosio
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Glucose (y)', color=color)
ax2.plot(time_batch[0,:,0].numpy(), y_batch_np[0,:,0], color=color, label='Glucose', alpha=0.7)

# --- AGGIUNTA: plot di y_hat_np ---
ax2.plot(time_batch[0,:,0].numpy(), y_hat_np[0,:,0], color='tab:green', label='Predicted Glucose', alpha=0.7)
# ---------------------------------

ax2.tick_params(axis='y', labelcolor='tab:red')

# Titolo e griglia
plt.title('Glucose and Meal vs Time, Test')
ax1.grid(True)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_16520\1830596232.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# Loss train: 0.0033088047057390213

# %% [markdown]
# # 1 System identification of G

# %% [markdown]
# ### REN model, loss function and optimizer parallel

# %%
#--------------------------3. Define model for sysid---------------------------------------------


device = torch.device(device if torch.cuda.is_available() else "cpu")

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

# meal   M 
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init = y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

# insulin  I_sat
REN_1 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

REN_0 = REN_0.to(device)
REN_1 = REN_1.to(device)

#create the closed loop with the identified model
# closed_loop_G = ClosedLoopSystem(REN_G, controller)

#--------------------------4. Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()

optimizer = torch.optim.Adam( list(REN_0.parameters()) + list(REN_1.parameters()),   lr=learning_rate)
optimizer.zero_grad()

# %% [markdown]
# ### Training and validation loop parallel

# %%
#--------------------------5. Training---------------------------------------------------------------------

torch.set_default_device(device)      # default tensor device
torch.set_default_dtype(torch.float32)  # default tensor dtype
print(f"[INFO] Training on device: {device}")

REN_0.to(device); REN_1.to(device)
train_losses = []
val_losses = []  # Store validation losses across epochs
for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    REN_0.train(); REN_1.train()
    loss_epoch = 0.0  # Accumulate training loss

    
    for u0_batch, _, _, u1_batch, y_batch, _ in train_loader_p: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time

        
        u0_batch, u1_batch, y_batch= ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch) 
        # batch_size, time_horizon, input_dim
        u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)
        
        optimizer.zero_grad()
        REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1])); 
        REN_1.reset(y0 = - y_batch[:,:1,:1])

        # y_init_per_batch      torch.zeros_like(y_batch[:,:1])    y_batch[:,:1]
        y0_hat_train = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1])) # forward
        y1_hat_train = REN_1(u1_batch, y0 = - y_batch[:,:1,:1]) # forward
        y_hat_train = y0_hat_train - y1_hat_train 
        # with monotonicity we have forced a positive response from the insulin REN (REN_1) 
        # but from real-world knowledge it is a negative relation

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        optimizer.step()
        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    REN_0.eval(); REN_1.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, _, u1_batch, y_batch, _ in val_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time

            u0_batch, u1_batch, y_batch= ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)
            u0_batch, u1_batch, y_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device)
            
            REN_0.reset(y0 = torch.zeros_like(y_batch[:,:1,:1]))
            REN_1.reset(y0 = - y_batch[:,:1,:1])

            y0_hat_val = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
            y1_hat_val = REN_1(u1_batch, y0 = - y_batch[:,:1,:1])# select the correct U
            y_hat_val = y0_hat_val - y1_hat_val
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        candidate_REN_0 = REN_0
        candidate_REN_1 = REN_1

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")

if redo_save:
    # model on CPU before saving
    candidate_REN_0_cpu = candidate_REN_0.to('cpu')
    candidate_REN_1_cpu = candidate_REN_1.to('cpu')

    # Save the best model
    # 1. Create models directory
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/"+ "strategy_1" + "/" + patient_str
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'REN_0_state_dict': candidate_REN_0_cpu.state_dict(),
    'REN_1_state_dict': candidate_REN_1_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
# Out:
# [INFO] Training on device: cpu
# Epoch: 1 	||	 Training Loss: 0.157639 	||	 Validation Loss: 0.147790
# Epoch: 2 	||	 Training Loss: 0.147206 	||	 Validation Loss: 0.137981
# Epoch: 3 	||	 Training Loss: 0.137417 	||	 Validation Loss: 0.128812
# Epoch: 4 	||	 Training Loss: 0.128266 	||	 Validation Loss: 0.120271
# Epoch: 5 	||	 Training Loss: 0.119741 	||	 Validation Loss: 0.112342

# %% [markdown]
# ### Plots: test results for G

# %%
# --------------Plot identification results for G-----------------



patient_str = "/paz_" + str(int(patient)).zfill(3)
patient_model_folder = model_folder + "/strategy_1" + "/" + patient_str
MODEL_PATH = Path(patient_model_folder)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])


# ----------------------------------

epochs = 700

#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0

REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

REN_1 = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)

checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")

REN_0.load_state_dict(checkpoint["REN_0_state_dict"])
REN_1.load_state_dict(checkpoint["REN_1_state_dict"])


REN_0.eval()
REN_1.eval()

for u0_batch, _, _, u1_batch, y_batch, time in train_loader_p:

    u0_batch, u1_batch, y_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)

    y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
    y1_hat = REN_1(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = y0_hat - y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    
    break # just first batch

# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Train Set, first batch")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()

# -------------------------------------------------------------



for u0_batch, _, _, u1_batch, y_batch, time in test_loader:

    u0_batch, u1_batch, y_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch)

    y0_hat = REN_0(u0_batch, y0 = torch.zeros_like(y_batch[:,:1,:1]))
    y1_hat = REN_1(u1_batch, y0 = -y_batch[:,:1,:1])
    y_hat = y0_hat - y1_hat

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    


# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time, y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time, y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()

# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_insulin_30g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())

# --- Creazione di un Dataset custom ---
class TestDataset(Dataset):
    def __init__(self, MH, I, y, sequence_length=1):
        """
        MH: meal input (torch tensor)
        I: insulin input (torch tensor)
        y: output (glucose) (torch tensor)
        sequence_length: lunghezza sequenza temporale per la RNN/REN
        """
        self.MH = MH.unsqueeze(-1) if MH.ndim==1 else MH  # shape (N,1)
        self.I  = I.unsqueeze(-1) if I.ndim==1 else I
        self.y  = y.unsqueeze(-1) if y.ndim==1 else y
        self.seq_len = sequence_length

    def __len__(self):
        return len(self.y) - self.seq_len + 1

    def __getitem__(self, idx):
        u0_seq = self.MH[idx:idx+self.seq_len]
        u1_seq = self.I[idx:idx+self.seq_len]
        y_seq  = self.y[idx:idx+self.seq_len]
        time_seq = torch.arange(idx, idx+self.seq_len)
        return u0_seq, u1_seq, y_seq, time_seq

# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)


# !!!!!!!!!!!!!!!!!!!!!!!!!!!  sbagliatissimo, nelkla strategia 1 il modello non è closed loop
# !!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!

Dual_REN = DualREN(REN_0, REN_1)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, batch_size = 1, use_noise = use_noise) # errore qua! batchsize
closed_loop_REN = ClosedLoopSystem(Dual_REN, controller, negative=True)



for u0_batch, u1_batch, y_batch, time in test_loader_new:
    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2) 
    
    
    closed_loop_REN.eval()
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, insulin")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()


# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_meal_80g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())


# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)


    
for u0_batch, u1_batch, y_batch, time in test_loader_new:
    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2) 
    
    
    closed_loop_REN.eval()
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, meal")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_24768\817672786.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\models.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32) # MODIFICATO PER BATCH

# %% [markdown]
# # System identification of the negative feedback of K and S

# %% [markdown]
# ### Closed loop model of REN in negative feedback with K, loss function and optimizer

# %%
#-----------------------------closedloop sysid of S through RENs------------------------
#--------------------------Define model for sysid---------------------------------------------
#create the REN model for S

y_init = x0

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)

REN_S = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = -y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)
Dual_REN = DualREN(REN_0, REN_S, device=device)

controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise = use_noise)

closed_loop_REN = ClosedLoopSystem(Dual_REN, controller, negative=True)

closed_loop_closed_loop_1 = ClosedLoopSystem(closed_loop_REN, controller)



#--------------------------Define the loss function and optimizer---------------------------------------------
MSE = nn.MSELoss()
optimizer = torch.optim.Adam(Dual_REN.parameters(), lr=learning_rate)
optimizer.zero_grad()

# %% [markdown]
# ### Training and validation loop

# %%
#--------------------------5. Training---------------------------------------------------------------------

epochs = 700

REN_0 = REN_0.to(device)
REN_S = REN_S.to(device)
Dual_Ren = Dual_REN.to(device)
controller = controller.to(device)
closed_loop_REN = closed_loop_REN.to(device)
x0 = x0.to(device)
print(f"[INFO] Training on device: {device}")

closed_loop_closed_loop_1 = closed_loop_closed_loop_1.to("cpu") # test always on cpu?
torch.set_default_dtype(torch.float32)  # default tensor dtype

train_losses = []
val_losses = []  # Store validation losses across epochs

for epoch in range(epochs):
    # ---------------- TRAINING ---------------- #
    closed_loop_REN.train()
    loss_epoch = 0.0  # Accumulate training loss


    for u0_batch, _, _, u1_batch, y_batch, t_batch in train_loader_p: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
        # u_batch.shape = batch_size   horizon   input_dim
        
        u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
        u0_batch, u1_batch, y_batch, t_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device), t_batch.to(device)
        u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input dimension

        optimizer.zero_grad()
        
        saturation_error_init, glucose_PID_init, _ = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
        closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
        
        
        _, y_hat_train = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])

        if torch.isnan(y_hat_train).any() or torch.isinf(y_hat_train).any():
            y_hat_train = torch.nan_to_num(y_hat_train, nan=1e5, posinf=1e5, neginf=-1e5)
            for name, param in closed_loop_REN.named_parameters():
                print(f"{name}: mean {param.data.mean()}, std {param.data.std()}")

        loss_batch = MSE(y_hat_train, y_batch)

        loss_batch.backward()
        # torch.nn.utils.clip_grad_norm_(Dual_REN.parameters(), max_norm=1.0) # Gradient clipping TODO: check if other code is correct

        optimizer.step()

        loss_epoch += loss_batch.item()

    loss_epoch /= len(train_loader_p)
    train_losses.append(loss_epoch)

    # ---------------- VALIDATION ---------------- #
    Dual_REN.eval()
    loss_val_epoch = 0.0

    with torch.no_grad():
        for u0_batch, _, _, u1_batch, y_batch, t_batch in val_loader: # MH, I_rec (PID), R (noise + sat), I_sat (I_rec + R), CGM, time
            # u_batch.shape = batch_size   horizon   input_dim
            
            u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
            u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input dimension
            u_batch, y_batch, t_batch = u_batch.to(device), y_batch.to(device), t_batch.to(device)
            
            saturation_error_init, glucose_PID_init, _ = fun_start_controller(val_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
            closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
            
            _, y_hat_val = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])
            
            loss_batch_val = MSE(y_hat_val, y_batch)

            loss_val_epoch += loss_batch_val.item()

    if epoch == 0 or loss_val_epoch < min_val_loss:
        min_val_loss = loss_val_epoch
        epoch_when_model_saved = epoch
        candidate_Dual_REN = Dual_REN

    loss_val_epoch /= len(val_loader)
    val_losses.append(loss_val_epoch)  # Store validation loss for plotting

    print(f"Epoch: {epoch + 1} \t||\t Training Loss: {loss_epoch:.6f} \t||\t Validation Loss: {loss_val_epoch:.6f}")

if redo_save:
    # model on CPU before saving
    candidate_Dual_REN_cpu = candidate_Dual_REN.to('cpu')

    # Save the best model
    # 1. Create models directory
    
    patient_str = "/paz_" + str(int(patient)).zfill(3)
    patient_model_folder = model_folder + "/" + patient_str + "/" + "strategy_2" 
    MODEL_PATH = Path(patient_model_folder)
    MODEL_PATH.mkdir(parents = True, exist_ok = True)
    # 2. save model state dict
    torch.save({
    'Dueal_REN_state_dict': candidate_Dual_REN_cpu.state_dict()}, MODEL_PATH / 'trained_models.pth')


    # save .mat
    np_x0 = x0.detach().cpu().numpy(); np_input_dim = np.array(input_dim); np_output_dim = np.array(output_dim); np_dim_internal =np.array(dim_internal); np_dim_nl = np.array(dim_nl)
    np_y_init = y_init.cpu().numpy(); np_gamma = gamma.cpu().numpy()
    
    # 4. Create params directory
    params_folder = Path(patient_model_folder) / "params"
    params_folder.mkdir(parents=True, exist_ok=True)
    scipy.io.savemat(params_folder / 'parameters.mat', {'train_losses': train_losses, 'val_losses': val_losses, 'epoch_when_model_saved': epoch_when_model_saved, 'x0': np_x0, 'input_dim': np_input_dim, 'output_dim': np_output_dim, 'dim_internal': np_dim_internal, 'dim_nl': np_dim_nl, 'y_init': np_y_init, 'gamma': np_gamma})
# Out:
# [INFO] Training on device: cpu
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\code\exp_2\models.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32) # MODIFICATO PER BATCH
# Epoch: 1 	||	 Training Loss: 6.063666 	||	 Validation Loss: 4.823240
# Epoch: 2 	||	 Training Loss: 4.653574 	||	 Validation Loss: 0.629513
# Epoch: 3 	||	 Training Loss: 1.976499 	||	 Validation Loss: 2.435708
# Epoch: 4 	||	 Training Loss: 1.451269 	||	 Validation Loss: 0.326278
# Epoch: 5 	||	 Training Loss: 0.318112 	||	 Validation Loss: 0.257040
# Epoch: 6 	||	 Training Loss: 0.235929 	||	 Validation Loss: 0.208620
# Epoch: 7 	||	 Training Loss: 0.207594 	||	 Validation Loss: 0.199278
# Epoch: 8 	||	 Training Loss: 0.198197 	||	 Validation Loss: 0.191311
# Epoch: 9 	||	 Training Loss: 0.191843 	||	 Validation Loss: 0.187786
# Epoch: 10 	||	 Training Loss: 0.187977 	||	 Validation Loss: 0.184440
# Epoch: 11 	||	 Training Loss: 0.185668 	||	 Validation Loss: 0.182968
# Epoch: 12 	||	 Training Loss: 0.184389 	||	 Validation Loss: 0.182111
# Epoch: 13 	||	 Training Loss: 0.183443 	||	 Validation Loss: 0.181443
# Epoch: 14 	||	 Training Loss: 0.183064 	||	 Validation Loss: 0.181150
# Epoch: 15 	||	 Training Loss: 0.182755 	||	 Validation Loss: 0.180636
# Epoch: 16 	||	 Training Loss: 0.182566 	||	 Validation Loss: 0.180557
# Epoch: 17 	||	 Training Loss: 0.182350 	||	 Validation Loss: 0.180517
# Epoch: 18 	||	 Training Loss: 0.182338 	||	 Validation Loss: 0.180514
# Epoch: 19 	||	 Training Loss: 0.182302 	||	 Validation Loss: 0.180423
# Epoch: 20 	||	 Training Loss: 0.182284 	||	 Validation Loss: 0.180283
# Epoch: 21 	||	 Training Loss: 0.182263 	||	 Validation Loss: 0.180394
# Epoch: 22 	||	 Training Loss: 0.182237 	||	 Validation Loss: 0.180273
# Epoch: 23 	||	 Training Loss: 0.182171 	||	 Validation Loss: 0.180221
# Epoch: 24 	||	 Training Loss: 0.182143 	||	 Validation Loss: 0.180101
# Epoch: 25 	||	 Training Loss: 0.182071 	||	 Validation Loss: 0.179972
# Epoch: 26 	||	 Training Loss: 0.181942 	||	 Validation Loss: 0.179879
# Epoch: 27 	||	 Training Loss: 0.181896 	||	 Validation Loss: 0.179797
# Epoch: 28 	||	 Training Loss: 0.181787 	||	 Validation Loss: 0.179696
# Epoch: 29 	||	 Training Loss: 0.181660 	||	 Validation Loss: 0.179629
# Epoch: 30 	||	 Training Loss: 0.181552 	||	 Validation Loss: 0.179602
# Epoch: 31 	||	 Training Loss: 0.181423 	||	 Validation Loss: 0.179451
# Epoch: 32 	||	 Training Loss: 0.181300 	||	 Validation Loss: 0.179333
# Epoch: 33 	||	 Training Loss: 0.181191 	||	 Validation Loss: 0.179137
# Epoch: 34 	||	 Training Loss: 0.181061 	||	 Validation Loss: 0.179062
# Epoch: 35 	||	 Training Loss: 0.180934 	||	 Validation Loss: 0.178940
# Epoch: 36 	||	 Training Loss: 0.180828 	||	 Validation Loss: 0.178776
# Epoch: 37 	||	 Training Loss: 0.180737 	||	 Validation Loss: 0.178736
# Epoch: 38 	||	 Training Loss: 0.180595 	||	 Validation Loss: 0.178613
# Epoch: 39 	||	 Training Loss: 0.180452 	||	 Validation Loss: 0.178435
# Epoch: 40 	||	 Training Loss: 0.180345 	||	 Validation Loss: 0.178309
# Epoch: 41 	||	 Training Loss: 0.180203 	||	 Validation Loss: 0.178186
# Epoch: 42 	||	 Training Loss: 0.180080 	||	 Validation Loss: 0.178052
# Epoch: 43 	||	 Training Loss: 0.179927 	||	 Validation Loss: 0.177898
# Epoch: 44 	||	 Training Loss: 0.179795 	||	 Validation Loss: 0.177761
# Epoch: 45 	||	 Training Loss: 0.179650 	||	 Validation Loss: 0.177621
# Epoch: 46 	||	 Training Loss: 0.179492 	||	 Validation Loss: 0.177527
# Epoch: 47 	||	 Training Loss: 0.179356 	||	 Validation Loss: 0.177402
# Epoch: 48 	||	 Training Loss: 0.179211 	||	 Validation Loss: 0.177238
# Epoch: 49 	||	 Training Loss: 0.179066 	||	 Validation Loss: 0.177113
# Epoch: 50 	||	 Training Loss: 0.178928 	||	 Validation Loss: 0.177002
# Epoch: 51 	||	 Training Loss: 0.178782 	||	 Validation Loss: 0.176829
# Epoch: 52 	||	 Training Loss: 0.178628 	||	 Validation Loss: 0.176699
# Epoch: 53 	||	 Training Loss: 0.178477 	||	 Validation Loss: 0.176565
# Epoch: 54 	||	 Training Loss: 0.178367 	||	 Validation Loss: 0.176467
# Epoch: 55 	||	 Training Loss: 0.178198 	||	 Validation Loss: 0.176291
# Epoch: 56 	||	 Training Loss: 0.178099 	||	 Validation Loss: 0.176174
# Epoch: 57 	||	 Training Loss: 0.177963 	||	 Validation Loss: 0.176033
# Epoch: 58 	||	 Training Loss: 0.177816 	||	 Validation Loss: 0.175897
# Epoch: 59 	||	 Training Loss: 0.177675 	||	 Validation Loss: 0.175754
# Epoch: 60 	||	 Training Loss: 0.177550 	||	 Validation Loss: 0.175587
# Epoch: 61 	||	 Training Loss: 0.177445 	||	 Validation Loss: 0.175446
# Epoch: 62 	||	 Training Loss: 0.177333 	||	 Validation Loss: 0.175304
# Epoch: 63 	||	 Training Loss: 0.177205 	||	 Validation Loss: 0.175224
# Epoch: 64 	||	 Training Loss: 0.177071 	||	 Validation Loss: 0.175125
# Epoch: 65 	||	 Training Loss: 0.176947 	||	 Validation Loss: 0.174978
# Epoch: 66 	||	 Training Loss: 0.176821 	||	 Validation Loss: 0.174883
# Epoch: 67 	||	 Training Loss: 0.176678 	||	 Validation Loss: 0.174738
# Epoch: 68 	||	 Training Loss: 0.176623 	||	 Validation Loss: 0.174609
# Epoch: 69 	||	 Training Loss: 0.176519 	||	 Validation Loss: 0.174436
# Epoch: 70 	||	 Training Loss: 0.176374 	||	 Validation Loss: 0.174324
# Epoch: 71 	||	 Training Loss: 0.176222 	||	 Validation Loss: 0.174151
# Epoch: 72 	||	 Training Loss: 0.176067 	||	 Validation Loss: 0.173895
# Epoch: 73 	||	 Training Loss: 0.175925 	||	 Validation Loss: 0.173811
# Epoch: 74 	||	 Training Loss: 0.175777 	||	 Validation Loss: 0.173579
# Epoch: 75 	||	 Training Loss: 0.175634 	||	 Validation Loss: 0.173441
# Epoch: 76 	||	 Training Loss: 0.175460 	||	 Validation Loss: 0.173299
# Epoch: 77 	||	 Training Loss: 0.175294 	||	 Validation Loss: 0.173123
# Epoch: 78 	||	 Training Loss: 0.175103 	||	 Validation Loss: 0.173085
# Epoch: 79 	||	 Training Loss: 0.174963 	||	 Validation Loss: 0.172901
# Epoch: 80 	||	 Training Loss: 0.174831 	||	 Validation Loss: 0.172829
# Epoch: 81 	||	 Training Loss: 0.174650 	||	 Validation Loss: 0.172628
# Epoch: 82 	||	 Training Loss: 0.174475 	||	 Validation Loss: 0.172438
# Epoch: 83 	||	 Training Loss: 0.174287 	||	 Validation Loss: 0.172243
# Epoch: 84 	||	 Training Loss: 0.174096 	||	 Validation Loss: 0.172036
# Epoch: 85 	||	 Training Loss: 0.173909 	||	 Validation Loss: 0.171846
# Epoch: 86 	||	 Training Loss: 0.173741 	||	 Validation Loss: 0.171660
# Epoch: 87 	||	 Training Loss: 0.173565 	||	 Validation Loss: 0.171461
# Epoch: 88 	||	 Training Loss: 0.173393 	||	 Validation Loss: 0.171217
# Epoch: 89 	||	 Training Loss: 0.173223 	||	 Validation Loss: 0.171024
# Epoch: 90 	||	 Training Loss: 0.173032 	||	 Validation Loss: 0.170813
# Epoch: 91 	||	 Training Loss: 0.172845 	||	 Validation Loss: 0.170663
# Epoch: 92 	||	 Training Loss: 0.172636 	||	 Validation Loss: 0.170451
# Epoch: 93 	||	 Training Loss: 0.172439 	||	 Validation Loss: 0.170246
# Epoch: 94 	||	 Training Loss: 0.172227 	||	 Validation Loss: 0.170019
# Epoch: 95 	||	 Training Loss: 0.172019 	||	 Validation Loss: 0.169753
# Epoch: 96 	||	 Training Loss: 0.171796 	||	 Validation Loss: 0.169549
# Epoch: 97 	||	 Training Loss: 0.171580 	||	 Validation Loss: 0.169268
# Epoch: 98 	||	 Training Loss: 0.171351 	||	 Validation Loss: 0.168811
# Epoch: 99 	||	 Training Loss: 0.171135 	||	 Validation Loss: 0.168571
# Epoch: 100 	||	 Training Loss: 0.170908 	||	 Validation Loss: 0.168376
# Epoch: 101 	||	 Training Loss: 0.170664 	||	 Validation Loss: 0.168158
# Epoch: 102 	||	 Training Loss: 0.170416 	||	 Validation Loss: 0.168056
# Epoch: 103 	||	 Training Loss: 0.170149 	||	 Validation Loss: 0.167771
# Epoch: 104 	||	 Training Loss: 0.169865 	||	 Validation Loss: 0.167543
# Epoch: 105 	||	 Training Loss: 0.169541 	||	 Validation Loss: 0.167184
# Epoch: 106 	||	 Training Loss: 0.169239 	||	 Validation Loss: 0.167120
# Epoch: 107 	||	 Training Loss: 0.168904 	||	 Validation Loss: 0.166626
# Epoch: 108 	||	 Training Loss: 0.168557 	||	 Validation Loss: 0.166443
# Epoch: 109 	||	 Training Loss: 0.168453 	||	 Validation Loss: 0.166852
# Epoch: 110 	||	 Training Loss: 0.168583 	||	 Validation Loss: 0.166926
# Epoch: 111 	||	 Training Loss: 0.168559 	||	 Validation Loss: 0.166864
# Epoch: 112 	||	 Training Loss: 0.168383 	||	 Validation Loss: 0.166950
# Epoch: 113 	||	 Training Loss: 0.168467 	||	 Validation Loss: 0.166281
# Epoch: 114 	||	 Training Loss: 0.167929 	||	 Validation Loss: 0.165513
# Epoch: 115 	||	 Training Loss: 0.167561 	||	 Validation Loss: 0.164795
# Epoch: 116 	||	 Training Loss: 0.167218 	||	 Validation Loss: 0.164231
# Epoch: 117 	||	 Training Loss: 0.166510 	||	 Validation Loss: 0.163428
# Epoch: 118 	||	 Training Loss: 0.165472 	||	 Validation Loss: 0.162892
# Epoch: 119 	||	 Training Loss: 0.164446 	||	 Validation Loss: 0.161041
# Epoch: 120 	||	 Training Loss: 0.163278 	||	 Validation Loss: 0.159333
# Epoch: 121 	||	 Training Loss: 0.161489 	||	 Validation Loss: 0.156832
# Epoch: 122 	||	 Training Loss: 0.159069 	||	 Validation Loss: 0.153992
# Epoch: 123 	||	 Training Loss: 0.156585 	||	 Validation Loss: 0.151660
# Epoch: 124 	||	 Training Loss: 0.153575 	||	 Validation Loss: 0.148123
# Epoch: 125 	||	 Training Loss: 0.150181 	||	 Validation Loss: 0.143544
# Epoch: 126 	||	 Training Loss: 0.146308 	||	 Validation Loss: 0.139425
# Epoch: 127 	||	 Training Loss: 0.141713 	||	 Validation Loss: 0.134145
# Epoch: 128 	||	 Training Loss: 0.136360 	||	 Validation Loss: 0.128112
# Epoch: 129 	||	 Training Loss: 0.130388 	||	 Validation Loss: 0.121040
# Epoch: 130 	||	 Training Loss: 0.123325 	||	 Validation Loss: 0.113146
# Epoch: 131 	||	 Training Loss: 0.115497 	||	 Validation Loss: 0.104576
# Epoch: 132 	||	 Training Loss: 0.106625 	||	 Validation Loss: 0.094915
# Epoch: 133 	||	 Training Loss: 0.097050 	||	 Validation Loss: 0.084767
# Epoch: 134 	||	 Training Loss: 0.086919 	||	 Validation Loss: 0.075198
# Epoch: 135 	||	 Training Loss: 0.076716 	||	 Validation Loss: 0.066137
# Epoch: 136 	||	 Training Loss: 0.066896 	||	 Validation Loss: 0.058178
# Epoch: 137 	||	 Training Loss: 0.058512 	||	 Validation Loss: 0.052116
# Epoch: 138 	||	 Training Loss: 0.052043 	||	 Validation Loss: 0.047832
# Epoch: 139 	||	 Training Loss: 0.047619 	||	 Validation Loss: 0.045999
# Epoch: 140 	||	 Training Loss: 0.045168 	||	 Validation Loss: 0.045291
# Epoch: 141 	||	 Training Loss: 0.044072 	||	 Validation Loss: 0.044536
# Epoch: 142 	||	 Training Loss: 0.043204 	||	 Validation Loss: 0.043383
# Epoch: 143 	||	 Training Loss: 0.042057 	||	 Validation Loss: 0.041375
# Epoch: 144 	||	 Training Loss: 0.040779 	||	 Validation Loss: 0.039781
# Epoch: 145 	||	 Training Loss: 0.039869 	||	 Validation Loss: 0.039670
# Epoch: 146 	||	 Training Loss: 0.039830 	||	 Validation Loss: 0.039202
# Epoch: 147 	||	 Training Loss: 0.040188 	||	 Validation Loss: 0.038680
# Epoch: 148 	||	 Training Loss: 0.039657 	||	 Validation Loss: 0.037414
# Epoch: 149 	||	 Training Loss: 0.038374 	||	 Validation Loss: 0.036434
# Epoch: 150 	||	 Training Loss: 0.037043 	||	 Validation Loss: 0.036259
# Epoch: 151 	||	 Training Loss: 0.036467 	||	 Validation Loss: 0.036305
# Epoch: 152 	||	 Training Loss: 0.036265 	||	 Validation Loss: 0.036420
# Epoch: 153 	||	 Training Loss: 0.036077 	||	 Validation Loss: 0.036293
# Epoch: 154 	||	 Training Loss: 0.035978 	||	 Validation Loss: 0.035465
# Epoch: 155 	||	 Training Loss: 0.035694 	||	 Validation Loss: 0.034703
# Epoch: 156 	||	 Training Loss: 0.035252 	||	 Validation Loss: 0.034567
# Epoch: 157 	||	 Training Loss: 0.034958 	||	 Validation Loss: 0.034826
# Epoch: 158 	||	 Training Loss: 0.034702 	||	 Validation Loss: 0.034699
# Epoch: 159 	||	 Training Loss: 0.034864 	||	 Validation Loss: 0.034617
# Epoch: 160 	||	 Training Loss: 0.034789 	||	 Validation Loss: 0.034492
# Epoch: 161 	||	 Training Loss: 0.034683 	||	 Validation Loss: 0.034362
# Epoch: 162 	||	 Training Loss: 0.034489 	||	 Validation Loss: 0.034250
# Epoch: 163 	||	 Training Loss: 0.034306 	||	 Validation Loss: 0.034231
# Epoch: 164 	||	 Training Loss: 0.034115 	||	 Validation Loss: 0.034263
# Epoch: 165 	||	 Training Loss: 0.034038 	||	 Validation Loss: 0.034163
# Epoch: 166 	||	 Training Loss: 0.034053 	||	 Validation Loss: 0.034210
# Epoch: 167 	||	 Training Loss: 0.033975 	||	 Validation Loss: 0.034035
# Epoch: 168 	||	 Training Loss: 0.033854 	||	 Validation Loss: 0.033960
# Epoch: 169 	||	 Training Loss: 0.033826 	||	 Validation Loss: 0.033673
# Epoch: 170 	||	 Training Loss: 0.033733 	||	 Validation Loss: 0.033488
# Epoch: 171 	||	 Training Loss: 0.033637 	||	 Validation Loss: 0.033337
# Epoch: 172 	||	 Training Loss: 0.033527 	||	 Validation Loss: 0.033266
# Epoch: 173 	||	 Training Loss: 0.033445 	||	 Validation Loss: 0.033085
# Epoch: 174 	||	 Training Loss: 0.033401 	||	 Validation Loss: 0.033025
# Epoch: 175 	||	 Training Loss: 0.033323 	||	 Validation Loss: 0.032984
# Epoch: 176 	||	 Training Loss: 0.033187 	||	 Validation Loss: 0.032970
# Epoch: 177 	||	 Training Loss: 0.033083 	||	 Validation Loss: 0.033016
# Epoch: 178 	||	 Training Loss: 0.033037 	||	 Validation Loss: 0.033196
# Epoch: 179 	||	 Training Loss: 0.032959 	||	 Validation Loss: 0.033195
# Epoch: 180 	||	 Training Loss: 0.033006 	||	 Validation Loss: 0.032999
# Epoch: 181 	||	 Training Loss: 0.032903 	||	 Validation Loss: 0.032926
# Epoch: 182 	||	 Training Loss: 0.032817 	||	 Validation Loss: 0.032821
# Epoch: 183 	||	 Training Loss: 0.032772 	||	 Validation Loss: 0.032702
# Epoch: 184 	||	 Training Loss: 0.032790 	||	 Validation Loss: 0.032497
# Epoch: 185 	||	 Training Loss: 0.032720 	||	 Validation Loss: 0.032463
# Epoch: 186 	||	 Training Loss: 0.032656 	||	 Validation Loss: 0.032421
# Epoch: 187 	||	 Training Loss: 0.032619 	||	 Validation Loss: 0.032374
# Epoch: 188 	||	 Training Loss: 0.032595 	||	 Validation Loss: 0.032283
# Epoch: 189 	||	 Training Loss: 0.032501 	||	 Validation Loss: 0.032495
# Epoch: 190 	||	 Training Loss: 0.032479 	||	 Validation Loss: 0.032527
# Epoch: 191 	||	 Training Loss: 0.032414 	||	 Validation Loss: 0.032541
# Epoch: 192 	||	 Training Loss: 0.032385 	||	 Validation Loss: 0.032693
# Epoch: 193 	||	 Training Loss: 0.032317 	||	 Validation Loss: 0.032647
# Epoch: 194 	||	 Training Loss: 0.032259 	||	 Validation Loss: 0.032585
# Epoch: 195 	||	 Training Loss: 0.032154 	||	 Validation Loss: 0.032467
# Epoch: 196 	||	 Training Loss: 0.032080 	||	 Validation Loss: 0.032404
# Epoch: 197 	||	 Training Loss: 0.032084 	||	 Validation Loss: 0.032349
# Epoch: 198 	||	 Training Loss: 0.032035 	||	 Validation Loss: 0.032384
# Epoch: 199 	||	 Training Loss: 0.031976 	||	 Validation Loss: 0.032321
# Epoch: 200 	||	 Training Loss: 0.031964 	||	 Validation Loss: 0.032084
# Epoch: 201 	||	 Training Loss: 0.031938 	||	 Validation Loss: 0.032058
# Epoch: 202 	||	 Training Loss: 0.031863 	||	 Validation Loss: 0.032028
# Epoch: 203 	||	 Training Loss: 0.031830 	||	 Validation Loss: 0.031973
# Epoch: 204 	||	 Training Loss: 0.031759 	||	 Validation Loss: 0.031921
# Epoch: 205 	||	 Training Loss: 0.031722 	||	 Validation Loss: 0.031851
# Epoch: 206 	||	 Training Loss: 0.031667 	||	 Validation Loss: 0.031764
# Epoch: 207 	||	 Training Loss: 0.031679 	||	 Validation Loss: 0.031677
# Epoch: 208 	||	 Training Loss: 0.031748 	||	 Validation Loss: 0.031630
# Epoch: 209 	||	 Training Loss: 0.031689 	||	 Validation Loss: 0.031596
# Epoch: 210 	||	 Training Loss: 0.031715 	||	 Validation Loss: 0.031575
# Epoch: 211 	||	 Training Loss: 0.031676 	||	 Validation Loss: 0.031556
# Epoch: 212 	||	 Training Loss: 0.031573 	||	 Validation Loss: 0.031522
# Epoch: 213 	||	 Training Loss: 0.031526 	||	 Validation Loss: 0.031509
# Epoch: 214 	||	 Training Loss: 0.031462 	||	 Validation Loss: 0.031512
# Epoch: 215 	||	 Training Loss: 0.031402 	||	 Validation Loss: 0.031468
# Epoch: 216 	||	 Training Loss: 0.031402 	||	 Validation Loss: 0.031100
# Epoch: 217 	||	 Training Loss: 0.031311 	||	 Validation Loss: 0.030751
# Epoch: 218 	||	 Training Loss: 0.031302 	||	 Validation Loss: 0.030718
# Epoch: 219 	||	 Training Loss: 0.031264 	||	 Validation Loss: 0.030692
# Epoch: 220 	||	 Training Loss: 0.031188 	||	 Validation Loss: 0.030653
# Epoch: 221 	||	 Training Loss: 0.031122 	||	 Validation Loss: 0.030656
# Epoch: 222 	||	 Training Loss: 0.030997 	||	 Validation Loss: 0.030599
# Epoch: 223 	||	 Training Loss: 0.031009 	||	 Validation Loss: 0.030547
# Epoch: 224 	||	 Training Loss: 0.030962 	||	 Validation Loss: 0.030565
# Epoch: 225 	||	 Training Loss: 0.030918 	||	 Validation Loss: 0.030518
# Epoch: 226 	||	 Training Loss: 0.030854 	||	 Validation Loss: 0.030420
# Epoch: 227 	||	 Training Loss: 0.030803 	||	 Validation Loss: 0.030391
# Epoch: 228 	||	 Training Loss: 0.030772 	||	 Validation Loss: 0.030549
# Epoch: 229 	||	 Training Loss: 0.030724 	||	 Validation Loss: 0.030508
# Epoch: 230 	||	 Training Loss: 0.030793 	||	 Validation Loss: 0.030220
# Epoch: 231 	||	 Training Loss: 0.030729 	||	 Validation Loss: 0.030525
# Epoch: 232 	||	 Training Loss: 0.030694 	||	 Validation Loss: 0.030432
# Epoch: 233 	||	 Training Loss: 0.030648 	||	 Validation Loss: 0.030390
# Epoch: 234 	||	 Training Loss: 0.030652 	||	 Validation Loss: 0.030363
# Epoch: 235 	||	 Training Loss: 0.030626 	||	 Validation Loss: 0.030378
# Epoch: 236 	||	 Training Loss: 0.030645 	||	 Validation Loss: 0.030369
# Epoch: 237 	||	 Training Loss: 0.030590 	||	 Validation Loss: 0.030367
# Epoch: 238 	||	 Training Loss: 0.030512 	||	 Validation Loss: 0.030336
# Epoch: 239 	||	 Training Loss: 0.030512 	||	 Validation Loss: 0.030124
# Epoch: 240 	||	 Training Loss: 0.030648 	||	 Validation Loss: 0.030168
# Epoch: 241 	||	 Training Loss: 0.030215 	||	 Validation Loss: 0.030192
# Epoch: 242 	||	 Training Loss: 0.030150 	||	 Validation Loss: 0.030108
# Epoch: 243 	||	 Training Loss: 0.030082 	||	 Validation Loss: 0.030045
# Epoch: 244 	||	 Training Loss: 0.030383 	||	 Validation Loss: 0.030012
# Epoch: 245 	||	 Training Loss: 0.030528 	||	 Validation Loss: 0.029986
# Epoch: 246 	||	 Training Loss: 0.030307 	||	 Validation Loss: 0.029897
# Epoch: 247 	||	 Training Loss: 0.030388 	||	 Validation Loss: 0.029830
# Epoch: 248 	||	 Training Loss: 0.030275 	||	 Validation Loss: 0.029802
# Epoch: 249 	||	 Training Loss: 0.030244 	||	 Validation Loss: 0.029983
# Epoch: 250 	||	 Training Loss: 0.030234 	||	 Validation Loss: 0.030005
# Epoch: 251 	||	 Training Loss: 0.030231 	||	 Validation Loss: 0.030010
# Epoch: 252 	||	 Training Loss: 0.030251 	||	 Validation Loss: 0.029997
# Epoch: 253 	||	 Training Loss: 0.030196 	||	 Validation Loss: 0.029980
# Epoch: 254 	||	 Training Loss: 0.030227 	||	 Validation Loss: 0.029959
# Epoch: 255 	||	 Training Loss: 0.030223 	||	 Validation Loss: 0.029933
# Epoch: 256 	||	 Training Loss: 0.030006 	||	 Validation Loss: 0.029912
# Epoch: 257 	||	 Training Loss: 0.029999 	||	 Validation Loss: 0.029827
# Epoch: 258 	||	 Training Loss: 0.030264 	||	 Validation Loss: 0.029795
# Epoch: 259 	||	 Training Loss: 0.030538 	||	 Validation Loss: 0.029957
# Epoch: 260 	||	 Training Loss: 0.030463 	||	 Validation Loss: 0.029927
# Epoch: 261 	||	 Training Loss: 0.030292 	||	 Validation Loss: 0.029839
# Epoch: 262 	||	 Training Loss: 0.030313 	||	 Validation Loss: 0.029908
# Epoch: 263 	||	 Training Loss: 0.030319 	||	 Validation Loss: 0.029963
# Epoch: 264 	||	 Training Loss: 0.030321 	||	 Validation Loss: 0.029937
# Epoch: 265 	||	 Training Loss: 0.030168 	||	 Validation Loss: 0.029896
# Epoch: 266 	||	 Training Loss: 0.030241 	||	 Validation Loss: 0.029779
# Epoch: 267 	||	 Training Loss: 0.030274 	||	 Validation Loss: 0.029758
# Epoch: 268 	||	 Training Loss: 0.030166 	||	 Validation Loss: 0.029731
# Epoch: 269 	||	 Training Loss: 0.030334 	||	 Validation Loss: 0.029714
# Epoch: 270 	||	 Training Loss: 0.030223 	||	 Validation Loss: 0.029780
# Epoch: 271 	||	 Training Loss: 0.030215 	||	 Validation Loss: 0.029556
# Epoch: 272 	||	 Training Loss: 0.030045 	||	 Validation Loss: 0.029500
# Epoch: 273 	||	 Training Loss: 0.030016 	||	 Validation Loss: 0.029441
# Epoch: 274 	||	 Training Loss: 0.030043 	||	 Validation Loss: 0.029449
# Epoch: 275 	||	 Training Loss: 0.030087 	||	 Validation Loss: 0.029425
# Epoch: 276 	||	 Training Loss: 0.029860 	||	 Validation Loss: 0.029501
# Epoch: 277 	||	 Training Loss: 0.029819 	||	 Validation Loss: 0.029764
# Epoch: 278 	||	 Training Loss: 0.029707 	||	 Validation Loss: 0.029426
# Epoch: 279 	||	 Training Loss: 0.029282 	||	 Validation Loss: 0.029232
# Epoch: 280 	||	 Training Loss: 0.029001 	||	 Validation Loss: 0.029246
# Epoch: 281 	||	 Training Loss: 0.029016 	||	 Validation Loss: 0.029576
# Epoch: 282 	||	 Training Loss: 0.028957 	||	 Validation Loss: 0.029552
# Epoch: 283 	||	 Training Loss: 0.029043 	||	 Validation Loss: 0.029522
# Epoch: 284 	||	 Training Loss: 0.029033 	||	 Validation Loss: 0.029690
# Epoch: 285 	||	 Training Loss: 0.029239 	||	 Validation Loss: 0.029393
# Epoch: 286 	||	 Training Loss: 0.029294 	||	 Validation Loss: 0.029339
# Epoch: 287 	||	 Training Loss: 0.029037 	||	 Validation Loss: 0.029592
# Epoch: 288 	||	 Training Loss: 0.028751 	||	 Validation Loss: 0.029795
# Epoch: 289 	||	 Training Loss: 0.028668 	||	 Validation Loss: 0.030198
# Epoch: 290 	||	 Training Loss: 0.028598 	||	 Validation Loss: 0.030334
# Epoch: 291 	||	 Training Loss: 0.028789 	||	 Validation Loss: 0.030466
# Epoch: 292 	||	 Training Loss: 0.028856 	||	 Validation Loss: 0.031294
# Epoch: 293 	||	 Training Loss: 0.029024 	||	 Validation Loss: 0.031200
# Epoch: 294 	||	 Training Loss: 0.029022 	||	 Validation Loss: 0.030220
# Epoch: 295 	||	 Training Loss: 0.028805 	||	 Validation Loss: 0.030136
# Epoch: 296 	||	 Training Loss: 0.028926 	||	 Validation Loss: 0.029076
# Epoch: 297 	||	 Training Loss: 0.028839 	||	 Validation Loss: 0.029029
# Epoch: 298 	||	 Training Loss: 0.028905 	||	 Validation Loss: 0.028951
# Epoch: 299 	||	 Training Loss: 0.028813 	||	 Validation Loss: 0.028332
# Epoch: 300 	||	 Training Loss: 0.028625 	||	 Validation Loss: 0.028233
# Epoch: 301 	||	 Training Loss: 0.028247 	||	 Validation Loss: 0.027936
# Epoch: 302 	||	 Training Loss: 0.028199 	||	 Validation Loss: 0.029371
# Epoch: 303 	||	 Training Loss: 0.028169 	||	 Validation Loss: 0.029072
# Epoch: 304 	||	 Training Loss: 0.027561 	||	 Validation Loss: 0.029762
# Epoch: 305 	||	 Training Loss: 0.027522 	||	 Validation Loss: 0.029985
# Epoch: 306 	||	 Training Loss: 0.027640 	||	 Validation Loss: 0.029906
# Epoch: 307 	||	 Training Loss: 0.027790 	||	 Validation Loss: 0.028445
# Epoch: 308 	||	 Training Loss: 0.027676 	||	 Validation Loss: 0.028686
# Epoch: 309 	||	 Training Loss: 0.027544 	||	 Validation Loss: 0.028473
# Epoch: 310 	||	 Training Loss: 0.027598 	||	 Validation Loss: 0.028621
# Epoch: 311 	||	 Training Loss: 0.027716 	||	 Validation Loss: 0.029466
# Epoch: 312 	||	 Training Loss: 0.027372 	||	 Validation Loss: 0.031437
# Epoch: 313 	||	 Training Loss: 0.027451 	||	 Validation Loss: 0.030676
# Epoch: 314 	||	 Training Loss: 0.027437 	||	 Validation Loss: 0.029148
# Epoch: 315 	||	 Training Loss: 0.027174 	||	 Validation Loss: 0.029041
# Epoch: 316 	||	 Training Loss: 0.027172 	||	 Validation Loss: 0.029113
# Epoch: 317 	||	 Training Loss: 0.027337 	||	 Validation Loss: 0.028576
# Epoch: 318 	||	 Training Loss: 0.026948 	||	 Validation Loss: 0.028324
# Epoch: 319 	||	 Training Loss: 0.027008 	||	 Validation Loss: 0.028752
# Epoch: 320 	||	 Training Loss: 0.026917 	||	 Validation Loss: 0.028558
# Epoch: 321 	||	 Training Loss: 0.026898 	||	 Validation Loss: 0.026746
# Epoch: 322 	||	 Training Loss: 0.026968 	||	 Validation Loss: 0.026756
# Epoch: 323 	||	 Training Loss: 0.026665 	||	 Validation Loss: 0.027015
# Epoch: 324 	||	 Training Loss: 0.026581 	||	 Validation Loss: 0.026933
# Epoch: 325 	||	 Training Loss: 0.026629 	||	 Validation Loss: 0.026955
# Epoch: 326 	||	 Training Loss: 0.026487 	||	 Validation Loss: 0.026765
# Epoch: 327 	||	 Training Loss: 0.026497 	||	 Validation Loss: 0.027126
# Epoch: 328 	||	 Training Loss: 0.026434 	||	 Validation Loss: 0.027068
# Epoch: 329 	||	 Training Loss: 0.026247 	||	 Validation Loss: 0.027136
# Epoch: 330 	||	 Training Loss: 0.026195 	||	 Validation Loss: 0.027094
# Epoch: 331 	||	 Training Loss: 0.026027 	||	 Validation Loss: 0.027015
# Epoch: 332 	||	 Training Loss: 0.025976 	||	 Validation Loss: 0.026921
# Epoch: 333 	||	 Training Loss: 0.025991 	||	 Validation Loss: 0.026815
# Epoch: 334 	||	 Training Loss: 0.025971 	||	 Validation Loss: 0.026720
# Epoch: 335 	||	 Training Loss: 0.025761 	||	 Validation Loss: 0.026664
# Epoch: 336 	||	 Training Loss: 0.025607 	||	 Validation Loss: 0.026599
# Epoch: 337 	||	 Training Loss: 0.025515 	||	 Validation Loss: 0.026500
# Epoch: 338 	||	 Training Loss: 0.025364 	||	 Validation Loss: 0.026330
# Epoch: 339 	||	 Training Loss: 0.025280 	||	 Validation Loss: 0.026245
# Epoch: 340 	||	 Training Loss: 0.025273 	||	 Validation Loss: 0.026129
# Epoch: 341 	||	 Training Loss: 0.025239 	||	 Validation Loss: 0.026081
# Epoch: 342 	||	 Training Loss: 0.025120 	||	 Validation Loss: 0.026069
# Epoch: 343 	||	 Training Loss: 0.024998 	||	 Validation Loss: 0.025861
# Epoch: 344 	||	 Training Loss: 0.024920 	||	 Validation Loss: 0.026124
# Epoch: 345 	||	 Training Loss: 0.024854 	||	 Validation Loss: 0.026141
# Epoch: 346 	||	 Training Loss: 0.024850 	||	 Validation Loss: 0.026143
# Epoch: 347 	||	 Training Loss: 0.024764 	||	 Validation Loss: 0.026166
# Epoch: 348 	||	 Training Loss: 0.024719 	||	 Validation Loss: 0.026211
# Epoch: 349 	||	 Training Loss: 0.024701 	||	 Validation Loss: 0.026271
# Epoch: 350 	||	 Training Loss: 0.024527 	||	 Validation Loss: 0.025719
# Epoch: 351 	||	 Training Loss: 0.024486 	||	 Validation Loss: 0.025628
# Epoch: 352 	||	 Training Loss: 0.024437 	||	 Validation Loss: 0.025662
# Epoch: 353 	||	 Training Loss: 0.024401 	||	 Validation Loss: 0.026076
# Epoch: 354 	||	 Training Loss: 0.024334 	||	 Validation Loss: 0.026455
# Epoch: 355 	||	 Training Loss: 0.024274 	||	 Validation Loss: 0.026389
# Epoch: 356 	||	 Training Loss: 0.024289 	||	 Validation Loss: 0.026337
# Epoch: 357 	||	 Training Loss: 0.024523 	||	 Validation Loss: 0.025720
# Epoch: 358 	||	 Training Loss: 0.024415 	||	 Validation Loss: 0.026070
# Epoch: 359 	||	 Training Loss: 0.024322 	||	 Validation Loss: 0.026234
# Epoch: 360 	||	 Training Loss: 0.024301 	||	 Validation Loss: 0.024753
# Epoch: 361 	||	 Training Loss: 0.024235 	||	 Validation Loss: 0.024386
# Epoch: 362 	||	 Training Loss: 0.024036 	||	 Validation Loss: 0.024403
# Epoch: 363 	||	 Training Loss: 0.024107 	||	 Validation Loss: 0.024402
# Epoch: 364 	||	 Training Loss: 0.024026 	||	 Validation Loss: 0.024398
# Epoch: 365 	||	 Training Loss: 0.024137 	||	 Validation Loss: 0.024048
# Epoch: 366 	||	 Training Loss: 0.024093 	||	 Validation Loss: 0.023932
# Epoch: 367 	||	 Training Loss: 0.024045 	||	 Validation Loss: 0.024401
# Epoch: 368 	||	 Training Loss: 0.023847 	||	 Validation Loss: 0.024392
# Epoch: 369 	||	 Training Loss: 0.023606 	||	 Validation Loss: 0.024714
# Epoch: 370 	||	 Training Loss: 0.023429 	||	 Validation Loss: 0.024673
# Epoch: 371 	||	 Training Loss: 0.023404 	||	 Validation Loss: 0.024514
# Epoch: 372 	||	 Training Loss: 0.023535 	||	 Validation Loss: 0.024515
# Epoch: 373 	||	 Training Loss: 0.023631 	||	 Validation Loss: 0.025045
# Epoch: 374 	||	 Training Loss: 0.023154 	||	 Validation Loss: 0.024987
# Epoch: 375 	||	 Training Loss: 0.023142 	||	 Validation Loss: 0.024800
# Epoch: 376 	||	 Training Loss: 0.023271 	||	 Validation Loss: 0.024799
# Epoch: 377 	||	 Training Loss: 0.023314 	||	 Validation Loss: 0.024883
# Epoch: 378 	||	 Training Loss: 0.023436 	||	 Validation Loss: 0.024618
# Epoch: 379 	||	 Training Loss: 0.023370 	||	 Validation Loss: 0.024558
# Epoch: 380 	||	 Training Loss: 0.023248 	||	 Validation Loss: 0.024534
# Epoch: 381 	||	 Training Loss: 0.023234 	||	 Validation Loss: 0.024560
# Epoch: 382 	||	 Training Loss: 0.023283 	||	 Validation Loss: 0.024428
# Epoch: 383 	||	 Training Loss: 0.023231 	||	 Validation Loss: 0.024370
# Epoch: 384 	||	 Training Loss: 0.023234 	||	 Validation Loss: 0.024394
# Epoch: 385 	||	 Training Loss: 0.023237 	||	 Validation Loss: 0.024398
# Epoch: 386 	||	 Training Loss: 0.023020 	||	 Validation Loss: 0.024559
# Epoch: 387 	||	 Training Loss: 0.022903 	||	 Validation Loss: 0.024547
# Epoch: 388 	||	 Training Loss: 0.022863 	||	 Validation Loss: 0.024519
# Epoch: 389 	||	 Training Loss: 0.022782 	||	 Validation Loss: 0.024501
# Epoch: 390 	||	 Training Loss: 0.022783 	||	 Validation Loss: 0.024419
# Epoch: 391 	||	 Training Loss: 0.022926 	||	 Validation Loss: 0.024405
# Epoch: 392 	||	 Training Loss: 0.022864 	||	 Validation Loss: 0.024328
# Epoch: 393 	||	 Training Loss: 0.022734 	||	 Validation Loss: 0.024129
# Epoch: 394 	||	 Training Loss: 0.022651 	||	 Validation Loss: 0.024266
# Epoch: 395 	||	 Training Loss: 0.022510 	||	 Validation Loss: 0.024325
# Epoch: 396 	||	 Training Loss: 0.022507 	||	 Validation Loss: 0.024348
# Epoch: 397 	||	 Training Loss: 0.022457 	||	 Validation Loss: 0.024317
# Epoch: 398 	||	 Training Loss: 0.022434 	||	 Validation Loss: 0.024370
# Epoch: 399 	||	 Training Loss: 0.022416 	||	 Validation Loss: 0.024293
# Epoch: 400 	||	 Training Loss: 0.022271 	||	 Validation Loss: 0.024250
# Epoch: 401 	||	 Training Loss: 0.022294 	||	 Validation Loss: 0.024116
# Epoch: 402 	||	 Training Loss: 0.022276 	||	 Validation Loss: 0.024087
# Epoch: 403 	||	 Training Loss: 0.022263 	||	 Validation Loss: 0.024020
# Epoch: 404 	||	 Training Loss: 0.022261 	||	 Validation Loss: 0.023800
# Epoch: 405 	||	 Training Loss: 0.022232 	||	 Validation Loss: 0.023790
# Epoch: 406 	||	 Training Loss: 0.022171 	||	 Validation Loss: 0.023910
# Epoch: 407 	||	 Training Loss: 0.022151 	||	 Validation Loss: 0.024058
# Epoch: 408 	||	 Training Loss: 0.022123 	||	 Validation Loss: 0.024040
# Epoch: 409 	||	 Training Loss: 0.022169 	||	 Validation Loss: 0.024010
# Epoch: 410 	||	 Training Loss: 0.022131 	||	 Validation Loss: 0.024047
# Epoch: 411 	||	 Training Loss: 0.022143 	||	 Validation Loss: 0.024050
# Epoch: 412 	||	 Training Loss: 0.022065 	||	 Validation Loss: 0.023984
# Epoch: 413 	||	 Training Loss: 0.022028 	||	 Validation Loss: 0.023927
# Epoch: 414 	||	 Training Loss: 0.021993 	||	 Validation Loss: 0.023884
# Epoch: 415 	||	 Training Loss: 0.021956 	||	 Validation Loss: 0.023852
# Epoch: 416 	||	 Training Loss: 0.021964 	||	 Validation Loss: 0.023740
# Epoch: 417 	||	 Training Loss: 0.021921 	||	 Validation Loss: 0.023718
# Epoch: 418 	||	 Training Loss: 0.021926 	||	 Validation Loss: 0.023728
# Epoch: 419 	||	 Training Loss: 0.021892 	||	 Validation Loss: 0.023711
# Epoch: 420 	||	 Training Loss: 0.021860 	||	 Validation Loss: 0.023680
# Epoch: 421 	||	 Training Loss: 0.021837 	||	 Validation Loss: 0.023656
# Epoch: 422 	||	 Training Loss: 0.021809 	||	 Validation Loss: 0.023837
# Epoch: 423 	||	 Training Loss: 0.021749 	||	 Validation Loss: 0.023814
# Epoch: 424 	||	 Training Loss: 0.021755 	||	 Validation Loss: 0.023783
# Epoch: 425 	||	 Training Loss: 0.021763 	||	 Validation Loss: 0.023772
# Epoch: 426 	||	 Training Loss: 0.021774 	||	 Validation Loss: 0.023590
# Epoch: 427 	||	 Training Loss: 0.021731 	||	 Validation Loss: 0.023551
# Epoch: 428 	||	 Training Loss: 0.021732 	||	 Validation Loss: 0.023521
# Epoch: 429 	||	 Training Loss: 0.021671 	||	 Validation Loss: 0.023487
# Epoch: 430 	||	 Training Loss: 0.021661 	||	 Validation Loss: 0.023421
# Epoch: 431 	||	 Training Loss: 0.021636 	||	 Validation Loss: 0.023318
# Epoch: 432 	||	 Training Loss: 0.021610 	||	 Validation Loss: 0.023265
# Epoch: 433 	||	 Training Loss: 0.021565 	||	 Validation Loss: 0.023017
# Epoch: 434 	||	 Training Loss: 0.021551 	||	 Validation Loss: 0.022988
# Epoch: 435 	||	 Training Loss: 0.021501 	||	 Validation Loss: 0.022968
# Epoch: 436 	||	 Training Loss: 0.021469 	||	 Validation Loss: 0.022945
# Epoch: 437 	||	 Training Loss: 0.021461 	||	 Validation Loss: 0.023026
# Epoch: 438 	||	 Training Loss: 0.021403 	||	 Validation Loss: 0.023004
# Epoch: 439 	||	 Training Loss: 0.021393 	||	 Validation Loss: 0.023000
# Epoch: 440 	||	 Training Loss: 0.021295 	||	 Validation Loss: 0.023055
# Epoch: 441 	||	 Training Loss: 0.021294 	||	 Validation Loss: 0.022936
# Epoch: 442 	||	 Training Loss: 0.021252 	||	 Validation Loss: 0.022938
# Epoch: 443 	||	 Training Loss: 0.021264 	||	 Validation Loss: 0.023008
# Epoch: 444 	||	 Training Loss: 0.021215 	||	 Validation Loss: 0.022988
# Epoch: 445 	||	 Training Loss: 0.021182 	||	 Validation Loss: 0.022967
# Epoch: 446 	||	 Training Loss: 0.021151 	||	 Validation Loss: 0.022664
# Epoch: 447 	||	 Training Loss: 0.021198 	||	 Validation Loss: 0.022669
# Epoch: 448 	||	 Training Loss: 0.021193 	||	 Validation Loss: 0.022646
# Epoch: 449 	||	 Training Loss: 0.021178 	||	 Validation Loss: 0.022643
# Epoch: 450 	||	 Training Loss: 0.021154 	||	 Validation Loss: 0.022499
# Epoch: 451 	||	 Training Loss: 0.021122 	||	 Validation Loss: 0.022504
# Epoch: 452 	||	 Training Loss: 0.021091 	||	 Validation Loss: 0.022481
# Epoch: 453 	||	 Training Loss: 0.021075 	||	 Validation Loss: 0.022426
# Epoch: 454 	||	 Training Loss: 0.021054 	||	 Validation Loss: 0.022410
# Epoch: 455 	||	 Training Loss: 0.021045 	||	 Validation Loss: 0.022393
# Epoch: 456 	||	 Training Loss: 0.021020 	||	 Validation Loss: 0.022374
# Epoch: 457 	||	 Training Loss: 0.020996 	||	 Validation Loss: 0.022356
# Epoch: 458 	||	 Training Loss: 0.020981 	||	 Validation Loss: 0.022339
# Epoch: 459 	||	 Training Loss: 0.020988 	||	 Validation Loss: 0.022324
# Epoch: 460 	||	 Training Loss: 0.020984 	||	 Validation Loss: 0.022307
# Epoch: 461 	||	 Training Loss: 0.020958 	||	 Validation Loss: 0.022194
# Epoch: 462 	||	 Training Loss: 0.020953 	||	 Validation Loss: 0.022196
# Epoch: 463 	||	 Training Loss: 0.020945 	||	 Validation Loss: 0.022260
# Epoch: 464 	||	 Training Loss: 0.020936 	||	 Validation Loss: 0.022242
# Epoch: 465 	||	 Training Loss: 0.020897 	||	 Validation Loss: 0.022226
# Epoch: 466 	||	 Training Loss: 0.020876 	||	 Validation Loss: 0.022112
# Epoch: 467 	||	 Training Loss: 0.020857 	||	 Validation Loss: 0.022093
# Epoch: 468 	||	 Training Loss: 0.020834 	||	 Validation Loss: 0.022080
# Epoch: 469 	||	 Training Loss: 0.020819 	||	 Validation Loss: 0.022152
# Epoch: 470 	||	 Training Loss: 0.020793 	||	 Validation Loss: 0.022135
# Epoch: 471 	||	 Training Loss: 0.020776 	||	 Validation Loss: 0.022117
# Epoch: 472 	||	 Training Loss: 0.020783 	||	 Validation Loss: 0.022113
# Epoch: 473 	||	 Training Loss: 0.020798 	||	 Validation Loss: 0.022096
# Epoch: 474 	||	 Training Loss: 0.020790 	||	 Validation Loss: 0.022077
# Epoch: 475 	||	 Training Loss: 0.020778 	||	 Validation Loss: 0.022059
# Epoch: 476 	||	 Training Loss: 0.020713 	||	 Validation Loss: 0.022048
# Epoch: 477 	||	 Training Loss: 0.020699 	||	 Validation Loss: 0.022023
# Epoch: 478 	||	 Training Loss: 0.020676 	||	 Validation Loss: 0.021997
# Epoch: 479 	||	 Training Loss: 0.020667 	||	 Validation Loss: 0.021957
# Epoch: 480 	||	 Training Loss: 0.020665 	||	 Validation Loss: 0.021947
# Epoch: 481 	||	 Training Loss: 0.020641 	||	 Validation Loss: 0.022061
# Epoch: 482 	||	 Training Loss: 0.020615 	||	 Validation Loss: 0.022023
# Epoch: 483 	||	 Training Loss: 0.020606 	||	 Validation Loss: 0.022034
# Epoch: 484 	||	 Training Loss: 0.020601 	||	 Validation Loss: 0.022019
# Epoch: 485 	||	 Training Loss: 0.020592 	||	 Validation Loss: 0.021991
# Epoch: 486 	||	 Training Loss: 0.020577 	||	 Validation Loss: 0.021977
# Epoch: 487 	||	 Training Loss: 0.020562 	||	 Validation Loss: 0.021961
# Epoch: 488 	||	 Training Loss: 0.020550 	||	 Validation Loss: 0.021949
# Epoch: 489 	||	 Training Loss: 0.020535 	||	 Validation Loss: 0.021908
# Epoch: 490 	||	 Training Loss: 0.020515 	||	 Validation Loss: 0.021888
# Epoch: 491 	||	 Training Loss: 0.020499 	||	 Validation Loss: 0.021858
# Epoch: 492 	||	 Training Loss: 0.020478 	||	 Validation Loss: 0.021604
# Epoch: 493 	||	 Training Loss: 0.020481 	||	 Validation Loss: 0.021606
# Epoch: 494 	||	 Training Loss: 0.020476 	||	 Validation Loss: 0.021602
# Epoch: 495 	||	 Training Loss: 0.020469 	||	 Validation Loss: 0.021648
# Epoch: 496 	||	 Training Loss: 0.020455 	||	 Validation Loss: 0.021635
# Epoch: 497 	||	 Training Loss: 0.020446 	||	 Validation Loss: 0.021624
# Epoch: 498 	||	 Training Loss: 0.020438 	||	 Validation Loss: 0.021608
# Epoch: 499 	||	 Training Loss: 0.020423 	||	 Validation Loss: 0.021590
# Epoch: 500 	||	 Training Loss: 0.020444 	||	 Validation Loss: 0.021570
# Epoch: 501 	||	 Training Loss: 0.020431 	||	 Validation Loss: 0.021542
# Epoch: 502 	||	 Training Loss: 0.020407 	||	 Validation Loss: 0.021483
# Epoch: 503 	||	 Training Loss: 0.020423 	||	 Validation Loss: 0.021465
# Epoch: 504 	||	 Training Loss: 0.020428 	||	 Validation Loss: 0.021447
# Epoch: 505 	||	 Training Loss: 0.020423 	||	 Validation Loss: 0.021430
# Epoch: 506 	||	 Training Loss: 0.020412 	||	 Validation Loss: 0.021413
# Epoch: 507 	||	 Training Loss: 0.020391 	||	 Validation Loss: 0.021400
# Epoch: 508 	||	 Training Loss: 0.020394 	||	 Validation Loss: 0.021377
# Epoch: 509 	||	 Training Loss: 0.020383 	||	 Validation Loss: 0.021356
# Epoch: 510 	||	 Training Loss: 0.020374 	||	 Validation Loss: 0.021334
# Epoch: 511 	||	 Training Loss: 0.020313 	||	 Validation Loss: 0.021313
# Epoch: 512 	||	 Training Loss: 0.020312 	||	 Validation Loss: 0.021249
# Epoch: 513 	||	 Training Loss: 0.020306 	||	 Validation Loss: 0.021226
# Epoch: 514 	||	 Training Loss: 0.020299 	||	 Validation Loss: 0.021208
# Epoch: 515 	||	 Training Loss: 0.020270 	||	 Validation Loss: 0.021189
# Epoch: 516 	||	 Training Loss: 0.020271 	||	 Validation Loss: 0.021170
# Epoch: 517 	||	 Training Loss: 0.020246 	||	 Validation Loss: 0.021161
# Epoch: 518 	||	 Training Loss: 0.020238 	||	 Validation Loss: 0.021195
# Epoch: 519 	||	 Training Loss: 0.020230 	||	 Validation Loss: 0.021167
# Epoch: 520 	||	 Training Loss: 0.020232 	||	 Validation Loss: 0.021148
# Epoch: 521 	||	 Training Loss: 0.020250 	||	 Validation Loss: 0.021119
# Epoch: 522 	||	 Training Loss: 0.020242 	||	 Validation Loss: 0.021101
# Epoch: 523 	||	 Training Loss: 0.020241 	||	 Validation Loss: 0.021080
# Epoch: 524 	||	 Training Loss: 0.020232 	||	 Validation Loss: 0.021059
# Epoch: 525 	||	 Training Loss: 0.020185 	||	 Validation Loss: 0.021045
# Epoch: 526 	||	 Training Loss: 0.020158 	||	 Validation Loss: 0.021026
# Epoch: 527 	||	 Training Loss: 0.020141 	||	 Validation Loss: 0.021009
# Epoch: 528 	||	 Training Loss: 0.020136 	||	 Validation Loss: 0.020954
# Epoch: 529 	||	 Training Loss: 0.020132 	||	 Validation Loss: 0.020940
# Epoch: 530 	||	 Training Loss: 0.020130 	||	 Validation Loss: 0.020919
# Epoch: 531 	||	 Training Loss: 0.020138 	||	 Validation Loss: 0.020899
# Epoch: 532 	||	 Training Loss: 0.020125 	||	 Validation Loss: 0.020866
# Epoch: 533 	||	 Training Loss: 0.020122 	||	 Validation Loss: 0.020841
# Epoch: 534 	||	 Training Loss: 0.020111 	||	 Validation Loss: 0.020824
# Epoch: 535 	||	 Training Loss: 0.020099 	||	 Validation Loss: 0.020806
# Epoch: 536 	||	 Training Loss: 0.020082 	||	 Validation Loss: 0.020790
# Epoch: 537 	||	 Training Loss: 0.020070 	||	 Validation Loss: 0.020775
# Epoch: 538 	||	 Training Loss: 0.020049 	||	 Validation Loss: 0.020761
# Epoch: 539 	||	 Training Loss: 0.020045 	||	 Validation Loss: 0.020874
# Epoch: 540 	||	 Training Loss: 0.020036 	||	 Validation Loss: 0.020857
# Epoch: 541 	||	 Training Loss: 0.020030 	||	 Validation Loss: 0.020840
# Epoch: 542 	||	 Training Loss: 0.020024 	||	 Validation Loss: 0.020805
# Epoch: 543 	||	 Training Loss: 0.020006 	||	 Validation Loss: 0.020785
# Epoch: 544 	||	 Training Loss: 0.020002 	||	 Validation Loss: 0.020849
# Epoch: 545 	||	 Training Loss: 0.019993 	||	 Validation Loss: 0.020832
# Epoch: 546 	||	 Training Loss: 0.020003 	||	 Validation Loss: 0.020817
# Epoch: 547 	||	 Training Loss: 0.019990 	||	 Validation Loss: 0.020802
# Epoch: 548 	||	 Training Loss: 0.019978 	||	 Validation Loss: 0.020787
# Epoch: 549 	||	 Training Loss: 0.019972 	||	 Validation Loss: 0.020771
# Epoch: 550 	||	 Training Loss: 0.019972 	||	 Validation Loss: 0.020727
# Epoch: 551 	||	 Training Loss: 0.019968 	||	 Validation Loss: 0.020714
# Epoch: 552 	||	 Training Loss: 0.019980 	||	 Validation Loss: 0.020609
# Epoch: 553 	||	 Training Loss: 0.019982 	||	 Validation Loss: 0.020594
# Epoch: 554 	||	 Training Loss: 0.019988 	||	 Validation Loss: 0.020579
# Epoch: 555 	||	 Training Loss: 0.019978 	||	 Validation Loss: 0.020658
# Epoch: 556 	||	 Training Loss: 0.019970 	||	 Validation Loss: 0.020627
# Epoch: 557 	||	 Training Loss: 0.019970 	||	 Validation Loss: 0.020613
# Epoch: 558 	||	 Training Loss: 0.019948 	||	 Validation Loss: 0.020599
# Epoch: 559 	||	 Training Loss: 0.019942 	||	 Validation Loss: 0.020615
# Epoch: 560 	||	 Training Loss: 0.019936 	||	 Validation Loss: 0.020577
# Epoch: 561 	||	 Training Loss: 0.019956 	||	 Validation Loss: 0.020568
# Epoch: 562 	||	 Training Loss: 0.019966 	||	 Validation Loss: 0.020553
# Epoch: 563 	||	 Training Loss: 0.019961 	||	 Validation Loss: 0.020538
# Epoch: 564 	||	 Training Loss: 0.019951 	||	 Validation Loss: 0.020525
# Epoch: 565 	||	 Training Loss: 0.019933 	||	 Validation Loss: 0.020554
# Epoch: 566 	||	 Training Loss: 0.019931 	||	 Validation Loss: 0.020550
# Epoch: 567 	||	 Training Loss: 0.019934 	||	 Validation Loss: 0.020563
# Epoch: 568 	||	 Training Loss: 0.019928 	||	 Validation Loss: 0.020491
# Epoch: 569 	||	 Training Loss: 0.019922 	||	 Validation Loss: 0.020479
# Epoch: 570 	||	 Training Loss: 0.019915 	||	 Validation Loss: 0.020467
# Epoch: 571 	||	 Training Loss: 0.019907 	||	 Validation Loss: 0.020454
# Epoch: 572 	||	 Training Loss: 0.019881 	||	 Validation Loss: 0.020440
# Epoch: 573 	||	 Training Loss: 0.019819 	||	 Validation Loss: 0.020425
# Epoch: 574 	||	 Training Loss: 0.019798 	||	 Validation Loss: 0.020366
# Epoch: 575 	||	 Training Loss: 0.019785 	||	 Validation Loss: 0.020347
# Epoch: 576 	||	 Training Loss: 0.019760 	||	 Validation Loss: 0.020330
# Epoch: 577 	||	 Training Loss: 0.019751 	||	 Validation Loss: 0.020258
# Epoch: 578 	||	 Training Loss: 0.019746 	||	 Validation Loss: 0.020258
# Epoch: 579 	||	 Training Loss: 0.019741 	||	 Validation Loss: 0.020248
# Epoch: 580 	||	 Training Loss: 0.019730 	||	 Validation Loss: 0.020233
# Epoch: 581 	||	 Training Loss: 0.019723 	||	 Validation Loss: 0.020223
# Epoch: 582 	||	 Training Loss: 0.019704 	||	 Validation Loss: 0.020212
# Epoch: 583 	||	 Training Loss: 0.019695 	||	 Validation Loss: 0.020211
# Epoch: 584 	||	 Training Loss: 0.019720 	||	 Validation Loss: 0.020198
# Epoch: 585 	||	 Training Loss: 0.019718 	||	 Validation Loss: 0.020187
# Epoch: 586 	||	 Training Loss: 0.019724 	||	 Validation Loss: 0.020252
# Epoch: 587 	||	 Training Loss: 0.019702 	||	 Validation Loss: 0.020240
# Epoch: 588 	||	 Training Loss: 0.019690 	||	 Validation Loss: 0.020146
# Epoch: 589 	||	 Training Loss: 0.019684 	||	 Validation Loss: 0.020117
# Epoch: 590 	||	 Training Loss: 0.019676 	||	 Validation Loss: 0.020185
# Epoch: 591 	||	 Training Loss: 0.019663 	||	 Validation Loss: 0.020177
# Epoch: 592 	||	 Training Loss: 0.019638 	||	 Validation Loss: 0.020167
# Epoch: 593 	||	 Training Loss: 0.019624 	||	 Validation Loss: 0.020150
# Epoch: 594 	||	 Training Loss: 0.019612 	||	 Validation Loss: 0.020139
# Epoch: 595 	||	 Training Loss: 0.019600 	||	 Validation Loss: 0.020128
# Epoch: 596 	||	 Training Loss: 0.019593 	||	 Validation Loss: 0.020118
# Epoch: 597 	||	 Training Loss: 0.019593 	||	 Validation Loss: 0.020109
# Epoch: 598 	||	 Training Loss: 0.019587 	||	 Validation Loss: 0.020099
# Epoch: 599 	||	 Training Loss: 0.019571 	||	 Validation Loss: 0.020098
# Epoch: 600 	||	 Training Loss: 0.019569 	||	 Validation Loss: 0.020091
# Epoch: 601 	||	 Training Loss: 0.019511 	||	 Validation Loss: 0.019937
# Epoch: 602 	||	 Training Loss: 0.019502 	||	 Validation Loss: 0.019926
# Epoch: 603 	||	 Training Loss: 0.019496 	||	 Validation Loss: 0.019916
# Epoch: 604 	||	 Training Loss: 0.019491 	||	 Validation Loss: 0.019984
# Epoch: 605 	||	 Training Loss: 0.019487 	||	 Validation Loss: 0.019893
# Epoch: 606 	||	 Training Loss: 0.019497 	||	 Validation Loss: 0.019883
# Epoch: 607 	||	 Training Loss: 0.019485 	||	 Validation Loss: 0.019850
# Epoch: 608 	||	 Training Loss: 0.019481 	||	 Validation Loss: 0.019841
# Epoch: 609 	||	 Training Loss: 0.019490 	||	 Validation Loss: 0.019745
# Epoch: 610 	||	 Training Loss: 0.019486 	||	 Validation Loss: 0.019736
# Epoch: 611 	||	 Training Loss: 0.019474 	||	 Validation Loss: 0.019727
# Epoch: 612 	||	 Training Loss: 0.019467 	||	 Validation Loss: 0.019718
# Epoch: 613 	||	 Training Loss: 0.019461 	||	 Validation Loss: 0.019710
# Epoch: 614 	||	 Training Loss: 0.019452 	||	 Validation Loss: 0.019701
# Epoch: 615 	||	 Training Loss: 0.019451 	||	 Validation Loss: 0.019745
# Epoch: 616 	||	 Training Loss: 0.019446 	||	 Validation Loss: 0.019737
# Epoch: 617 	||	 Training Loss: 0.019431 	||	 Validation Loss: 0.019729
# Epoch: 618 	||	 Training Loss: 0.019426 	||	 Validation Loss: 0.019704
# Epoch: 619 	||	 Training Loss: 0.019431 	||	 Validation Loss: 0.019696
# Epoch: 620 	||	 Training Loss: 0.019427 	||	 Validation Loss: 0.019688
# Epoch: 621 	||	 Training Loss: 0.019421 	||	 Validation Loss: 0.019680
# Epoch: 622 	||	 Training Loss: 0.019424 	||	 Validation Loss: 0.019673
# Epoch: 623 	||	 Training Loss: 0.019423 	||	 Validation Loss: 0.019623
# Epoch: 624 	||	 Training Loss: 0.019414 	||	 Validation Loss: 0.019604
# Epoch: 625 	||	 Training Loss: 0.019411 	||	 Validation Loss: 0.019578
# Epoch: 626 	||	 Training Loss: 0.019405 	||	 Validation Loss: 0.019593
# Epoch: 627 	||	 Training Loss: 0.019399 	||	 Validation Loss: 0.019585
# Epoch: 628 	||	 Training Loss: 0.019394 	||	 Validation Loss: 0.019577
# Epoch: 629 	||	 Training Loss: 0.019394 	||	 Validation Loss: 0.019570
# Epoch: 630 	||	 Training Loss: 0.019389 	||	 Validation Loss: 0.019566
# Epoch: 631 	||	 Training Loss: 0.019381 	||	 Validation Loss: 0.019559
# Epoch: 632 	||	 Training Loss: 0.019376 	||	 Validation Loss: 0.019551
# Epoch: 633 	||	 Training Loss: 0.019378 	||	 Validation Loss: 0.019543
# Epoch: 634 	||	 Training Loss: 0.019332 	||	 Validation Loss: 0.019527
# Epoch: 635 	||	 Training Loss: 0.019319 	||	 Validation Loss: 0.019502
# Epoch: 636 	||	 Training Loss: 0.019320 	||	 Validation Loss: 0.019494
# Epoch: 637 	||	 Training Loss: 0.019319 	||	 Validation Loss: 0.019487
# Epoch: 638 	||	 Training Loss: 0.019309 	||	 Validation Loss: 0.019480
# Epoch: 639 	||	 Training Loss: 0.019324 	||	 Validation Loss: 0.019476
# Epoch: 640 	||	 Training Loss: 0.019282 	||	 Validation Loss: 0.019464
# Epoch: 641 	||	 Training Loss: 0.019324 	||	 Validation Loss: 0.019458
# Epoch: 642 	||	 Training Loss: 0.019281 	||	 Validation Loss: 0.019453
# Epoch: 643 	||	 Training Loss: 0.019280 	||	 Validation Loss: 0.019472
# Epoch: 644 	||	 Training Loss: 0.019310 	||	 Validation Loss: 0.019477
# Epoch: 645 	||	 Training Loss: 0.019312 	||	 Validation Loss: 0.019471
# Epoch: 646 	||	 Training Loss: 0.019333 	||	 Validation Loss: 0.019565
# Epoch: 647 	||	 Training Loss: 0.019295 	||	 Validation Loss: 0.019559
# Epoch: 648 	||	 Training Loss: 0.019296 	||	 Validation Loss: 0.019550
# Epoch: 649 	||	 Training Loss: 0.019294 	||	 Validation Loss: 0.019545
# Epoch: 650 	||	 Training Loss: 0.019287 	||	 Validation Loss: 0.019539
# Epoch: 651 	||	 Training Loss: 0.019303 	||	 Validation Loss: 0.019500
# Epoch: 652 	||	 Training Loss: 0.019273 	||	 Validation Loss: 0.019494
# Epoch: 653 	||	 Training Loss: 0.019269 	||	 Validation Loss: 0.019488
# Epoch: 654 	||	 Training Loss: 0.019262 	||	 Validation Loss: 0.019482
# Epoch: 655 	||	 Training Loss: 0.019273 	||	 Validation Loss: 0.019477
# Epoch: 656 	||	 Training Loss: 0.019269 	||	 Validation Loss: 0.019471
# Epoch: 657 	||	 Training Loss: 0.019264 	||	 Validation Loss: 0.019465
# Epoch: 658 	||	 Training Loss: 0.019260 	||	 Validation Loss: 0.019460
# Epoch: 659 	||	 Training Loss: 0.019255 	||	 Validation Loss: 0.019456
# Epoch: 660 	||	 Training Loss: 0.019251 	||	 Validation Loss: 0.019451
# Epoch: 661 	||	 Training Loss: 0.019254 	||	 Validation Loss: 0.019446
# Epoch: 662 	||	 Training Loss: 0.019246 	||	 Validation Loss: 0.019441
# Epoch: 663 	||	 Training Loss: 0.019234 	||	 Validation Loss: 0.019413
# Epoch: 664 	||	 Training Loss: 0.019249 	||	 Validation Loss: 0.019426
# Epoch: 665 	||	 Training Loss: 0.019248 	||	 Validation Loss: 0.019421
# Epoch: 666 	||	 Training Loss: 0.019245 	||	 Validation Loss: 0.019415
# Epoch: 667 	||	 Training Loss: 0.019237 	||	 Validation Loss: 0.019397
# Epoch: 668 	||	 Training Loss: 0.019230 	||	 Validation Loss: 0.019391
# Epoch: 669 	||	 Training Loss: 0.019230 	||	 Validation Loss: 0.019386
# Epoch: 670 	||	 Training Loss: 0.019228 	||	 Validation Loss: 0.019381
# Epoch: 671 	||	 Training Loss: 0.019224 	||	 Validation Loss: 0.019388
# Epoch: 672 	||	 Training Loss: 0.019219 	||	 Validation Loss: 0.019384
# Epoch: 673 	||	 Training Loss: 0.019206 	||	 Validation Loss: 0.019378
# Epoch: 674 	||	 Training Loss: 0.019208 	||	 Validation Loss: 0.019371
# Epoch: 675 	||	 Training Loss: 0.019205 	||	 Validation Loss: 0.019367
# Epoch: 676 	||	 Training Loss: 0.019203 	||	 Validation Loss: 0.019365
# Epoch: 677 	||	 Training Loss: 0.019199 	||	 Validation Loss: 0.019360
# Epoch: 678 	||	 Training Loss: 0.019197 	||	 Validation Loss: 0.019347
# Epoch: 679 	||	 Training Loss: 0.019191 	||	 Validation Loss: 0.019342
# Epoch: 680 	||	 Training Loss: 0.019186 	||	 Validation Loss: 0.019337
# Epoch: 681 	||	 Training Loss: 0.019187 	||	 Validation Loss: 0.019265
# Epoch: 682 	||	 Training Loss: 0.019192 	||	 Validation Loss: 0.019260
# Epoch: 683 	||	 Training Loss: 0.019192 	||	 Validation Loss: 0.019256
# Epoch: 684 	||	 Training Loss: 0.019193 	||	 Validation Loss: 0.019251
# Epoch: 685 	||	 Training Loss: 0.019190 	||	 Validation Loss: 0.019338
# Epoch: 686 	||	 Training Loss: 0.019190 	||	 Validation Loss: 0.019334
# Epoch: 687 	||	 Training Loss: 0.019189 	||	 Validation Loss: 0.019304
# Epoch: 688 	||	 Training Loss: 0.019193 	||	 Validation Loss: 0.019300
# Epoch: 689 	||	 Training Loss: 0.019177 	||	 Validation Loss: 0.019295
# Epoch: 690 	||	 Training Loss: 0.019172 	||	 Validation Loss: 0.019290
# Epoch: 691 	||	 Training Loss: 0.019168 	||	 Validation Loss: 0.019284
# Epoch: 692 	||	 Training Loss: 0.019166 	||	 Validation Loss: 0.019197
# Epoch: 693 	||	 Training Loss: 0.019164 	||	 Validation Loss: 0.019192
# Epoch: 694 	||	 Training Loss: 0.019159 	||	 Validation Loss: 0.019124
# Epoch: 695 	||	 Training Loss: 0.019160 	||	 Validation Loss: 0.019120
# Epoch: 696 	||	 Training Loss: 0.019151 	||	 Validation Loss: 0.019163
# Epoch: 697 	||	 Training Loss: 0.019150 	||	 Validation Loss: 0.019159
# Epoch: 698 	||	 Training Loss: 0.019150 	||	 Validation Loss: 0.019153
# Epoch: 699 	||	 Training Loss: 0.019142 	||	 Validation Loss: 0.019150
# Epoch: 700 	||	 Training Loss: 0.019138 	||	 Validation Loss: 0.019146

# %% [markdown]
# ### Plots: identification results for the negative feedback of S and K

# %%
# --------------Plot identification results for G-----------------

patient_str = "/paz_" + str(int(patient)).zfill(3)
patient_model_folder = model_folder + "/" + patient_str + "/" + "strategy_2" 
MODEL_PATH = Path(patient_model_folder)
PARAM_PATH = MODEL_PATH / "params" / "parameters.mat"
params = scipy.io.loadmat(PARAM_PATH)

x0          = torch.tensor(params['x0'])
input_dim   = params["input_dim"].flatten().astype(int).tolist()
output_dim  = params["output_dim"].flatten().astype(int).tolist()
dim_internal= params["dim_internal"].flatten().astype(int).tolist()
dim_nl      = params["dim_nl"].flatten().astype(int).tolist()

y_init      = torch.tensor(params['y_init'])
gamma       = torch.tensor(params['gamma']).flatten()

train_losses = params["train_losses"][0]
val_losses   = params["val_losses"][0]
epoch_best   = int(params["epoch_when_model_saved"][0])


# ----------------------------------

epochs = 700


#Training and Validation Loss Across Epochs
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), train_losses, label='Training Loss', color='blue')
plt.plot(range(epochs), val_losses, label='Validation Loss', color='red')  # Assuming val_losses are collected
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)

saturation_error_init, glucose_PID_init, y0_1 = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
y0_0 = torch.zeros_like(y0_1) # meal ren initialized to 0
REN_0 = REN_IQC_gamma(dim_in= input_dim[0], dim_out= output_dim[0], dim_internal=dim_internal[0], dim_nl= dim_nl[0], y_init =  y0_0.unsqueeze(1), QR_fun = set_QR, gammat=gamma[0], IQC_type = IQC_type[0], device=device)
REN_S = REN_IQC_gamma(dim_in= input_dim[1], dim_out= output_dim[1], dim_internal=dim_internal[1], dim_nl= dim_nl[1], y_init = - y0_1.unsqueeze(1), QR_fun = set_QR, gammat=gamma[1], IQC_type = IQC_type[1], device=device)
Dual_REN = DualREN(REN_0, REN_S, device=device)
controller = NonLinearController_p2(loaded_parameters, PID_functions, dataset.basal_vec, scaler_glucose, scaler_insulin, scaler_meal, use_noise = use_noise)
closed_loop_REN = ClosedLoopSystem(Dual_REN, controller, negative=True)


checkpoint = torch.load(MODEL_PATH / "trained_models.pth", map_location="cpu")
state_dict = checkpoint["Dueal_REN_state_dict"]

# Rimuovi tutte le chiavi di inizializzazione
state_dict.pop("REN_0.y_init", None)
state_dict.pop("REN_1.y_init", None)
state_dict.pop("REN_0.x_init", None)
state_dict.pop("REN_1.x_init", None)

Dual_REN.load_state_dict(state_dict, strict=False)
Dual_REN.eval()

for u0_batch, _, _, u1_batch, y_batch, t_batch in train_loader_p:

    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(t_batch) # batch_size, time_horizon, input_dim
    u0_batch, u1_batch, y_batch, t_batch = u0_batch.to(device), u1_batch.to(device), y_batch.to(device), t_batch.to(device)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(train_loader_p, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
            
    _, y_hat_train = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  


    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat_train.detach().cpu()).numpy()
    
    break # just first batch

# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(t_batch[0,:,0], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(t_batch[0,:,0], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Train Set, first batch")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()





for u0_batch, _, _, u1_batch, y_batch, time in test_loader:

    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input di
    
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()
    


# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time, y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time, y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()



# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_insulin_30g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())

# --- Creazione di un Dataset custom ---
class TestDataset(Dataset):
    def __init__(self, MH, I, y, sequence_length=1):
        """
        MH: meal input (torch tensor)
        I: insulin input (torch tensor)
        y: output (glucose) (torch tensor)
        sequence_length: lunghezza sequenza temporale per la RNN/REN
        """
        self.MH = MH.unsqueeze(-1) if MH.ndim==1 else MH  # shape (N,1)
        self.I  = I.unsqueeze(-1) if I.ndim==1 else I
        self.y  = y.unsqueeze(-1) if y.ndim==1 else y
        self.seq_len = sequence_length

    def __len__(self):
        return len(self.y) - self.seq_len + 1

    def __getitem__(self, idx):
        u0_seq = self.MH[idx:idx+self.seq_len]
        u1_seq = self.I[idx:idx+self.seq_len]
        y_seq  = self.y[idx:idx+self.seq_len]
        time_seq = torch.arange(idx, idx+self.seq_len)
        return u0_seq, u1_seq, y_seq, time_seq

# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)

for u0_batch, u1_batch, y_batch, time in test_loader_new:

    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input di
    
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, insulin")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()


# -------------------------------------------------------------
# -------------------------------------------------------------
data_path = './data/test/sc_1_day_test_IR_meal_80g_13h/'

loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')

# Insulin suggestions saturated (effectively given by the pump)
I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
I_data = I_data[:,0]
i = scaler_insulin.normalize(torch.from_numpy(I_data).float())
CGM = loaded['CGM']['signals'][0, 0]['values'][0, 0][1::5].flatten()
y = scaler_glucose.normalize(torch.from_numpy(CGM).float())
true_carbs_hypo_redone_05 = loaded['carb_intake']['signals'][0, 0]['values'][0, 0][1:-1:2].flatten()
MH = true_carbs_hypo_redone_05.reshape(-1, 5).sum(axis=1)
m = scaler_meal.normalize(torch.from_numpy(MH).float())


# --- Definizione del dataset e DataLoader ---
sequence_length = len(y)  # puoi aumentare se vuoi usare finestre temporali
test_dataset_new = TestDataset(MH=m, I=i, y=y, sequence_length=sequence_length)

batch_size = 1
test_loader_new = DataLoader(
    test_dataset_new,
    batch_size=batch_size,
    shuffle=False
)

for u0_batch, u1_batch, y_batch, time in test_loader_new:

    
    u0_batch, u1_batch, y_batch, t_batch = ensure_3d(u0_batch), ensure_3d(u1_batch), ensure_3d(y_batch), ensure_3d(time)
    u_batch = torch.cat((u0_batch, u1_batch), dim=2)  # concatenate along input di
    
    
    saturation_error_init, glucose_PID_init, _ = fun_start_controller(test_loader_new, loaded_parameters, scaler_glucose, scaler_insulin, dataset)
    closed_loop_REN.reset(y0 = y_batch[:,:1,:1], saturation_error_init = saturation_error_init, glucose_PID_init = glucose_PID_init)
    
    _, y_hat = closed_loop_REN(u_batch, t_batch, y0 = y_batch[:,:1,:1])  

    y_batch_np = scaler_glucose.denormalize(y_batch.detach().cpu()).numpy()
    y_hat_np = scaler_glucose.denormalize(y_hat.detach().cpu()).numpy()



# -------------------------------------------------------------
# Model's Predictions vs Actual Output for the test set
plt.figure(figsize=(10, 6))
plt.plot(time.detach().cpu().numpy()[0,:], y_batch_np[0, :, 0], label="Real Output", color="blue")
plt.plot(time.detach().cpu().numpy()[0,:], y_hat_np[0, :, 0], label="Predicted Output", linestyle="--", color="orange")
plt.title(f"Test Set, meal")
plt.xlabel("Time (s)")
plt.ylabel("Output Value")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\pmong\AppData\Local\Temp\ipykernel_17236\3748521492.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   epoch_best   = int(params["epoch_when_model_saved"][0])
# c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\code\exp_2\models.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   basal = torch.tensor(basal, dtype=torch.float32) # MODIFICATO PER BATCH
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/test/sc_1_day_test_IR_insulin_30g_13h//s#adult#001.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 132
#     128 # -------------------------------------------------------------
#     129 # -------------------------------------------------------------
#     130 data_path = './data/test/sc_1_day_test_IR_insulin_30g_13h/'
# --> 132 loaded = sio.loadmat(f'{data_path}/s#adult#{patient:03d}.mat')
#     134 # Insulin suggestions saturated (effectively given by the pump)
#     135 I_data = loaded['injection']['signals'][0, 0]['values'][0, 0][1::5] / 6000  # now in U
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\scipy\io\matlab\_mio.py:225, in loadmat(file_name, mdict, appendmat, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)
#     222     3.14159265+3.14159265j])
#     223 """
#     224 variable_names = kwargs.pop('variable_names', None)
# --> 225 with _open_file_context(file_name, appendmat) as f:
#     226     MR, _ = mat_reader_factory(f, **kwargs)
#     227     matfile_dict = MR.get_variables(variable_names)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\scipy\io\matlab\_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File c:\Users\pmong\OneDrive - Università di Pavia\EPFL\Nonlinear_system_identification_modified\non_lin_sys_id\lib\site-packages\scipy\io\matlab\_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/test/sc_1_day_test_IR_insulin_30g_13h//s#adult#001.mat'
