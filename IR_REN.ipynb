# %% [markdown]
# ### Imports

# %%
# %config InlineBackend.figure_format = 'svg'

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pickle
from models import NonLinearController, ClosedLoopSystem, NonLinearController_p2, Double_closed_loop
# from Rens import REN_IQC_gamma, DualREN
from utils import set_params, set_QR, ensure_3d, fun_start_controller, fun_start_controller_simple
from torch.utils.data import DataLoader, random_split, Subset, SubsetRandomSampler, Dataset, TensorDataset
from ParametersFunctions import Parameter, PID_functions, MinMaxScalerTorch
from pathlib import Path
import scipy.io as sio
from dataset import LoadData, SimpleLoadData

# from neural_ssm import DeepSSM

# model = DeepSSM(d_input=1, d_output=1, param='l2n')  #lru   l2n gamma prescritto
# y, _ = model(torch.tensor([5.0]))
# print(y)

# %%
class REN_IQC_gamma(nn.Module):

    def __init__(
        self, dim_in: int, dim_out: int, dim_internal: int,
        dim_nl: int, internal_state_init = None, y_init = None,
        initialization_std: float = 0.5, pos_def_tol: float = 0.001, gammat=None, QR_fun=None, IQC_type='l2_gain',
        Q=None, R=None, S=None, device='cpu'
    ):
        """
        Args:
            dim_in (int): Input (u) dimension.
            dim_out (int): Output (y) dimension.
            dim_internal (int): Internal state (x) dimension. This state evolves with contraction properties.
            dim_nl (int): Dimension of the input ("v") and ouput ("w") of the nonlinear static block.
            initialization_std (float, optional): Weight initialization. Set to 0.1 by default.
            internal_state_init (torch.Tensor or None, optional): Initial condition for the internal state. Defaults to 0 when set to None.
            epsilon (float, optional): Positive and negligible scalar to force positive definite matrices.
            gamma (float, optional):  Defaults to 1.
        """
        super().__init__()
        
        self.device = device

        # set dimensions
        self.dim_in = dim_in
        self.dim_out = dim_out
        self.dim_internal = dim_internal
        self.dim_nl = dim_nl

        # set functionalities

        self.IQC_type = IQC_type
        self.QR_fun = QR_fun
        self.Q = Q
        self.R = R
        self.S = S
        

        # auxiliary elements
        self.epsilon = pos_def_tol

        # # # free parameters except for D22
        # define matrices shapes
        # auxiliary matrices
        self.X_shape = (2 * dim_internal + dim_nl, 2 * dim_internal + dim_nl)
        self.Y_shape = (dim_internal, dim_internal)
        # nn state dynamics
        self.B2_shape = (dim_internal, dim_in)
        # nn output
        self.C2_shape = (dim_out, dim_internal)
        self.D21_shape = (dim_out, dim_nl)
        self.D22_shape = (dim_out, dim_in)


        # v signal
        self.D12_shape = (dim_nl, dim_in)

        self.s = np.max((dim_in, dim_out))
        # self.X3_shape = (self.s, self.s)
        # self.Y3_shape = (self.s, self.s)
        # self.Z3_shape = (abs(dim_out - dim_in), min(dim_out, dim_in))

        self.gamma_shape = (1, 1)
        self.gammat = gammat
        self.device = device

        # define trainable params
        self.training_param_names = ['X', 'Y', 'B2', 'C2', 'D21', 'D12']
        if self.gammat is None:
            self.training_param_names.append('gamma')
        else:
            self.gamma = gammat

        # initialize trainable parameters
        self._init_trainable_params(initialization_std)

        # register buffers (non-trainable masks)
        self.register_buffer('eye_mask_min', torch.eye(min(dim_in, dim_out), device=device))
        self.register_buffer('eye_mask_dim_in', torch.eye(dim_in, device=device))
        self.register_buffer('eye_mask_dim_out', torch.eye(dim_out, device=device))
        self.register_buffer('eye_mask_dim_state', torch.eye(dim_internal, device=device))
        self.register_buffer('eye_mask_H', torch.eye(2 * dim_internal + dim_nl, device=device))
        self.register_buffer('zeros_mask_S', torch.zeros(dim_in, dim_out, device=device))
        self.register_buffer('zeros_mask_Q', torch.zeros(dim_out, dim_out, device=device))
        self.register_buffer('zeros_mask_R', torch.zeros(dim_in, dim_in, device=device))
        self.register_buffer('zeros_mask_so', torch.zeros(dim_internal, dim_out, device=device))
        self.register_buffer('eye_mask_w', torch.eye(dim_nl, device=device))
        
        batch_size = 1  # default batch size

        # initialize internal state
        if internal_state_init is not None:
            assert isinstance(internal_state_init, torch.Tensor)
            self.x = internal_state_init.reshape(1, 1, dim_internal)
        elif y_init is not None:
            batch_size = y_init.shape[0]
            self.C2 = nn.Parameter(self.C2.data)  # C2 already inizializzato come Parameter
            self.x = torch.stack([
                torch.linalg.lstsq(self.C2, y_init[b, 0, :].unsqueeze(1))[0].T
                for b in range(batch_size)
            ], dim=0).unsqueeze(1)
            # self.x = torch.linalg.lstsq(self.C2, y_init.squeeze(1).T)[0].T.unsqueeze(0).unsqueeze(0)
        else:
            self.x = torch.zeros(1, 1, dim_internal)

        # register initial state buffers
        self.register_buffer('x_init', self.x.detach().clone())
        y_init_calc = F.linear(self.x_init, self.C2)
        y_init_calc = y_init_calc.view(batch_size, 1, self.dim_out)
        self.register_buffer('y_init', y_init_calc)

        # move everything to device
        self.to(device)

        # esplicito solo stato interno (già incluso in buffers), ma per sicurezza
        self.x = self.x.to(device)
        

    def _update_model_param(self):
        """
        Update non-trainable matrices according to the REN formulation to preserve IQC.
        """
        dim_internal, dim_nl, dim_in, dim_out = self.dim_internal, self.dim_nl, self.dim_in, self.dim_out

        if self.QR_fun is not None:
            self.Q, self.R, self.S = self.QR_fun(self.gamma, dim_in, dim_out, self.IQC_type)
        else:
            # monotone
            eps = 1e-4

            # monotone on l2
            self.Q = torch.zeros(self.dim_out, self.dim_out) -eps * torch.eye(self.dim_out) # 0
            self.R = - 2 * self.gamma * torch.eye(self.dim_in, self.dim_in)  # -2 nu I
            self.S = torch.eye(self.dim_out, self.dim_in)  # I


        self.D22 = torch.zeros(self.dim_out, self.dim_in)

        # psi terms (keep same)
        R_cal = self.R
        R_cal_inv = torch.inverse(R_cal)
        C2_cal = torch.matmul(torch.matmul(self.D22.T, self.Q) + self.S, self.C2)
        D21_cal = torch.matmul(torch.matmul(self.D22.T, self.Q) + self.S, self.D21) - self.D12.T
        
        vec_r = torch.cat((C2_cal.T, D21_cal.T, self.B2), dim=0)
        psi_r = torch.matmul(vec_r, torch.matmul(R_cal_inv, vec_r.T))

        vec_q = torch.cat((self.C2.T, self.D21.T, self.zeros_mask_so), dim=0)
        psi_q = torch.matmul(vec_q, torch.matmul(self.Q, vec_q.T))

        H = torch.matmul(self.X.T, self.X) + self.epsilon * self.eye_mask_H + psi_r - psi_q
        
        h1, h2, h3 = torch.split(H, [dim_internal, dim_nl, dim_internal], dim=0)
        H11, H12, H13 = torch.split(h1, [dim_internal, dim_nl, dim_internal], dim=1)
        H21, H22, _ = torch.split(h2, [dim_internal, dim_nl, dim_internal], dim=1)
        H31, H32, H33 = torch.split(h3, [dim_internal, dim_nl, dim_internal], dim=1)
        self.P_cal = H33
        # NN state dynamics:
        self.F = H31
        self.B1 = H32
        # NN output:
        self.E = 0.5 * (H11 + self.P_cal + self.Y - self.Y.T)
        self.E_inv = self.E.inverse()
        # v signal:  [Change the following 2 lines if we don't want a strictly acyclic REN!]
        self.Lambda = 0.5 * torch.diag(H22)
        self.D11 = -torch.tril(H22, diagonal=-1)
        self.C1 = -H21
        # Matrix P
        #self.P = torch.matmul(self.E.T, torch.matmul(torch.inverse(self.P_cal), self.E))

    def forward(self, u_in):
        """
        Forward pass of REN.

        Args:
            u_in (torch.Tensor): Input with the size of (batch_size, 1, self.dim_in).

        Return:
            y_out (torch.Tensor): Output with (batch_size, 1, self.dim_out).
        """
        # update non-trainable model params
        self._update_model_param()

        batch_size = u_in.shape[0]

        w = torch.zeros(batch_size, 1, self.dim_nl, device=u_in.device)

        # update each row of w using Eq. (8) with a lower triangular D11
        for i in range(self.dim_nl): # does the non linear one by one but all together the multiple batches
            #  v is element i of v with dim (batch_size, 1)
            v = F.linear(self.x, self.C1[i, :]) + F.linear(w, self.D11[i, :]) + F.linear(u_in, self.D12[i, :])
            w = w + (self.eye_mask_w[i, :] * torch.tanh(v / self.Lambda[i])).reshape(batch_size, 1, self.dim_nl) # w dim [batch 1 dim_nl]


        # compute next state using Eq. 18
        self.x = F.linear(F.linear(self.x, self.F) + F.linear(w, self.B1) + F.linear(u_in, self.B2), self.E_inv)

        # compute output
        y_out = F.linear(self.x, self.C2) + F.linear(w, self.D21) # + F.linear(u_in, self.D22)
        return y_out

    def reset(self, x0=None, y0= None):
        """
        Reset compatibile con ClosedLoopSystem.
        Se x0 è fornito (shape (batch, 1, dim_internal) o (1, 1, dim_internal)),
        lo utilizza come stato; altrimenti usa self.x_init (replicato per batch se necessario).
        """
        batch_size = y0.shape[0]
        if x0 is not None:
            # accetta sia (1,1,dim) sia (batch,1,dim)
            self.x = x0.clone().to(self.device)
        elif y0 is not None:
            self.x = torch.stack([
                torch.linalg.lstsq(self.C2, y0[b, 0, :].unsqueeze(1))[0].T
                for b in range(batch_size)
                ], dim=0).to(self.device)
            self.y_init = y0.detach().clone().to(self.device)
        else:
            # default behaviour: reset to x_init, replicate to batch_size se richiesto
            if batch_size is None:
                self.x = self.x_init.clone().to(self.device)
            else:
                self.x = self.x_init.detach().clone().repeat(batch_size, 1, 1).to(self.device)


    def y0_from_x0(self, x0: torch.Tensor) -> torch.Tensor:
        """
        Given an internal state x0 (batch,1,dim_internal) returns the corresponding y0.
        We assume initial w = 0 and u = 0, so y0 = C2 @ x0 (linear part).
        """
        return F.linear(x0, self.C2)


    def run(self, u_in, x0=None, y0=None):
        """
        Runs the forward pass of REN for a whole input sequence of length horizon.

        Args:
            u_in (torch.Tensor): Input with the size of (batch_size, horizon, self.dim_in).

        Return:
            y_out (torch.Tensor): Output with (batch_size, horizon, self.dim_out).
        """

        self.reset(x0 = x0, y0 = y0)
        if y0 is not None:
            y_log = y0.detach().clone()
        else:
            y_log = self.y_init.detach().clone()
       
            
        for t in range(u_in.shape[1] - 1):
            y_log = torch.cat((y_log, self.forward(u_in[:, t:t + 1, :])), 1)
        # note that the last input is not used
        return y_log

    # init trainable params
    def _init_trainable_params(self, initialization_std):
        for training_param_name in self.training_param_names:  # name of one of the training params, e.g., X
            # read the defined shapes of the selected training param, e.g., X_shape
            shape = getattr(self, training_param_name + '_shape')
            # define the selected param (e.g., self.X) as nn.Parameter
            if training_param_name == 'gamma':
                initialization_std = 3
            setattr(self, training_param_name, nn.Parameter((torch.randn(*shape) * initialization_std)))

    # setters and getters
    def get_parameter_shapes(self):
        param_dict = OrderedDict(
            (name, getattr(self, name).shape) for name in self.training_param_names
        )
        return param_dict

    def get_named_parameters(self):
        param_dict = OrderedDict(
            (name, getattr(self, name)) for name in self.training_param_names
        )
        return param_dict

    def __call__(self,u_in, x0=None, y0=None):
        return self.run(u_in, x0, y0)

# %% [markdown]
# ### REN model 101, loss function and optimizer parallel
# as strategy 1

# %%
# input pos
flag_y_ref_pos = False   # True 
#if true the y ref is positive, if false is Negative


flag_y_hat_pos = True  # True 
#if false the output of the REN is inverted

epochs = 1000

gamma = torch.tensor([40])

# --------------------------


y_pos = torch.cat([
    torch.zeros(20),
    torch.sin(torch.linspace(0, torch.pi, 50)),
    torch.zeros(20)
])

u = torch.cat([
    torch.zeros(20),
    torch.tensor([1.0]),
    torch.zeros(69)
])

# reshape (T, dim_in)
u = u[:, None].float()        # (T, 1)
y_pos = y_pos[:, None].float()  # (T, 1)
y_neg = -y_pos

T = u.shape[0]

# -------------------------- 2. Define dataset and loader ------------------------------------
# Add batch dimension: (1, T, 1)
dataset_pos = TensorDataset(u[None, :, :], y_pos[None, :, :])
dataset_neg = TensorDataset(u[None, :, :], y_neg[None, :, :])

loader_pos = DataLoader(dataset_pos, batch_size=1, shuffle=False)
loader_neg = DataLoader(dataset_neg, batch_size=1, shuffle=False)

# -------------------------- 3. Define model ---------------------------------------------

y0_0 = torch.zeros(1)[None,:,None]
REN_prova = REN_IQC_gamma(dim_in= 1, dim_out= 1, dim_internal=8, dim_nl= 8, y_init = y0_0, gammat = gamma)

# Loss and optimizer
MSE = nn.MSELoss()
optimizer = torch.optim.Adam(REN_prova.parameters(), lr=0.001)

# -------------------------- 4. Training loop ---------------------------------------------

train_losses = []

if flag_y_ref_pos:
    loader = loader_pos
else: 
    loader = loader_neg

for epoch in range(epochs):
    REN_prova.train()
    epoch_loss = 0.0
    for u_batch, y_batch in loader:
        optimizer.zero_grad()
        # REN_prova.reset(y0 = y_batch[:,:1,:1])
        y_hat = REN_prova(u_batch, y0 = y_batch[:,:1,:1])   # builds graph only for this sequence
        
        if flag_y_hat_pos == False: 
            y_hat = -y_hat

        loss = MSE(y_hat, y_batch)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    train_losses.append(epoch_loss)

    print(f"Epoch {epoch}, Loss: {epoch_loss:.6f}")
    
    if epoch == epochs-1:
        
        plt.figure(figsize=(15,10))
        plt.plot(y_hat[0,:,0].detach().numpy(), label='Predicted')
        plt.plot(y_batch[0,:,0].detach().numpy(), label='Target')
        plt.plot(u_batch[0,:,0].detach().numpy(), label='u')
        plt.grid()
        plt.legend()
        plt.show()
# Out:
# Epoch 0, Loss: 0.271543
# Epoch 1, Loss: 0.271392
# Epoch 2, Loss: 0.271239
# Epoch 3, Loss: 0.271082
# Epoch 4, Loss: 0.270920
# Epoch 5, Loss: 0.270750
# Epoch 6, Loss: 0.270571
# Epoch 7, Loss: 0.270382
# Epoch 8, Loss: 0.270181
# Epoch 9, Loss: 0.269965
# Epoch 10, Loss: 0.269733
# Epoch 11, Loss: 0.269481
# Epoch 12, Loss: 0.269207
# Epoch 13, Loss: 0.268909
# Epoch 14, Loss: 0.268582
# Epoch 15, Loss: 0.268223
# Epoch 16, Loss: 0.267828
# Epoch 17, Loss: 0.267392
# Epoch 18, Loss: 0.266909
# Epoch 19, Loss: 0.266375
# Epoch 20, Loss: 0.265781
# Epoch 21, Loss: 0.265122
# Epoch 22, Loss: 0.264387
# Epoch 23, Loss: 0.263568
# Epoch 24, Loss: 0.262653
# Epoch 25, Loss: 0.261631
# Epoch 26, Loss: 0.260487
# Epoch 27, Loss: 0.259207
# Epoch 28, Loss: 0.257772
# Epoch 29, Loss: 0.256163
# Epoch 30, Loss: 0.254358
# Epoch 31, Loss: 0.252334
# Epoch 32, Loss: 0.250064
# Epoch 33, Loss: 0.247519
# Epoch 34, Loss: 0.244668
# Epoch 35, Loss: 0.241481
# Epoch 36, Loss: 0.237924
# Epoch 37, Loss: 0.233966
# Epoch 38, Loss: 0.229571
# Epoch 39, Loss: 0.224709
# Epoch 40, Loss: 0.219347
# Epoch 41, Loss: 0.213455
# Epoch 42, Loss: 0.207012
# Epoch 43, Loss: 0.200003
# Epoch 44, Loss: 0.192429
# Epoch 45, Loss: 0.184314
# Epoch 46, Loss: 0.175714
# Epoch 47, Loss: 0.166717
# Epoch 48, Loss: 0.157455
# Epoch 49, Loss: 0.148101
# Epoch 50, Loss: 0.138869
# Epoch 51, Loss: 0.130013
# Epoch 52, Loss: 0.121811
# Epoch 53, Loss: 0.114543
# Epoch 54, Loss: 0.108451
# Epoch 55, Loss: 0.103686
# Epoch 56, Loss: 0.100261
# Epoch 57, Loss: 0.098007
# Epoch 58, Loss: 0.096563
# Epoch 59, Loss: 0.095444
# Epoch 60, Loss: 0.094183
# Epoch 61, Loss: 0.092529
# Epoch 62, Loss: 0.090615
# Epoch 63, Loss: 0.088961
# Epoch 64, Loss: 0.088157
# Epoch 65, Loss: 0.088189
# Epoch 66, Loss: 0.088166
# Epoch 67, Loss: 0.087445
# Epoch 68, Loss: 0.086267
# Epoch 69, Loss: 0.085274
# Epoch 70, Loss: 0.084897
# Epoch 71, Loss: 0.084994
# Epoch 72, Loss: 0.085028
# Epoch 73, Loss: 0.084663
# Epoch 74, Loss: 0.084049
# Epoch 75, Loss: 0.083584
# Epoch 76, Loss: 0.083497
# Epoch 77, Loss: 0.083623
# Epoch 78, Loss: 0.083613
# Epoch 79, Loss: 0.083332
# Epoch 80, Loss: 0.082960
# Epoch 81, Loss: 0.082754
# Epoch 82, Loss: 0.082763
# Epoch 83, Loss: 0.082797
# Epoch 84, Loss: 0.082669
# Epoch 85, Loss: 0.082410
# Epoch 86, Loss: 0.082196
# Epoch 87, Loss: 0.082124
# Epoch 88, Loss: 0.082110
# Epoch 89, Loss: 0.082013
# Epoch 90, Loss: 0.081812
# Epoch 91, Loss: 0.081607
# Epoch 92, Loss: 0.081486
# Epoch 93, Loss: 0.081418
# Epoch 94, Loss: 0.081309
# Epoch 95, Loss: 0.081130
# Epoch 96, Loss: 0.080946
# Epoch 97, Loss: 0.080817
# Epoch 98, Loss: 0.080721
# Epoch 99, Loss: 0.080597
# Epoch 100, Loss: 0.080430
# Epoch 101, Loss: 0.080263
# Epoch 102, Loss: 0.080133
# Epoch 103, Loss: 0.080021
# Epoch 104, Loss: 0.079887
# Epoch 105, Loss: 0.079731
# Epoch 106, Loss: 0.079584
# Epoch 107, Loss: 0.079462
# Epoch 108, Loss: 0.079344
# Epoch 109, Loss: 0.079206
# Epoch 110, Loss: 0.079060
# Epoch 111, Loss: 0.078926
# Epoch 112, Loss: 0.078806
# Epoch 113, Loss: 0.078679
# Epoch 114, Loss: 0.078540
# Epoch 115, Loss: 0.078403
# Epoch 116, Loss: 0.078277
# Epoch 117, Loss: 0.078152
# Epoch 118, Loss: 0.078017
# Epoch 119, Loss: 0.077878
# Epoch 120, Loss: 0.077745
# Epoch 121, Loss: 0.077615
# Epoch 122, Loss: 0.077480
# Epoch 123, Loss: 0.077339
# Epoch 124, Loss: 0.077200
# Epoch 125, Loss: 0.077064
# Epoch 126, Loss: 0.076924
# Epoch 127, Loss: 0.076780
# Epoch 128, Loss: 0.076635
# Epoch 129, Loss: 0.076492
# Epoch 130, Loss: 0.076347
# Epoch 131, Loss: 0.076197
# Epoch 132, Loss: 0.076047
# Epoch 133, Loss: 0.075898
# Epoch 134, Loss: 0.075746
# Epoch 135, Loss: 0.075590
# Epoch 136, Loss: 0.075433
# Epoch 137, Loss: 0.075276
# Epoch 138, Loss: 0.075116
# Epoch 139, Loss: 0.074953
# Epoch 140, Loss: 0.074789
# Epoch 141, Loss: 0.074623
# Epoch 142, Loss: 0.074454
# Epoch 143, Loss: 0.074281
# Epoch 144, Loss: 0.074107
# Epoch 145, Loss: 0.073930
# Epoch 146, Loss: 0.073750
# Epoch 147, Loss: 0.073566
# Epoch 148, Loss: 0.073380
# Epoch 149, Loss: 0.073190
# Epoch 150, Loss: 0.072996
# Epoch 151, Loss: 0.072799
# Epoch 152, Loss: 0.072597
# Epoch 153, Loss: 0.072391
# Epoch 154, Loss: 0.072181
# Epoch 155, Loss: 0.071967
# Epoch 156, Loss: 0.071747
# Epoch 157, Loss: 0.071522
# Epoch 158, Loss: 0.071291
# Epoch 159, Loss: 0.071055
# Epoch 160, Loss: 0.070813
# Epoch 161, Loss: 0.070565
# Epoch 162, Loss: 0.070310
# Epoch 163, Loss: 0.070047
# Epoch 164, Loss: 0.069777
# Epoch 165, Loss: 0.069500
# Epoch 166, Loss: 0.069213
# Epoch 167, Loss: 0.068918
# Epoch 168, Loss: 0.068614
# Epoch 169, Loss: 0.068299
# Epoch 170, Loss: 0.067974
# Epoch 171, Loss: 0.067637
# Epoch 172, Loss: 0.067288
# Epoch 173, Loss: 0.066926
# Epoch 174, Loss: 0.066551
# Epoch 175, Loss: 0.066161
# Epoch 176, Loss: 0.065755
# Epoch 177, Loss: 0.065333
# Epoch 178, Loss: 0.064892
# Epoch 179, Loss: 0.064433
# Epoch 180, Loss: 0.063953
# Epoch 181, Loss: 0.063451
# Epoch 182, Loss: 0.062925
# Epoch 183, Loss: 0.062373
# Epoch 184, Loss: 0.061794
# Epoch 185, Loss: 0.061185
# Epoch 186, Loss: 0.060544
# Epoch 187, Loss: 0.059869
# Epoch 188, Loss: 0.059155
# Epoch 189, Loss: 0.058401
# Epoch 190, Loss: 0.057603
# Epoch 191, Loss: 0.056756
# Epoch 192, Loss: 0.055857
# Epoch 193, Loss: 0.054902
# Epoch 194, Loss: 0.053885
# Epoch 195, Loss: 0.052800
# Epoch 196, Loss: 0.051643
# Epoch 197, Loss: 0.050406
# Epoch 198, Loss: 0.049083
# Epoch 199, Loss: 0.047667
# Epoch 200, Loss: 0.046151
# Epoch 201, Loss: 0.044528
# Epoch 202, Loss: 0.042791
# Epoch 203, Loss: 0.040934
# Epoch 204, Loss: 0.038953
# Epoch 205, Loss: 0.036846
# Epoch 206, Loss: 0.034616
# Epoch 207, Loss: 0.032271
# Epoch 208, Loss: 0.029824
# Epoch 209, Loss: 0.027301
# Epoch 210, Loss: 0.024735
# Epoch 211, Loss: 0.022170
# Epoch 212, Loss: 0.019664
# Epoch 213, Loss: 0.017278
# Epoch 214, Loss: 0.015078
# Epoch 215, Loss: 0.013121
# Epoch 216, Loss: 0.011454
# Epoch 217, Loss: 0.010134
# Epoch 218, Loss: 0.009723
# Epoch 219, Loss: 0.016077
# Epoch 220, Loss: 0.016433
# Epoch 221, Loss: 0.011560
# Epoch 222, Loss: 0.012936
# Epoch 223, Loss: 0.010431
# Epoch 224, Loss: 0.009870
# Epoch 225, Loss: 0.011802
# Epoch 226, Loss: 0.007345
# Epoch 227, Loss: 0.011644
# Epoch 228, Loss: 0.007720
# Epoch 229, Loss: 0.009418
# Epoch 230, Loss: 0.009522
# Epoch 231, Loss: 0.007371
# Epoch 232, Loss: 0.009785
# Epoch 233, Loss: 0.007601
# Epoch 234, Loss: 0.008346
# Epoch 235, Loss: 0.008709
# Epoch 236, Loss: 0.007220
# Epoch 237, Loss: 0.008607
# Epoch 238, Loss: 0.007529
# Epoch 239, Loss: 0.007616
# Epoch 240, Loss: 0.008103
# Epoch 241, Loss: 0.007099
# Epoch 242, Loss: 0.007867
# Epoch 243, Loss: 0.007378
# Epoch 244, Loss: 0.007266
# Epoch 245, Loss: 0.007665
# Epoch 246, Loss: 0.007040
# Epoch 247, Loss: 0.007465
# Epoch 248, Loss: 0.007228
# Epoch 249, Loss: 0.007106
# Epoch 250, Loss: 0.007367
# Epoch 251, Loss: 0.006986
# Epoch 252, Loss: 0.007223
# Epoch 253, Loss: 0.007094
# Epoch 254, Loss: 0.007001
# Epoch 255, Loss: 0.007162
# Epoch 256, Loss: 0.006933
# Epoch 257, Loss: 0.007066
# Epoch 258, Loss: 0.006998
# Epoch 259, Loss: 0.006935
# Epoch 260, Loss: 0.007035
# Epoch 261, Loss: 0.006899
# Epoch 262, Loss: 0.006974
# Epoch 263, Loss: 0.006939
# Epoch 264, Loss: 0.006897
# Epoch 265, Loss: 0.006957
# Epoch 266, Loss: 0.006876
# Epoch 267, Loss: 0.006918
# Epoch 268, Loss: 0.006896
# Epoch 269, Loss: 0.006870
# Epoch 270, Loss: 0.006904
# Epoch 271, Loss: 0.006854
# Epoch 272, Loss: 0.006880
# Epoch 273, Loss: 0.006863
# Epoch 274, Loss: 0.006849
# Epoch 275, Loss: 0.006866
# Epoch 276, Loss: 0.006835
# Epoch 277, Loss: 0.006852
# Epoch 278, Loss: 0.006838
# Epoch 279, Loss: 0.006832
# Epoch 280, Loss: 0.006839
# Epoch 281, Loss: 0.006820
# Epoch 282, Loss: 0.006830
# Epoch 283, Loss: 0.006817
# Epoch 284, Loss: 0.006816
# Epoch 285, Loss: 0.006816
# Epoch 286, Loss: 0.006805
# Epoch 287, Loss: 0.006809
# Epoch 288, Loss: 0.006799
# Epoch 289, Loss: 0.006799
# Epoch 290, Loss: 0.006796
# Epoch 291, Loss: 0.006790
# Epoch 292, Loss: 0.006791
# Epoch 293, Loss: 0.006783
# Epoch 294, Loss: 0.006784
# Epoch 295, Loss: 0.006779
# Epoch 296, Loss: 0.006776
# Epoch 297, Loss: 0.006774
# Epoch 298, Loss: 0.006769
# Epoch 299, Loss: 0.006768
# Epoch 300, Loss: 0.006763
# Epoch 301, Loss: 0.006761
# Epoch 302, Loss: 0.006758
# Epoch 303, Loss: 0.006755
# Epoch 304, Loss: 0.006753
# Epoch 305, Loss: 0.006749
# Epoch 306, Loss: 0.006747
# Epoch 307, Loss: 0.006744
# Epoch 308, Loss: 0.006741
# Epoch 309, Loss: 0.006738
# Epoch 310, Loss: 0.006735
# Epoch 311, Loss: 0.006733
# Epoch 312, Loss: 0.006729
# Epoch 313, Loss: 0.006727
# Epoch 314, Loss: 0.006724
# Epoch 315, Loss: 0.006721
# Epoch 316, Loss: 0.006719
# Epoch 317, Loss: 0.006716
# Epoch 318, Loss: 0.006713
# Epoch 319, Loss: 0.006710
# Epoch 320, Loss: 0.006708
# Epoch 321, Loss: 0.006705
# Epoch 322, Loss: 0.006702
# Epoch 323, Loss: 0.006700
# Epoch 324, Loss: 0.006697
# Epoch 325, Loss: 0.006694
# Epoch 326, Loss: 0.006692
# Epoch 327, Loss: 0.006689
# Epoch 328, Loss: 0.006686
# Epoch 329, Loss: 0.006684
# Epoch 330, Loss: 0.006681
# Epoch 331, Loss: 0.006678
# Epoch 332, Loss: 0.006676
# Epoch 333, Loss: 0.006673
# Epoch 334, Loss: 0.006670
# Epoch 335, Loss: 0.006668
# Epoch 336, Loss: 0.006665
# Epoch 337, Loss: 0.006663
# Epoch 338, Loss: 0.006660
# Epoch 339, Loss: 0.006657
# Epoch 340, Loss: 0.006655
# Epoch 341, Loss: 0.006652
# Epoch 342, Loss: 0.006649
# Epoch 343, Loss: 0.006647
# Epoch 344, Loss: 0.006644
# Epoch 345, Loss: 0.006642
# Epoch 346, Loss: 0.006639
# Epoch 347, Loss: 0.006636
# Epoch 348, Loss: 0.006634
# Epoch 349, Loss: 0.006631
# Epoch 350, Loss: 0.006629
# Epoch 351, Loss: 0.006626
# Epoch 352, Loss: 0.006623
# Epoch 353, Loss: 0.006621
# Epoch 354, Loss: 0.006618
# Epoch 355, Loss: 0.006616
# Epoch 356, Loss: 0.006613
# Epoch 357, Loss: 0.006611
# Epoch 358, Loss: 0.006608
# Epoch 359, Loss: 0.006605
# Epoch 360, Loss: 0.006603
# Epoch 361, Loss: 0.006600
# Epoch 362, Loss: 0.006598
# Epoch 363, Loss: 0.006595
# Epoch 364, Loss: 0.006593
# Epoch 365, Loss: 0.006590
# Epoch 366, Loss: 0.006588
# Epoch 367, Loss: 0.006585
# Epoch 368, Loss: 0.006582
# Epoch 369, Loss: 0.006580
# Epoch 370, Loss: 0.006577
# Epoch 371, Loss: 0.006575
# Epoch 372, Loss: 0.006572
# Epoch 373, Loss: 0.006570
# Epoch 374, Loss: 0.006567
# Epoch 375, Loss: 0.006565
# Epoch 376, Loss: 0.006562
# Epoch 377, Loss: 0.006560
# Epoch 378, Loss: 0.006557
# Epoch 379, Loss: 0.006555
# Epoch 380, Loss: 0.006552
# Epoch 381, Loss: 0.006549
# Epoch 382, Loss: 0.006547
# Epoch 383, Loss: 0.006544
# Epoch 384, Loss: 0.006542
# Epoch 385, Loss: 0.006539
# Epoch 386, Loss: 0.006537
# Epoch 387, Loss: 0.006534
# Epoch 388, Loss: 0.006532
# Epoch 389, Loss: 0.006529
# Epoch 390, Loss: 0.006527
# Epoch 391, Loss: 0.006524
# Epoch 392, Loss: 0.006522
# Epoch 393, Loss: 0.006519
# Epoch 394, Loss: 0.006517
# Epoch 395, Loss: 0.006514
# Epoch 396, Loss: 0.006512
# Epoch 397, Loss: 0.006509
# Epoch 398, Loss: 0.006507
# Epoch 399, Loss: 0.006504
# Epoch 400, Loss: 0.006502
# Epoch 401, Loss: 0.006499
# Epoch 402, Loss: 0.006497
# Epoch 403, Loss: 0.006494
# Epoch 404, Loss: 0.006492
# Epoch 405, Loss: 0.006489
# Epoch 406, Loss: 0.006487
# Epoch 407, Loss: 0.006484
# Epoch 408, Loss: 0.006482
# Epoch 409, Loss: 0.006479
# Epoch 410, Loss: 0.006477
# Epoch 411, Loss: 0.006474
# Epoch 412, Loss: 0.006472
# Epoch 413, Loss: 0.006469
# Epoch 414, Loss: 0.006467
# Epoch 415, Loss: 0.006464
# Epoch 416, Loss: 0.006462
# Epoch 417, Loss: 0.006459
# Epoch 418, Loss: 0.006456
# Epoch 419, Loss: 0.006454
# Epoch 420, Loss: 0.006451
# Epoch 421, Loss: 0.006449
# Epoch 422, Loss: 0.006446
# Epoch 423, Loss: 0.006444
# Epoch 424, Loss: 0.006441
# Epoch 425, Loss: 0.006439
# Epoch 426, Loss: 0.006436
# Epoch 427, Loss: 0.006434
# Epoch 428, Loss: 0.006431
# Epoch 429, Loss: 0.006429
# Epoch 430, Loss: 0.006426
# Epoch 431, Loss: 0.006424
# Epoch 432, Loss: 0.006421
# Epoch 433, Loss: 0.006419
# Epoch 434, Loss: 0.006416
# Epoch 435, Loss: 0.006414
# Epoch 436, Loss: 0.006411
# Epoch 437, Loss: 0.006409
# Epoch 438, Loss: 0.006406
# Epoch 439, Loss: 0.006404
# Epoch 440, Loss: 0.006401
# Epoch 441, Loss: 0.006399
# Epoch 442, Loss: 0.006396
# Epoch 443, Loss: 0.006394
# Epoch 444, Loss: 0.006391
# Epoch 445, Loss: 0.006389
# Epoch 446, Loss: 0.006386
# Epoch 447, Loss: 0.006384
# Epoch 448, Loss: 0.006381
# Epoch 449, Loss: 0.006379
# Epoch 450, Loss: 0.006376
# Epoch 451, Loss: 0.006373
# Epoch 452, Loss: 0.006371
# Epoch 453, Loss: 0.006368
# Epoch 454, Loss: 0.006366
# Epoch 455, Loss: 0.006363
# Epoch 456, Loss: 0.006361
# Epoch 457, Loss: 0.006358
# Epoch 458, Loss: 0.006356
# Epoch 459, Loss: 0.006353
# Epoch 460, Loss: 0.006351
# Epoch 461, Loss: 0.006348
# Epoch 462, Loss: 0.006346
# Epoch 463, Loss: 0.006343
# Epoch 464, Loss: 0.006340
# Epoch 465, Loss: 0.006338
# Epoch 466, Loss: 0.006335
# Epoch 467, Loss: 0.006333
# Epoch 468, Loss: 0.006330
# Epoch 469, Loss: 0.006328
# Epoch 470, Loss: 0.006325
# Epoch 471, Loss: 0.006323
# Epoch 472, Loss: 0.006320
# Epoch 473, Loss: 0.006317
# Epoch 474, Loss: 0.006315
# Epoch 475, Loss: 0.006312
# Epoch 476, Loss: 0.006310
# Epoch 477, Loss: 0.006307
# Epoch 478, Loss: 0.006305
# Epoch 479, Loss: 0.006302
# Epoch 480, Loss: 0.006299
# Epoch 481, Loss: 0.006297
# Epoch 482, Loss: 0.006294
# Epoch 483, Loss: 0.006292
# Epoch 484, Loss: 0.006289
# Epoch 485, Loss: 0.006287
# Epoch 486, Loss: 0.006284
# Epoch 487, Loss: 0.006281
# Epoch 488, Loss: 0.006279
# Epoch 489, Loss: 0.006276
# Epoch 490, Loss: 0.006274
# Epoch 491, Loss: 0.006271
# Epoch 492, Loss: 0.006268
# Epoch 493, Loss: 0.006266
# Epoch 494, Loss: 0.006263
# Epoch 495, Loss: 0.006261
# Epoch 496, Loss: 0.006258
# Epoch 497, Loss: 0.006255
# Epoch 498, Loss: 0.006253
# Epoch 499, Loss: 0.006250
# Epoch 500, Loss: 0.006247
# Epoch 501, Loss: 0.006245
# Epoch 502, Loss: 0.006242
# Epoch 503, Loss: 0.006240
# Epoch 504, Loss: 0.006237
# Epoch 505, Loss: 0.006234
# Epoch 506, Loss: 0.006232
# Epoch 507, Loss: 0.006229
# Epoch 508, Loss: 0.006226
# Epoch 509, Loss: 0.006224
# Epoch 510, Loss: 0.006221
# Epoch 511, Loss: 0.006218
# Epoch 512, Loss: 0.006216
# Epoch 513, Loss: 0.006213
# Epoch 514, Loss: 0.006210
# Epoch 515, Loss: 0.006208
# Epoch 516, Loss: 0.006205
# Epoch 517, Loss: 0.006202
# Epoch 518, Loss: 0.006200
# Epoch 519, Loss: 0.006197
# Epoch 520, Loss: 0.006194
# Epoch 521, Loss: 0.006192
# Epoch 522, Loss: 0.006189
# Epoch 523, Loss: 0.006186
# Epoch 524, Loss: 0.006184
# Epoch 525, Loss: 0.006181
# Epoch 526, Loss: 0.006178
# Epoch 527, Loss: 0.006175
# Epoch 528, Loss: 0.006173
# Epoch 529, Loss: 0.006170
# Epoch 530, Loss: 0.006167
# Epoch 531, Loss: 0.006165
# Epoch 532, Loss: 0.006162
# Epoch 533, Loss: 0.006159
# Epoch 534, Loss: 0.006156
# Epoch 535, Loss: 0.006154
# Epoch 536, Loss: 0.006151
# Epoch 537, Loss: 0.006148
# Epoch 538, Loss: 0.006146
# Epoch 539, Loss: 0.006143
# Epoch 540, Loss: 0.006140
# Epoch 541, Loss: 0.006137
# Epoch 542, Loss: 0.006135
# Epoch 543, Loss: 0.006132
# Epoch 544, Loss: 0.006129
# Epoch 545, Loss: 0.006126
# Epoch 546, Loss: 0.006123
# Epoch 547, Loss: 0.006121
# Epoch 548, Loss: 0.006118
# Epoch 549, Loss: 0.006115
# Epoch 550, Loss: 0.006112
# Epoch 551, Loss: 0.006110
# Epoch 552, Loss: 0.006107
# Epoch 553, Loss: 0.006104
# Epoch 554, Loss: 0.006101
# Epoch 555, Loss: 0.006098
# Epoch 556, Loss: 0.006095
# Epoch 557, Loss: 0.006093
# Epoch 558, Loss: 0.006090
# Epoch 559, Loss: 0.006087
# Epoch 560, Loss: 0.006084
# Epoch 561, Loss: 0.006081
# Epoch 562, Loss: 0.006078
# Epoch 563, Loss: 0.006076
# Epoch 564, Loss: 0.006073
# Epoch 565, Loss: 0.006070
# Epoch 566, Loss: 0.006067
# Epoch 567, Loss: 0.006064
# Epoch 568, Loss: 0.006061
# Epoch 569, Loss: 0.006058
# Epoch 570, Loss: 0.006056
# Epoch 571, Loss: 0.006053
# Epoch 572, Loss: 0.006050
# Epoch 573, Loss: 0.006047
# Epoch 574, Loss: 0.006044
# Epoch 575, Loss: 0.006041
# Epoch 576, Loss: 0.006038
# Epoch 577, Loss: 0.006035
# Epoch 578, Loss: 0.006032
# Epoch 579, Loss: 0.006030
# Epoch 580, Loss: 0.006027
# Epoch 581, Loss: 0.006024
# Epoch 582, Loss: 0.006021
# Epoch 583, Loss: 0.006018
# Epoch 584, Loss: 0.006015
# Epoch 585, Loss: 0.006012
# Epoch 586, Loss: 0.006009
# Epoch 587, Loss: 0.006006
# Epoch 588, Loss: 0.006003
# Epoch 589, Loss: 0.006000
# Epoch 590, Loss: 0.005997
# Epoch 591, Loss: 0.005994
# Epoch 592, Loss: 0.005991
# Epoch 593, Loss: 0.005988
# Epoch 594, Loss: 0.005985
# Epoch 595, Loss: 0.005982
# Epoch 596, Loss: 0.005979
# Epoch 597, Loss: 0.005976
# Epoch 598, Loss: 0.005973
# Epoch 599, Loss: 0.005970
# Epoch 600, Loss: 0.005967
# Epoch 601, Loss: 0.005964
# Epoch 602, Loss: 0.005961
# Epoch 603, Loss: 0.005958
# Epoch 604, Loss: 0.005955
# Epoch 605, Loss: 0.005952
# Epoch 606, Loss: 0.005949
# Epoch 607, Loss: 0.005946
# Epoch 608, Loss: 0.005943
# Epoch 609, Loss: 0.005939
# Epoch 610, Loss: 0.005936
# Epoch 611, Loss: 0.005933
# Epoch 612, Loss: 0.005930
# Epoch 613, Loss: 0.005927
# Epoch 614, Loss: 0.005924
# Epoch 615, Loss: 0.005921
# Epoch 616, Loss: 0.005918
# Epoch 617, Loss: 0.005914
# Epoch 618, Loss: 0.005911
# Epoch 619, Loss: 0.005908
# Epoch 620, Loss: 0.005905
# Epoch 621, Loss: 0.005902
# Epoch 622, Loss: 0.005899
# Epoch 623, Loss: 0.005896
# Epoch 624, Loss: 0.005892
# Epoch 625, Loss: 0.005889
# Epoch 626, Loss: 0.005886
# Epoch 627, Loss: 0.005883
# Epoch 628, Loss: 0.005880
# Epoch 629, Loss: 0.005876
# Epoch 630, Loss: 0.005873
# Epoch 631, Loss: 0.005870
# Epoch 632, Loss: 0.005867
# Epoch 633, Loss: 0.005863
# Epoch 634, Loss: 0.005860
# Epoch 635, Loss: 0.005857
# Epoch 636, Loss: 0.005854
# Epoch 637, Loss: 0.005850
# Epoch 638, Loss: 0.005847
# Epoch 639, Loss: 0.005844
# Epoch 640, Loss: 0.005840
# Epoch 641, Loss: 0.005837
# Epoch 642, Loss: 0.005834
# Epoch 643, Loss: 0.005830
# Epoch 644, Loss: 0.005827
# Epoch 645, Loss: 0.005824
# Epoch 646, Loss: 0.005820
# Epoch 647, Loss: 0.005817
# Epoch 648, Loss: 0.005814
# Epoch 649, Loss: 0.005810
# Epoch 650, Loss: 0.005807
# Epoch 651, Loss: 0.005804
# Epoch 652, Loss: 0.005800
# Epoch 653, Loss: 0.005797
# Epoch 654, Loss: 0.005793
# Epoch 655, Loss: 0.005790
# Epoch 656, Loss: 0.005786
# Epoch 657, Loss: 0.005783
# Epoch 658, Loss: 0.005780
# Epoch 659, Loss: 0.005776
# Epoch 660, Loss: 0.005773
# Epoch 661, Loss: 0.005769
# Epoch 662, Loss: 0.005766
# Epoch 663, Loss: 0.005762
# Epoch 664, Loss: 0.005759
# Epoch 665, Loss: 0.005755
# Epoch 666, Loss: 0.005752
# Epoch 667, Loss: 0.005748
# Epoch 668, Loss: 0.005744
# Epoch 669, Loss: 0.005741
# Epoch 670, Loss: 0.005737
# Epoch 671, Loss: 0.005734
# Epoch 672, Loss: 0.005730
# Epoch 673, Loss: 0.005727
# Epoch 674, Loss: 0.005723
# Epoch 675, Loss: 0.005719
# Epoch 676, Loss: 0.005716
# Epoch 677, Loss: 0.005712
# Epoch 678, Loss: 0.005708
# Epoch 679, Loss: 0.005705
# Epoch 680, Loss: 0.005701
# Epoch 681, Loss: 0.005697
# Epoch 682, Loss: 0.005694
# Epoch 683, Loss: 0.005690
# Epoch 684, Loss: 0.005686
# Epoch 685, Loss: 0.005682
# Epoch 686, Loss: 0.005679
# Epoch 687, Loss: 0.005675
# Epoch 688, Loss: 0.005671
# Epoch 689, Loss: 0.005667
# Epoch 690, Loss: 0.005664
# Epoch 691, Loss: 0.005660
# Epoch 692, Loss: 0.005656
# Epoch 693, Loss: 0.005652
# Epoch 694, Loss: 0.005648
# Epoch 695, Loss: 0.005644
# Epoch 696, Loss: 0.005641
# Epoch 697, Loss: 0.005637
# Epoch 698, Loss: 0.005633
# Epoch 699, Loss: 0.005629
# Epoch 700, Loss: 0.005625
# Epoch 701, Loss: 0.005621
# Epoch 702, Loss: 0.005617
# Epoch 703, Loss: 0.005613
# Epoch 704, Loss: 0.005609
# Epoch 705, Loss: 0.005605
# Epoch 706, Loss: 0.005601
# Epoch 707, Loss: 0.005597
# Epoch 708, Loss: 0.005593
# Epoch 709, Loss: 0.005589
# Epoch 710, Loss: 0.005585
# Epoch 711, Loss: 0.005581
# Epoch 712, Loss: 0.005577
# Epoch 713, Loss: 0.005573
# Epoch 714, Loss: 0.005569
# Epoch 715, Loss: 0.005564
# Epoch 716, Loss: 0.005560
# Epoch 717, Loss: 0.005556
# Epoch 718, Loss: 0.005552
# Epoch 719, Loss: 0.005548
# Epoch 720, Loss: 0.005543
# Epoch 721, Loss: 0.005539
# Epoch 722, Loss: 0.005535
# Epoch 723, Loss: 0.005531
# Epoch 724, Loss: 0.005526
# Epoch 725, Loss: 0.005522
# Epoch 726, Loss: 0.005518
# Epoch 727, Loss: 0.005513
# Epoch 728, Loss: 0.005509
# Epoch 729, Loss: 0.005505
# Epoch 730, Loss: 0.005500
# Epoch 731, Loss: 0.005496
# Epoch 732, Loss: 0.005491
# Epoch 733, Loss: 0.005487
# Epoch 734, Loss: 0.005482
# Epoch 735, Loss: 0.005478
# Epoch 736, Loss: 0.005473
# Epoch 737, Loss: 0.005469
# Epoch 738, Loss: 0.005464
# Epoch 739, Loss: 0.005460
# Epoch 740, Loss: 0.005455
# Epoch 741, Loss: 0.005450
# Epoch 742, Loss: 0.005446
# Epoch 743, Loss: 0.005441
# Epoch 744, Loss: 0.005436
# Epoch 745, Loss: 0.005432
# Epoch 746, Loss: 0.005427
# Epoch 747, Loss: 0.005422
# Epoch 748, Loss: 0.005417
# Epoch 749, Loss: 0.005412
# Epoch 750, Loss: 0.005408
# Epoch 751, Loss: 0.005403
# Epoch 752, Loss: 0.005398
# Epoch 753, Loss: 0.005393
# Epoch 754, Loss: 0.005388
# Epoch 755, Loss: 0.005383
# Epoch 756, Loss: 0.005378
# Epoch 757, Loss: 0.005373
# Epoch 758, Loss: 0.005368
# Epoch 759, Loss: 0.005363
# Epoch 760, Loss: 0.005358
# Epoch 761, Loss: 0.005353
# Epoch 762, Loss: 0.005347
# Epoch 763, Loss: 0.005342
# Epoch 764, Loss: 0.005337
# Epoch 765, Loss: 0.005332
# Epoch 766, Loss: 0.005326
# Epoch 767, Loss: 0.005321
# Epoch 768, Loss: 0.005316
# Epoch 769, Loss: 0.005310
# Epoch 770, Loss: 0.005305
# Epoch 771, Loss: 0.005299
# Epoch 772, Loss: 0.005294
# Epoch 773, Loss: 0.005288
# Epoch 774, Loss: 0.005283
# Epoch 775, Loss: 0.005277
# Epoch 776, Loss: 0.005272
# Epoch 777, Loss: 0.005266
# Epoch 778, Loss: 0.005260
# Epoch 779, Loss: 0.005255
# Epoch 780, Loss: 0.005249
# Epoch 781, Loss: 0.005243
# Epoch 782, Loss: 0.005237
# Epoch 783, Loss: 0.005231
# Epoch 784, Loss: 0.005225
# Epoch 785, Loss: 0.005219
# Epoch 786, Loss: 0.005213
# Epoch 787, Loss: 0.005207
# Epoch 788, Loss: 0.005201
# Epoch 789, Loss: 0.005195
# Epoch 790, Loss: 0.005189
# Epoch 791, Loss: 0.005183
# Epoch 792, Loss: 0.005177
# Epoch 793, Loss: 0.005170
# Epoch 794, Loss: 0.005164
# Epoch 795, Loss: 0.005157
# Epoch 796, Loss: 0.005151
# Epoch 797, Loss: 0.005145
# Epoch 798, Loss: 0.005138
# Epoch 799, Loss: 0.005131
# Epoch 800, Loss: 0.005125
# Epoch 801, Loss: 0.005118
# Epoch 802, Loss: 0.005111
# Epoch 803, Loss: 0.005104
# Epoch 804, Loss: 0.005098
# Epoch 805, Loss: 0.005091
# Epoch 806, Loss: 0.005084
# Epoch 807, Loss: 0.005077
# Epoch 808, Loss: 0.005070
# Epoch 809, Loss: 0.005062
# Epoch 810, Loss: 0.005055
# Epoch 811, Loss: 0.005048
# Epoch 812, Loss: 0.005041
# Epoch 813, Loss: 0.005033
# Epoch 814, Loss: 0.005026
# Epoch 815, Loss: 0.005018
# Epoch 816, Loss: 0.005011
# Epoch 817, Loss: 0.005003
# Epoch 818, Loss: 0.004995
# Epoch 819, Loss: 0.004987
# Epoch 820, Loss: 0.004980
# Epoch 821, Loss: 0.004972
# Epoch 822, Loss: 0.004964
# Epoch 823, Loss: 0.004956
# Epoch 824, Loss: 0.004947
# Epoch 825, Loss: 0.004939
# Epoch 826, Loss: 0.004931
# Epoch 827, Loss: 0.004922
# Epoch 828, Loss: 0.004914
# Epoch 829, Loss: 0.004905
# Epoch 830, Loss: 0.004897
# Epoch 831, Loss: 0.004888
# Epoch 832, Loss: 0.004879
# Epoch 833, Loss: 0.004870
# Epoch 834, Loss: 0.004861
# Epoch 835, Loss: 0.004852
# Epoch 836, Loss: 0.004843
# Epoch 837, Loss: 0.004833
# Epoch 838, Loss: 0.004824
# Epoch 839, Loss: 0.004815
# Epoch 840, Loss: 0.004805
# Epoch 841, Loss: 0.004795
# Epoch 842, Loss: 0.004785
# Epoch 843, Loss: 0.004775
# Epoch 844, Loss: 0.004765
# Epoch 845, Loss: 0.004755
# Epoch 846, Loss: 0.004745
# Epoch 847, Loss: 0.004735
# Epoch 848, Loss: 0.004724
# Epoch 849, Loss: 0.004713
# Epoch 850, Loss: 0.004703
# Epoch 851, Loss: 0.004692
# Epoch 852, Loss: 0.004681
# Epoch 853, Loss: 0.004670
# Epoch 854, Loss: 0.004658
# Epoch 855, Loss: 0.004647
# Epoch 856, Loss: 0.004635
# Epoch 857, Loss: 0.004624
# Epoch 858, Loss: 0.004612
# Epoch 859, Loss: 0.004600
# Epoch 860, Loss: 0.004588
# Epoch 861, Loss: 0.004575
# Epoch 862, Loss: 0.004563
# Epoch 863, Loss: 0.004550
# Epoch 864, Loss: 0.004537
# Epoch 865, Loss: 0.004524
# Epoch 866, Loss: 0.004511
# Epoch 867, Loss: 0.004498
# Epoch 868, Loss: 0.004485
# Epoch 869, Loss: 0.004471
# Epoch 870, Loss: 0.004457
# Epoch 871, Loss: 0.004443
# Epoch 872, Loss: 0.004429
# Epoch 873, Loss: 0.004414
# Epoch 874, Loss: 0.004400
# Epoch 875, Loss: 0.004385
# Epoch 876, Loss: 0.004370
# Epoch 877, Loss: 0.004355
# Epoch 878, Loss: 0.004339
# Epoch 879, Loss: 0.004323
# Epoch 880, Loss: 0.004308
# Epoch 881, Loss: 0.004291
# Epoch 882, Loss: 0.004275
# Epoch 883, Loss: 0.004258
# Epoch 884, Loss: 0.004241
# Epoch 885, Loss: 0.004224
# Epoch 886, Loss: 0.004207
# Epoch 887, Loss: 0.004189
# Epoch 888, Loss: 0.004172
# Epoch 889, Loss: 0.004153
# Epoch 890, Loss: 0.004135
# Epoch 891, Loss: 0.004116
# Epoch 892, Loss: 0.004097
# Epoch 893, Loss: 0.004078
# Epoch 894, Loss: 0.004059
# Epoch 895, Loss: 0.004039
# Epoch 896, Loss: 0.004019
# Epoch 897, Loss: 0.003998
# Epoch 898, Loss: 0.003977
# Epoch 899, Loss: 0.003956
# Epoch 900, Loss: 0.003935
# Epoch 901, Loss: 0.003913
# Epoch 902, Loss: 0.003891
# Epoch 903, Loss: 0.003869
# Epoch 904, Loss: 0.003846
# Epoch 905, Loss: 0.003823
# Epoch 906, Loss: 0.003800
# Epoch 907, Loss: 0.003776
# Epoch 908, Loss: 0.003752
# Epoch 909, Loss: 0.003728
# Epoch 910, Loss: 0.003703
# Epoch 911, Loss: 0.003678
# Epoch 912, Loss: 0.003653
# Epoch 913, Loss: 0.003627
# Epoch 914, Loss: 0.003601
# Epoch 915, Loss: 0.003575
# Epoch 916, Loss: 0.003548
# Epoch 917, Loss: 0.003521
# Epoch 918, Loss: 0.003494
# Epoch 919, Loss: 0.003466
# Epoch 920, Loss: 0.003438
# Epoch 921, Loss: 0.003409
# Epoch 922, Loss: 0.003381
# Epoch 923, Loss: 0.003352
# Epoch 924, Loss: 0.003322
# Epoch 925, Loss: 0.003293
# Epoch 926, Loss: 0.003263
# Epoch 927, Loss: 0.003233
# Epoch 928, Loss: 0.003202
# Epoch 929, Loss: 0.003172
# Epoch 930, Loss: 0.003141
# Epoch 931, Loss: 0.003110
# Epoch 932, Loss: 0.003079
# Epoch 933, Loss: 0.003047
# Epoch 934, Loss: 0.003016
# Epoch 935, Loss: 0.002984
# Epoch 936, Loss: 0.002952
# Epoch 937, Loss: 0.002920
# Epoch 938, Loss: 0.002888
# Epoch 939, Loss: 0.002856
# Epoch 940, Loss: 0.002824
# Epoch 941, Loss: 0.002792
# Epoch 942, Loss: 0.002760
# Epoch 943, Loss: 0.002728
# Epoch 944, Loss: 0.002696
# Epoch 945, Loss: 0.002664
# Epoch 946, Loss: 0.002632
# Epoch 947, Loss: 0.002600
# Epoch 948, Loss: 0.002569
# Epoch 949, Loss: 0.002538
# Epoch 950, Loss: 0.002507
# Epoch 951, Loss: 0.002476
# Epoch 952, Loss: 0.002445
# Epoch 953, Loss: 0.002415
# Epoch 954, Loss: 0.002385
# Epoch 955, Loss: 0.002356
# Epoch 956, Loss: 0.002327
# Epoch 957, Loss: 0.002298
# Epoch 958, Loss: 0.002269
# Epoch 959, Loss: 0.002241
# Epoch 960, Loss: 0.002214
# Epoch 961, Loss: 0.002187
# Epoch 962, Loss: 0.002160
# Epoch 963, Loss: 0.002134
# Epoch 964, Loss: 0.002108
# Epoch 965, Loss: 0.002083
# Epoch 966, Loss: 0.002058
# Epoch 967, Loss: 0.002034
# Epoch 968, Loss: 0.002011
# Epoch 969, Loss: 0.001987
# Epoch 970, Loss: 0.001965
# Epoch 971, Loss: 0.001943
# Epoch 972, Loss: 0.001921
# Epoch 973, Loss: 0.001900
# Epoch 974, Loss: 0.001880
# Epoch 975, Loss: 0.001860
# Epoch 976, Loss: 0.001840
# Epoch 977, Loss: 0.001821
# Epoch 978, Loss: 0.001802
# Epoch 979, Loss: 0.001784
# Epoch 980, Loss: 0.001767
# Epoch 981, Loss: 0.001750
# Epoch 982, Loss: 0.001733
# Epoch 983, Loss: 0.001717
# Epoch 984, Loss: 0.001701
# Epoch 985, Loss: 0.001686
# Epoch 986, Loss: 0.001671
# Epoch 987, Loss: 0.001657
# Epoch 988, Loss: 0.001643
# Epoch 989, Loss: 0.001629
# Epoch 990, Loss: 0.001616
# Epoch 991, Loss: 0.001603
# Epoch 992, Loss: 0.001591
# Epoch 993, Loss: 0.001579
# Epoch 994, Loss: 0.001567
# Epoch 995, Loss: 0.001555
# Epoch 996, Loss: 0.001544
# Epoch 997, Loss: 0.001533
# Epoch 998, Loss: 0.001523
# Epoch 999, Loss: 0.001513

# %%
plt.figure(figsize=(15,10))
plt.plot(y_hat[0,:,0].detach().numpy(), label='Predicted')
plt.plot(y_batch[0,:,0].detach().numpy(), label='Target')
plt.plot(u_batch[0,:,0].detach().numpy(), label='u')
plt.grid()
plt.legend()
plt.show()
